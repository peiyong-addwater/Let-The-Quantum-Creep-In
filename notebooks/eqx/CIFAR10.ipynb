# %%
#pip install -U "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install pennylane pennylane-lightning pennylane-lightning[gpu] cotengra quimb equinox jaxtyping --upgrade
# Out:
# Requirement already satisfied: pennylane in /usr/local/lib/python3.10/dist-packages (0.35.1)
# Requirement already satisfied: pennylane-lightning in /usr/local/lib/python3.10/dist-packages (0.35.1)
# Requirement already satisfied: cotengra in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: quimb in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: equinox in /usr/local/lib/python3.10/dist-packages (0.11.4)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.10/dist-packages (0.2.28)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.3)
# Requirement already satisfied: rustworkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.14.2)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.6.9)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.11.0)
# Requirement already satisfied: pennylane-lightning-gpu in /usr/local/lib/python3.10/dist-packages (from pennylane-lightning) (0.35.1)
# Requirement already satisfied: cytoolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from quimb) (0.12.3)
# Requirement already satisfied: numba>=0.39 in /usr/local/lib/python3.10/dist-packages (from quimb) (0.58.1)
# Requirement already satisfied: psutil>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from quimb) (5.9.5)
# Requirement already satisfied: tqdm>=4 in /usr/local/lib/python3.10/dist-packages (from quimb) (4.66.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.10/dist-packages (from equinox) (0.4.26)
# Requirement already satisfied: typeguard==2.13.3 in /usr/local/lib/python3.10/dist-packages (from jaxtyping) (2.13.3)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz>=0.8.0->quimb) (0.12.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->equinox) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->equinox) (3.3.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.39->quimb) (0.41.1)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)

# %% [markdown]
# # Import Packages

# %%
import matplotlib.pyplot as plt
import sys
import pandas as pd
import jax

import os, json

from datetime import datetime
import time

from jaxtyping import Array, Float, Int, PyTree
import jax.numpy as jnp
import numpy as np

import equinox as eqx

import optax  # optimization using jax

import torch  # https://pytorch.org
import torchvision  # https://pytorch.org

import pennylane as qml
import pennylane.numpy as pnp

import functools, itertools

from jax.lib import xla_bridge

#jax.config.update("jax_enable_x64", True)
#os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"

def set_jax_platform():
    # Check if TPU is available
    try:
        tpu_backend = xla_bridge.get_backend('tpu')
        if tpu_backend and tpu_backend.device_count() > 0:
            # Set platform to TPU
            jax.config.update('jax_platform_name', 'tpu')
            print("Set platform to TPU")
            return
    except RuntimeError:
        pass  # No TPU found, move on to check for GPU

    # Check if GPU is available
    try:
      gpu_backend = xla_bridge.get_backend('gpu')
      if gpu_backend and gpu_backend.device_count() > 0:
          # Set platform to CUDA (GPU)
          jax.config.update('jax_platform_name', 'gpu')
          print("Set platform to GPU")
    except RuntimeError:
          # Set platform to CPU
          jax.config.update('jax_platform_name', 'cpu')
          print("Set platform to CPU")

# Call the function to set the platform
set_jax_platform()

seed = 1701
jrng_key = jax.random.PRNGKey(seed)
torch.manual_seed(seed)
print(jax.devices())
# Out:
# Set platform to GPU
# [cuda(id=0)]

# %% [markdown]
# # Training Hyper-parameters

# %%
# some training configuration
DATA = "CIFAR10" # "MNIST", "FashionMNIST", "CIFAR10"
BATCH_SIZE = 500
EPOCHS = 100
LEARNING_RATE = 5E-3
REPEATS = 5

curr_time = datetime.now().strftime("%Y%m%d_%H%M%S")

# %% [markdown]
# # Utilities for Quantum Circuit Simulation and Quantum Layers

# %%
# utilities
ket = {
    '0':jnp.array([1,0]),
    '1':jnp.array([0,1]),
    '+':(jnp.array([1,0]) + jnp.array([0,1]))/jnp.sqrt(2),
    '-':(jnp.array([1,0]) - jnp.array([0,1]))/jnp.sqrt(2)
}

pauli = {
    'I':jnp.array([[1,0],[0,1]]),
    'X':jnp.array([[0,1],[1,0]]),
    'Y':jnp.array([[0, -1j],[1j, 0]]),
    'Z':jnp.array([[1,0],[0,-1]])
}

def tensor_product(*args):
  input_list = [a for a in args]
  return functools.reduce(jnp.kron, input_list)

def multi_qubit_identity(n_qubits:int)->jnp.ndarray:
  assert n_qubits>0
  if n_qubits == 1:
    return pauli['I']
  else:
    return tensor_product(*[pauli['I'] for _ in range(n_qubits)])

def pauli_dict_func(key):
    return pauli[key]

def pauli_dict_func_multiple_keys(keys):
    return list(map(pauli_dict_func, keys))

def pauli_string_tensor_prod(pauli_string:str):
    paulis_char = list(pauli_string)
    paulis_mat = pauli_dict_func_multiple_keys(paulis_char)
    return tensor_product(*paulis_mat)

def generate_nqubit_pauli_strings(n_qubits:int):
    assert n_qubits>0
    pauli_labels = ['I', 'X', 'Y', 'Z']
    pauli_strings = []
    for labels in itertools.product(pauli_labels, repeat=n_qubits):
        pauli_str = "".join(labels)
        if pauli_str != 'I'*n_qubits:
            pauli_strings.append(pauli_str)
    return pauli_strings

def generate_pauli_tensor_list(pauli_strings:list):
    return list(map(pauli_string_tensor_prod, pauli_strings))

su4_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(2)
)

su32_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(5)
)

su8_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(3)
)

su16_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(4)
)

def su32_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su32_generators))
    return jax.scipy.linalg.expm(1j*generator)

def su4_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su4_generators))
    return jax.scipy.linalg.expm(1j*generator)

def su8_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su8_generators))
    return jax.scipy.linalg.expm(1j*generator)

def su16_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su16_generators))
    return jax.scipy.linalg.expm(1j*generator)

def measure_sv(
    state:jnp.ndarray,
    observable:jnp.ndarray
    ):
  """
  Measure a statevector with a Hermitian observable.
  Note: No checking Hermitianicity of the observable or whether the observable
  has all real eigenvalues or not
  """
  expectation_value = jnp.dot(jnp.conj(state.T), jnp.dot(observable, state))
  return jnp.real(expectation_value)

def measure_dm(
    rho:jnp.ndarray,
    observable:jnp.ndarray
):
  """
  Measure a density matrix with a Hermitian observable.
  Note: No checking Hermitianicity of the observable or whether the observable
  has all real eigenvalues or not.
  """
  product = jnp.dot(rho, observable)

  # Calculate the trace, which is the sum of diagonal elements
  trace = jnp.trace(product)

  # The expectation value should be real for physical observables
  return jnp.real(trace)

# assuming the input patch (hermitianized) has shape (c, h, w)
# assuming the input set statevectors has shape (c, 2**n)
# assuming we have a list of (state, observable) pairs
vmap_measure_sv_ob_pairs = jax.vmap(lambda pair: measure_sv(pair[0], pair[1]), in_axes=0, out_axes=0)
# assuming the input set desnity matrices has shape (c, 2**n, 2**n)
# assuming we have a list of (rho, observable) pairs
vmap_measure_dm_ob_pairs = jax.vmap(lambda pair: measure_dm(pair[0], pair[1]), in_axes=0, out_axes=0)

# vmap through different observables
vmap_measure_sv = jax.vmap(measure_sv, in_axes=(None, 0), out_axes=0)
vmap_measure_dm = jax.vmap(measure_dm, in_axes=(None, 0), out_axes=0)

def bitstring_to_state(bitstring:str):
  """
  Convert a bit string, like '0101001' or '+-+-101'
  to a statevector. Each character in the bitstring must be among
  0, 1, + and -
  """
  assert len(bitstring)>0
  for c in bitstring:
    assert c in ['0', '1', '+', '-']
  single_qubit_states = [ket[c] for c in bitstring]
  return tensor_product(*single_qubit_states)


# utilities for the flipped quanvolution kernel
def extract_patches(image, patch_size, stride, padding=None):
    """
    Extracts patches from an image with multiple input channels and optional custom padding.

    Args:
        image (jnp.ndarray): Input image tensor of shape (in_channels, height, width).
        patch_size (int): Size of the square patches to extract.
        stride (int): Stride between patches.
        padding (tuple): Padding value(s) for each dimension.

    Returns:
        jnp.ndarray: Tensor of extracted patches of shape (num_patches, in_channels, patch_size, patch_size).
    """

    in_channels, height, width = image.shape[-3], image.shape[-2], image.shape[-1]

    pad_h, pad_w = padding if padding is not None else (0, 0)


    image = jnp.pad(image, [(0, 0), (pad_h, pad_h), (pad_w, pad_w)], mode='constant') if padding is not None else image


    _, height, width = image.shape


    num_patches_h = (height - patch_size) // stride + 1
    num_patches_w = (width - patch_size) // stride + 1

    patch_indices = [(i, j) for i in range(num_patches_h) for j in range(num_patches_w)]

    patches = jnp.stack([image[:, i*stride:i*stride+patch_size, j*stride:j*stride+patch_size]
                         for i, j in patch_indices])

    return patches


def generate_2q_param_state(theta):
  state = bitstring_to_state('00')
  state = jnp.dot(
      su4_op(theta),
      state
  )
  return state

vmap_generate_2q_param_state = jax.vmap(generate_2q_param_state, in_axes=0, out_axes = 0)

# FlippedQuanv3x3 kernel
def single_kernel_op(thetas, patch):
  # patch has shape (c_in, h, w)
  # thetas has shape (c_in, 4^2-1) for SU4 gates
  n_theta = thetas.shape[0]
  n_channel = patch.shape[0]
  assert n_theta == n_channel, "Thetas and patch must have the same number of channels."
  states = vmap_generate_2q_param_state(thetas)
  patch = jnp.pad(patch, [(0,0),(0,1),(0,1)], mode='constant')
  herm_patch = (jnp.einsum("ijk->ikj", patch)+patch)/2
  channel_out = vmap_measure_sv_ob_pairs([states, herm_patch])
  return jnp.sum(channel_out, axis = 0)/n_theta

vmap_single_kernel_op_through_extracted_patches = jax.vmap(single_kernel_op, in_axes=(None, 0), out_axes=0)

# For multiple channel output
# parameter has shape (c_out, c_in, 4**2-1) for SU4 gates
vmap_vmap_single_kernel_op_through_extracted_patches = jax.vmap(vmap_single_kernel_op_through_extracted_patches, in_axes=(0, None), out_axes=0)

# Quantum version of the linear layer
# Realized with data reuploading and Hamiltonian embedding
# for input dimension D
# the quantum linear layer is a n = ceil(log4(D+1))-qubit quantum circuit
# Both the data encoding and the parameterised cirucit are achieved via the SU(2^n) unitary

def data_encode_unitary(padded_data, t):
    #original_dim = 4**7 # fix to 7 qubits #padded_data.shape[-1]
    #new_dim = jnp.sqrt(original_dim).astype(jnp.int_)
    data = jnp.reshape(padded_data, (2**7, 2**7))
    generator = (data + jnp.einsum('...jk->...kj', data))/2
    return jax.scipy.linalg.expm(1.0j*t*generator)

def su_n(params, pauli_string_tensor_list):
    paulis = jnp.asarray(pauli_string_tensor_list)
    generator = jnp.einsum("i, ijk -> jk", params, paulis)
    return jax.scipy.linalg.expm(1.0j*generator)

def linear_layer_func(
        padded_data,
        params,
        pauli_string_tensor_list,
        observables,
        n_qubits
):
    n_rep = params.shape[0]
    state = bitstring_to_state("+" * n_qubits)
    data_unitary = data_encode_unitary(padded_data, 1.0/n_rep)
    for i in range(n_rep):
        state = jnp.dot(data_unitary, state)
        state = jnp.dot(su_n(params[i], pauli_string_tensor_list), state)
    return vmap_measure_sv(state, observables)

vmap_batch_linear_layer_func = jax.vmap(linear_layer_func, in_axes=(0, None, None, None, None), out_axes=0)

# %% [markdown]
# # Layers and Models

# %%
# models
class FlippedQuanv3x3(eqx.Module):
  weight: jax.Array
  bias: jax.Array
  stride: int
  pad: tuple|None
  pad_h: int
  pad_w: int

  def __init__(self, in_channels, out_channels, stride, padding, key):
    wkey, bkey = jax.random.split(key,2)
    self.weight = jax.random.normal(shape=[out_channels, in_channels, 15], key=wkey)
    self.bias = jax.random.normal(shape=[out_channels, 1], key=bkey)
    self.stride = stride
    self.pad = padding
    self.pad_h, self.pad_w = padding if padding is not None else (0,0)

  def __call__(self, x):
    # x has shape ( ,c_in, h, w)
    # weight has shape (c_out, c_in, 15)
    # bias has shape (c_out, 1)
    c_in, h_in, w_in = x.shape[-3], x.shape[-2], x.shape[-1]
    patches = extract_patches(x, patch_size=3, stride=self.stride, padding=self.pad)
    h_out = (h_in-3+2*self.pad_h)//self.stride +1
    w_out = (w_in-3+2*self.pad_w)//self.stride +1
    out = vmap_vmap_single_kernel_op_through_extracted_patches(self.weight, patches)
    out = out + self.bias
    return out.reshape((-1, h_out, w_out))

class DataReUploadingLinear(eqx.Module):
    weight: jax.Array
    bias: jax.Array
    n_reps:int
    in_dim:int
    out_dim:int
    n_qubits:int

    def __init__(self, n_reps, key):
        #assert 2 ** n_qubits >= out_dim
        #assert 4 ** n_qubits >= in_dim
        wkey, bkey = jax.random.split(key, 2)
        # fix the following parameters for jit
        self.in_dim = 16 * 28 * 28
        self.out_dim = 10
        self.n_qubits = 7
        # in_dim is 16 * 28 * 28
        # out_dim is 10
        self.n_reps = n_reps
        param_dim = 4 ** self.n_qubits - 1
        self.weight = jax.random.normal(shape=[self.n_reps, param_dim], key=wkey)
        self.bias = jax.random.normal(shape=[self.out_dim], key=bkey)

    def generate_observables(self):
        observables = []
        for i in range(self.out_dim):
            temp_bitstring = '{0:b}'.format(i).zfill(self.n_qubits)
            ob = jnp.outer(bitstring_to_state(temp_bitstring), bitstring_to_state(temp_bitstring))
            observables.append(ob)
        return jnp.asarray(observables)

    def get_pauli_string_tensor_list(self):
        return generate_pauli_tensor_list(generate_nqubit_pauli_strings(self.n_qubits))

    #def get_pad_size(self):
    #    return 4 ** self.n_qubits - self.in_dim

    def __call__(self, x):
        # x has size (batchsize, in_dim)
        # pad x
        x = jnp.pad(x, (0, 4 ** self.n_qubits - self.in_dim))

        out = linear_layer_func(
            padded_data=x,
            params=self.weight,
            pauli_string_tensor_list=self.get_pauli_string_tensor_list(),
            observables=self.generate_observables(),
            n_qubits=self.n_qubits
        )
        out = out + self.bias
        return out

# %%
def loss_fn(
    pred_y:Float[Array, "batch 10"],
    y:Int[Array, "batch"]
):
  return jnp.mean(optax.softmax_cross_entropy_with_integer_labels(pred_y, y))

def accuracy_fn(
    pred_y:Float[Array, "batch 10"],
    y:Int[Array, "batch"]
):
  pred = jnp.argmax(pred_y, axis=1)
  return jnp.sum(jnp.array(pred == y).astype(int)) / len(pred_y)

# depending on input dataset, the input number of channels differs
if DATA == "CIFAR10":
    class HybridNet(eqx.Module):
      replacement_lvl:int
      layers:list
      def __init__(self, replacement_lvl, key):
        assert replacement_lvl in [0,1,2]
        self.replacement_lvl = replacement_lvl
        key1, key2, key3 = jax.random.split(key, 3)
        if self.replacement_lvl == 0:
          self.layers = [
              eqx.nn.Conv2d(3, 32, kernel_size = 3, padding = 0, key=key1),
              eqx.nn.Conv2d(32, 16, kernel_size = 3, padding = 0, key=key2),
              jnp.ravel,
              eqx.nn.Linear(16*28*28, 10, key=key3)
          ]
        elif self.replacement_lvl == 1:
          self.layers = [
                FlippedQuanv3x3(3, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                eqx.nn.Linear(16 * 28 * 28, 10, key=key3),
          ]
        elif self.replacement_lvl == 2:
          self.layers = [
                FlippedQuanv3x3(3, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                DataReUploadingLinear(n_reps=10, key=key3),
          ]
        else:
          raise ValueError("replacement_lvl should be 0, 1, or 2")

      def __call__(self, x:Float[Array, "3 h w"])->Float[Array, "10"]:
        for layer in self.layers:
          x = layer(x)
        return x

    @eqx.filter_jit
    def compute_out(
        model:HybridNet,
        x:Float[Array, "batch 3 32 32"]
    ) -> Float[Array, "batch 10"]:
      return jax.vmap(model)(x)

    @eqx.filter_jit
    def compute_loss(
        model: HybridNet, x: Float[Array, "batch 3 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return loss_fn(pred_y, y)

    @eqx.filter_jit
    def compute_accuracy(
        model: HybridNet, x: Float[Array, "batch 3 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return accuracy_fn(pred_y, y)


else:
    class HybridNet(eqx.Module):
      replacement_lvl:int
      layers:list
      def __init__(self, replacement_lvl, key):
        assert replacement_lvl in [0,1,2]
        self.replacement_lvl = replacement_lvl
        key1, key2, key3 = jax.random.split(key, 3)
        if self.replacement_lvl == 0:
          self.layers = [
              eqx.nn.Conv2d(1, 32, kernel_size = 3, padding = 0, key=key1),
              eqx.nn.Conv2d(32, 16, kernel_size = 3, padding = 0, key=key2),
              jnp.ravel,
              eqx.nn.Linear(16*28*28, 10, key=key3)
          ]
        elif self.replacement_lvl == 1:
          self.layers = [
                FlippedQuanv3x3(1, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                eqx.nn.Linear(16 * 28 * 28, 10, key=key3),
          ]
        elif self.replacement_lvl == 2:
          self.layers = [
                FlippedQuanv3x3(1, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                DataReUploadingLinear(n_reps=10, key=key3),
          ]
        else:
          raise ValueError("replacement_lvl should be 0, 1, or 2")

      def __call__(self, x:Float[Array, "1 h w"])->Float[Array, "10"]:
        for layer in self.layers:
          x = layer(x)
        return x

    @eqx.filter_jit
    def compute_out(
        model:HybridNet,
        x:Float[Array, "batch 1 32 32"]
    ) -> Float[Array, "batch 10"]:
      return jax.vmap(model)(x)

    @eqx.filter_jit
    def compute_loss(
        model: HybridNet, x: Float[Array, "batch 1 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return loss_fn(pred_y, y)

    @eqx.filter_jit
    def compute_accuracy(
        model: HybridNet, x: Float[Array, "batch 1 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return accuracy_fn(pred_y, y)

# %% [markdown]
# # Training Utilities

# %%
def get_train_test_data(name = "MNIST"):
  assert name in ["MNIST", "CIFAR10", "FashionMNIST"]
  if name  == "CIFAR10":
    preprocess = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5,), (0.5,))
    ])
  else:
    preprocess =  torchvision.transforms.Compose([
    torchvision.transforms.Pad(2),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5,), (0.5,))
    ])
  if name == "MNIST":
    train = torchvision.datasets.MNIST(
        root="MNIST",
        train=True,
        transform=preprocess,
        download=True)
    test = torchvision.datasets.MNIST(
        root="MNIST",
        train=False,
        transform=preprocess,
        download=True)
  elif name == "CIFAR10":
    train = torchvision.datasets.CIFAR10(
        root="CIFAR10",
        train=True,
        transform=preprocess,
        download=True)
    test = torchvision.datasets.CIFAR10(
        root="CIFAR10",
        train=False,
        transform=preprocess,
        download=True)
  elif name == "FashionMNIST":
    train = torchvision.datasets.FashionMNIST(
        root="FashionMNIST",
        train=True,
        transform=preprocess,
        download=True)
    test = torchvision.datasets.FashionMNIST(
        root="FashionMNIST",
        train=False,
        transform=preprocess,
        download=True)
  else:
    raise ValueError("name should be MNIST, CIFAR10, or FashionMNIST")
  return train, test

def train(
      model: HybridNet,
      data_name: str,
      batchsize: int,
      epochs: int,
      optim: optax.GradientTransformation,
  ):

  train_loss = []
  train_acc = []
  test_loss = []
  test_acc = []

  opt_state = optim.init(eqx.filter(model, eqx.is_array))
  train_data, test_data = get_train_test_data(data_name)
  trainloader = torch.utils.data.DataLoader(
      train_data, batch_size=batchsize, shuffle=True)
  test_loader = torch.utils.data.DataLoader(
      test_data, batch_size=batchsize, shuffle=False)
  if data_name == "CIFAR10":
    @eqx.filter_jit
    def make_step(
      model: HybridNet,
      opt_state: PyTree,
      x: Float[Array, "batch 3 32 32"],
      y: Int[Array, "batch"],
    ):
      loss_value, grads = eqx.filter_value_and_grad(compute_loss)(model, x, y)
      updates, opt_state = optim.update(grads, opt_state, model)
      model = eqx.apply_updates(model, updates)
      acc = compute_accuracy(model, x, y)
      return model, opt_state, loss_value, acc

    @eqx.filter_jit
    def make_test_step(
        model:HybridNet,
        x: Float[Array, "batch 3 32 32"],
        y: Int[Array, "batch"],
    ):
      out = compute_out(model, x)
      loss_value = loss_fn(out, y)
      acc = accuracy_fn(out, y)
      return loss_value, acc
  else:
    @eqx.filter_jit
    def make_step(
      model: HybridNet,
      opt_state: PyTree,
      x: Float[Array, "batch 1 32 32"],
      y: Int[Array, "batch"],
    ):
      loss_value, grads = eqx.filter_value_and_grad(compute_loss)(model, x, y)
      updates, opt_state = optim.update(grads, opt_state, model)
      model = eqx.apply_updates(model, updates)
      acc = compute_accuracy(model, x, y)
      return model, opt_state, loss_value, acc

    @eqx.filter_jit
    def make_test_step(
        model:HybridNet,
        x: Float[Array, "batch 1 32 32"],
        y: Int[Array, "batch"],
    ):
      out = compute_out(model, x)
      loss_value = loss_fn(out, y)
      acc = accuracy_fn(out, y)
      return loss_value, acc


  for step in range(epochs):
    step_start = time.time()
    batch_train_loss = []
    batch_train_acc = []
    batch_test_loss = []
    batch_test_acc = []
    for batchidx, (x, y) in enumerate(trainloader):
      x = x.numpy()
      y = y.numpy()
      model, opt_state, loss_value_batch, acc_value_batch = make_step(model, opt_state, x, y)
      batch_train_loss.append(loss_value_batch)
      batch_train_acc.append(acc_value_batch)
    loss_value = float(np.mean(batch_train_loss))
    acc_value = float(np.mean(batch_train_acc))
    train_loss.append(loss_value)
    train_acc.append(acc_value)
    train_time = time.time() - step_start
    print(f"Train step {step}, loss = {loss_value:.4f}, acc = {acc_value:.4f}; train time = {train_time:.4f} seconds")

    for batchidx, (x, y) in enumerate(test_loader):
      x = x.numpy()
      y = y.numpy()
      loss_value_batch, acc_value_batch = make_test_step(model, x, y)
      batch_test_loss.append(loss_value_batch)
      batch_test_acc.append(acc_value_batch)

    test_loss_value, test_acc_value = float(np.mean(batch_test_loss)), float(np.mean(batch_test_acc))
    test_loss.append(test_loss_value)
    test_acc.append(test_acc_value)
    test_time = time.time() - step_start - train_time
    print(f"Test loss = {test_loss_value:.4f}, acc = {test_acc_value:.4f}; test time = {test_time:.4f} seconds")
    print(f"Total time = {time.time() - step_start:.4f} seconds")

  return model, train_loss, train_acc, test_loss, test_acc

# %% [markdown]
# # Training

# %%
REPLACEMENT_LVL = [1,0,2]
NUM_KEYS = len(REPLACEMENT_LVL)*REPEATS

keys = jax.random.split(jrng_key, NUM_KEYS)
key_count = 0
for replacement_lvl in REPLACEMENT_LVL:
  for rep in range(REPEATS):
    #if replacement_lvl == 2 and (rep==0 or rep==1 or rep==2):
    #  continue # already have rep = 0,1,2 from a previous execution
    print(f"____Training with replacement_lvl = {replacement_lvl}____")
    print(f"----Training with repetatioin = {rep}----")
    key = keys[key_count]
    key_count += 1
    model = HybridNet(replacement_lvl, key)
    optim = optax.adam(LEARNING_RATE)
    model, train_loss, train_acc, test_loss, test_acc = train(model, DATA, BATCH_SIZE, EPOCHS, optim)
    results = {
      "train_loss": train_loss,
      "train_acc": train_acc,
      "test_loss": test_loss,
      "test_acc": test_acc,
    }
    with open(os.path.join('/content/drive/MyDrive/Research/Quanvolution/notebooks/eqx', f"{curr_time}_{DATA}_replacement_lvl_{replacement_lvl}_rep_{rep}.json"), 'w') as f:
      json.dump(results, f, indent=4)

    eqx.tree_serialise_leaves(os.path.join('/content/drive/MyDrive/Research/Quanvolution/notebooks/eqx', f"{curr_time}_{DATA}_replacement_lvl_{replacement_lvl}_rep_{rep}.eqx"), model)
# Out:
# ____Training with replacement_lvl = 1____
# ----Training with repetatioin = 0----
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# Train step 0, loss = 12.8321, acc = 0.1963; train time = 97.2876 seconds
# Test loss = 2.0472, acc = 0.2821; test time = 21.0191 seconds
# Total time = 118.3068 seconds
# Train step 1, loss = 2.0057, acc = 0.2999; train time = 45.7918 seconds
# Test loss = 1.9667, acc = 0.3153; test time = 3.6557 seconds
# Total time = 49.4480 seconds
# Train step 2, loss = 1.9406, acc = 0.3237; train time = 45.6124 seconds
# Test loss = 1.8959, acc = 0.3287; test time = 3.6785 seconds
# Total time = 49.2910 seconds
# Train step 3, loss = 1.8779, acc = 0.3524; train time = 45.5801 seconds
# Test loss = 1.8622, acc = 0.3506; test time = 3.7106 seconds
# Total time = 49.2915 seconds
# Train step 4, loss = 1.8483, acc = 0.3631; train time = 45.6647 seconds
# Test loss = 1.8655, acc = 0.3372; test time = 3.6677 seconds
# Total time = 49.3331 seconds
# Train step 5, loss = 1.8266, acc = 0.3712; train time = 45.8241 seconds
# Test loss = 1.8109, acc = 0.3723; test time = 3.6373 seconds
# Total time = 49.4615 seconds
# Train step 6, loss = 1.7955, acc = 0.3844; train time = 45.6906 seconds
# Test loss = 1.8018, acc = 0.3675; test time = 3.6208 seconds
# Total time = 49.3116 seconds
# Train step 7, loss = 1.7764, acc = 0.3933; train time = 45.5491 seconds
# Test loss = 1.7889, acc = 0.3769; test time = 3.6420 seconds
# Total time = 49.1912 seconds
# Train step 8, loss = 1.7699, acc = 0.3972; train time = 45.6307 seconds
# Test loss = 1.7742, acc = 0.3861; test time = 3.6703 seconds
# Total time = 49.3011 seconds
# Train step 9, loss = 1.7570, acc = 0.4033; train time = 45.6099 seconds
# Test loss = 1.7837, acc = 0.3829; test time = 3.7016 seconds
# Total time = 49.3116 seconds
# Train step 10, loss = 1.7463, acc = 0.4056; train time = 45.5826 seconds
# Test loss = 1.7806, acc = 0.3805; test time = 3.6837 seconds
# Total time = 49.2665 seconds
# Train step 11, loss = 1.7358, acc = 0.4096; train time = 45.5948 seconds
# Test loss = 1.7668, acc = 0.3866; test time = 3.6771 seconds
# Total time = 49.2720 seconds
# Train step 12, loss = 1.7293, acc = 0.4111; train time = 45.7593 seconds
# Test loss = 1.7738, acc = 0.3818; test time = 3.6599 seconds
# Total time = 49.4192 seconds
# Train step 13, loss = 1.7259, acc = 0.4151; train time = 45.4801 seconds
# Test loss = 1.7622, acc = 0.3840; test time = 3.6356 seconds
# Total time = 49.1158 seconds
# Train step 14, loss = 1.7231, acc = 0.4161; train time = 45.6601 seconds
# Test loss = 1.7586, acc = 0.3827; test time = 3.6604 seconds
# Total time = 49.3206 seconds
# Train step 15, loss = 1.7195, acc = 0.4164; train time = 45.6130 seconds
# Test loss = 1.7517, acc = 0.4000; test time = 3.6739 seconds
# Total time = 49.2870 seconds
# Train step 16, loss = 1.7128, acc = 0.4201; train time = 45.6879 seconds
# Test loss = 1.7595, acc = 0.3913; test time = 3.7333 seconds
# Total time = 49.4215 seconds
# Train step 17, loss = 1.7073, acc = 0.4218; train time = 45.7137 seconds
# Test loss = 1.7554, acc = 0.3900; test time = 3.6917 seconds
# Total time = 49.4055 seconds
# Train step 18, loss = 1.7048, acc = 0.4216; train time = 45.9473 seconds
# Test loss = 1.7558, acc = 0.3899; test time = 3.6577 seconds
# Total time = 49.6052 seconds
# Train step 19, loss = 1.6996, acc = 0.4255; train time = 45.6653 seconds
# Test loss = 1.7596, acc = 0.3912; test time = 3.6509 seconds
# Total time = 49.3163 seconds
# Train step 20, loss = 1.7011, acc = 0.4227; train time = 45.7208 seconds
# Test loss = 1.7597, acc = 0.3903; test time = 3.6701 seconds
# Total time = 49.3909 seconds
# Train step 21, loss = 1.6992, acc = 0.4247; train time = 45.5643 seconds
# Test loss = 1.7670, acc = 0.3871; test time = 3.6609 seconds
# Total time = 49.2254 seconds
# Train step 22, loss = 1.6946, acc = 0.4275; train time = 45.6831 seconds
# Test loss = 1.7482, acc = 0.3927; test time = 3.6962 seconds
# Total time = 49.3793 seconds
# Train step 23, loss = 1.6931, acc = 0.4275; train time = 45.6889 seconds
# Test loss = 1.7553, acc = 0.3902; test time = 3.7773 seconds
# Total time = 49.4663 seconds
# Train step 24, loss = 1.6919, acc = 0.4281; train time = 45.8545 seconds
# Test loss = 1.7571, acc = 0.3926; test time = 3.7577 seconds
# Total time = 49.6123 seconds
# Train step 25, loss = 1.6868, acc = 0.4305; train time = 45.6543 seconds
# Test loss = 1.7693, acc = 0.3906; test time = 3.6891 seconds
# Total time = 49.3435 seconds
# Train step 26, loss = 1.6842, acc = 0.4302; train time = 45.7374 seconds
# Test loss = 1.7590, acc = 0.3924; test time = 3.6576 seconds
# Total time = 49.3951 seconds
# Train step 27, loss = 1.6859, acc = 0.4269; train time = 45.7077 seconds
# Test loss = 1.7673, acc = 0.3884; test time = 3.7007 seconds
# Total time = 49.4092 seconds
# Train step 28, loss = 1.6859, acc = 0.4301; train time = 45.7482 seconds
# Test loss = 1.7644, acc = 0.3843; test time = 3.6892 seconds
# Total time = 49.4375 seconds
# Train step 29, loss = 1.6827, acc = 0.4305; train time = 45.7438 seconds
# Test loss = 1.7571, acc = 0.3920; test time = 3.6723 seconds
# Total time = 49.4167 seconds
# Train step 30, loss = 1.6854, acc = 0.4300; train time = 45.9348 seconds
# Test loss = 1.7598, acc = 0.3939; test time = 3.6696 seconds
# Total time = 49.6045 seconds
# Train step 31, loss = 1.6824, acc = 0.4315; train time = 45.6480 seconds
# Test loss = 1.7647, acc = 0.3848; test time = 3.6827 seconds
# Total time = 49.3308 seconds
# Train step 32, loss = 1.6769, acc = 0.4346; train time = 45.9142 seconds
# Test loss = 1.7780, acc = 0.3825; test time = 3.7782 seconds
# Total time = 49.6931 seconds
# Train step 33, loss = 1.6744, acc = 0.4329; train time = 45.8132 seconds
# Test loss = 1.7673, acc = 0.3898; test time = 3.7044 seconds
# Total time = 49.5177 seconds
# Train step 34, loss = 1.6776, acc = 0.4340; train time = 45.8366 seconds
# Test loss = 1.7698, acc = 0.3849; test time = 3.7396 seconds
# Total time = 49.5769 seconds
# Train step 35, loss = 1.6760, acc = 0.4328; train time = 45.7485 seconds
# Test loss = 1.7602, acc = 0.3923; test time = 3.6967 seconds
# Total time = 49.4453 seconds
# Train step 36, loss = 1.6723, acc = 0.4338; train time = 45.7587 seconds
# Test loss = 1.7620, acc = 0.3971; test time = 3.6975 seconds
# Total time = 49.4563 seconds
# Train step 37, loss = 1.6721, acc = 0.4334; train time = 45.7162 seconds
# Test loss = 1.7661, acc = 0.3874; test time = 3.6978 seconds
# Total time = 49.4141 seconds
# Train step 38, loss = 1.6687, acc = 0.4363; train time = 45.6800 seconds
# Test loss = 1.7665, acc = 0.3922; test time = 3.6725 seconds
# Total time = 49.3532 seconds
# Train step 39, loss = 1.6700, acc = 0.4349; train time = 45.6487 seconds
# Test loss = 1.7666, acc = 0.3882; test time = 3.6758 seconds
# Total time = 49.3245 seconds
# Train step 40, loss = 1.6705, acc = 0.4338; train time = 45.7300 seconds
# Test loss = 1.7627, acc = 0.3908; test time = 3.6358 seconds
# Total time = 49.3659 seconds
# Train step 41, loss = 1.6717, acc = 0.4358; train time = 45.6969 seconds
# Test loss = 1.7724, acc = 0.3875; test time = 3.6839 seconds
# Total time = 49.3812 seconds
# Train step 42, loss = 1.6685, acc = 0.4361; train time = 45.6347 seconds
# Test loss = 1.7730, acc = 0.3866; test time = 3.6907 seconds
# Total time = 49.3255 seconds
# Train step 43, loss = 1.6653, acc = 0.4379; train time = 45.8596 seconds
# Test loss = 1.7729, acc = 0.3772; test time = 3.6703 seconds
# Total time = 49.5300 seconds
# Train step 44, loss = 1.6638, acc = 0.4371; train time = 45.6702 seconds
# Test loss = 1.7573, acc = 0.3942; test time = 3.6662 seconds
# Total time = 49.3371 seconds
# Train step 45, loss = 1.6647, acc = 0.4365; train time = 45.6454 seconds
# Test loss = 1.7808, acc = 0.3821; test time = 3.6776 seconds
# Total time = 49.3232 seconds
# Train step 46, loss = 1.6642, acc = 0.4363; train time = 45.6406 seconds
# Test loss = 1.7699, acc = 0.3857; test time = 3.7069 seconds
# Total time = 49.3476 seconds
# Train step 47, loss = 1.6638, acc = 0.4359; train time = 45.7158 seconds
# Test loss = 1.7735, acc = 0.3876; test time = 3.6444 seconds
# Total time = 49.3604 seconds
# Train step 48, loss = 1.6662, acc = 0.4366; train time = 45.7250 seconds
# Test loss = 1.7749, acc = 0.3865; test time = 3.6202 seconds
# Total time = 49.3453 seconds
# Train step 49, loss = 1.6702, acc = 0.4352; train time = 45.7318 seconds
# Test loss = 1.7680, acc = 0.3868; test time = 3.6647 seconds
# Total time = 49.3967 seconds
# Train step 50, loss = 1.6638, acc = 0.4376; train time = 45.7279 seconds
# Test loss = 1.7749, acc = 0.3827; test time = 3.7227 seconds
# Total time = 49.4507 seconds
# Train step 51, loss = 1.6603, acc = 0.4383; train time = 45.7856 seconds
# Test loss = 1.7746, acc = 0.3839; test time = 3.6846 seconds
# Total time = 49.4703 seconds
# Train step 52, loss = 1.6644, acc = 0.4375; train time = 45.6423 seconds
# Test loss = 1.7718, acc = 0.3809; test time = 3.7028 seconds
# Total time = 49.3452 seconds
# Train step 53, loss = 1.6611, acc = 0.4384; train time = 45.6248 seconds
# Test loss = 1.7731, acc = 0.3868; test time = 3.6725 seconds
# Total time = 49.2980 seconds
# Train step 54, loss = 1.6619, acc = 0.4387; train time = 45.9330 seconds
# Test loss = 1.7775, acc = 0.3853; test time = 3.7047 seconds
# Total time = 49.6378 seconds
# Train step 55, loss = 1.6582, acc = 0.4391; train time = 45.7906 seconds
# Test loss = 1.7829, acc = 0.3814; test time = 3.9705 seconds
# Total time = 49.7618 seconds
# Train step 56, loss = 1.6576, acc = 0.4394; train time = 45.7109 seconds
# Test loss = 1.7642, acc = 0.3974; test time = 3.6940 seconds
# Total time = 49.4055 seconds
# Train step 57, loss = 1.6610, acc = 0.4366; train time = 45.6802 seconds
# Test loss = 1.7882, acc = 0.3797; test time = 3.6725 seconds
# Total time = 49.3535 seconds
# Train step 58, loss = 1.6612, acc = 0.4375; train time = 45.8175 seconds
# Test loss = 1.7770, acc = 0.3871; test time = 3.6855 seconds
# Total time = 49.5031 seconds
# Train step 59, loss = 1.6609, acc = 0.4382; train time = 45.8127 seconds
# Test loss = 1.7785, acc = 0.3817; test time = 3.7218 seconds
# Total time = 49.5346 seconds
# Train step 60, loss = 1.6608, acc = 0.4398; train time = 45.7690 seconds
# Test loss = 1.7828, acc = 0.3793; test time = 3.7139 seconds
# Total time = 49.4831 seconds
# Train step 61, loss = 1.6545, acc = 0.4415; train time = 45.6772 seconds
# Test loss = 1.7808, acc = 0.3821; test time = 3.6773 seconds
# Total time = 49.3551 seconds
# Train step 62, loss = 1.6534, acc = 0.4404; train time = 45.6183 seconds
# Test loss = 1.7741, acc = 0.3876; test time = 3.6670 seconds
# Total time = 49.2854 seconds
# Train step 63, loss = 1.6535, acc = 0.4422; train time = 45.7318 seconds
# Test loss = 1.7754, acc = 0.3858; test time = 3.6800 seconds
# Total time = 49.4127 seconds
# Train step 64, loss = 1.6547, acc = 0.4401; train time = 45.5589 seconds
# Test loss = 1.7877, acc = 0.3833; test time = 3.6332 seconds
# Total time = 49.1922 seconds
# Train step 65, loss = 1.6537, acc = 0.4420; train time = 45.6842 seconds
# Test loss = 1.7740, acc = 0.3870; test time = 3.6912 seconds
# Total time = 49.3761 seconds
# Train step 66, loss = 1.6577, acc = 0.4408; train time = 45.5916 seconds
# Test loss = 1.7879, acc = 0.3896; test time = 3.7199 seconds
# Total time = 49.3124 seconds
# Train step 67, loss = 1.6505, acc = 0.4421; train time = 45.7104 seconds
# Test loss = 1.7787, acc = 0.3857; test time = 3.6692 seconds
# Total time = 49.3797 seconds
# Train step 68, loss = 1.6508, acc = 0.4395; train time = 46.0158 seconds
# Test loss = 1.7755, acc = 0.3884; test time = 3.6571 seconds
# Total time = 49.6730 seconds
# Train step 69, loss = 1.6502, acc = 0.4416; train time = 45.7040 seconds
# Test loss = 1.7669, acc = 0.3892; test time = 3.6816 seconds
# Total time = 49.3857 seconds
# Train step 70, loss = 1.6516, acc = 0.4432; train time = 45.6485 seconds
# Test loss = 1.7701, acc = 0.3903; test time = 3.6680 seconds
# Total time = 49.3166 seconds
# Train step 71, loss = 1.6520, acc = 0.4405; train time = 45.6945 seconds
# Test loss = 1.7891, acc = 0.3796; test time = 3.6531 seconds
# Total time = 49.3477 seconds
# Train step 72, loss = 1.6519, acc = 0.4447; train time = 45.7273 seconds
# Test loss = 1.7637, acc = 0.3922; test time = 3.6537 seconds
# Total time = 49.3810 seconds
# Train step 73, loss = 1.6461, acc = 0.4438; train time = 45.6874 seconds
# Test loss = 1.7790, acc = 0.3842; test time = 3.7132 seconds
# Total time = 49.4013 seconds
# Train step 74, loss = 1.6487, acc = 0.4432; train time = 45.7355 seconds
# Test loss = 1.7750, acc = 0.3867; test time = 3.6753 seconds
# Total time = 49.4108 seconds
# Train step 75, loss = 1.6489, acc = 0.4438; train time = 45.7364 seconds
# Test loss = 1.7785, acc = 0.3828; test time = 3.7275 seconds
# Total time = 49.4640 seconds
# Train step 76, loss = 1.6488, acc = 0.4443; train time = 45.7922 seconds
# Test loss = 1.7793, acc = 0.3856; test time = 3.6808 seconds
# Total time = 49.4731 seconds
# Train step 77, loss = 1.6521, acc = 0.4419; train time = 45.7308 seconds
# Test loss = 1.7804, acc = 0.3849; test time = 3.6777 seconds
# Total time = 49.4086 seconds
# Train step 78, loss = 1.6487, acc = 0.4415; train time = 45.7878 seconds
# Test loss = 1.7783, acc = 0.3802; test time = 3.7076 seconds
# Total time = 49.4955 seconds
# Train step 79, loss = 1.6464, acc = 0.4454; train time = 45.6637 seconds
# Test loss = 1.7690, acc = 0.3939; test time = 3.6846 seconds
# Total time = 49.3484 seconds
# Train step 80, loss = 1.6491, acc = 0.4428; train time = 45.7311 seconds
# Test loss = 1.7782, acc = 0.3821; test time = 3.6517 seconds
# Total time = 49.3831 seconds
# Train step 81, loss = 1.6460, acc = 0.4445; train time = 45.9391 seconds
# Test loss = 1.7976, acc = 0.3750; test time = 3.7078 seconds
# Total time = 49.6470 seconds
# Train step 82, loss = 1.6428, acc = 0.4435; train time = 45.6757 seconds
# Test loss = 1.7818, acc = 0.3850; test time = 3.6783 seconds
# Total time = 49.3540 seconds
# Train step 83, loss = 1.6446, acc = 0.4426; train time = 45.7626 seconds
# Test loss = 1.7669, acc = 0.3882; test time = 3.6859 seconds
# Total time = 49.4485 seconds
# Train step 84, loss = 1.6442, acc = 0.4441; train time = 45.7754 seconds
# Test loss = 1.7774, acc = 0.3873; test time = 3.6831 seconds
# Total time = 49.4588 seconds
# Train step 85, loss = 1.6453, acc = 0.4456; train time = 45.6568 seconds
# Test loss = 1.8063, acc = 0.3726; test time = 3.6618 seconds
# Total time = 49.3187 seconds
# Train step 86, loss = 1.6410, acc = 0.4456; train time = 45.6434 seconds
# Test loss = 1.7897, acc = 0.3819; test time = 3.6608 seconds
# Total time = 49.3043 seconds
# Train step 87, loss = 1.6415, acc = 0.4441; train time = 45.7460 seconds
# Test loss = 1.7848, acc = 0.3868; test time = 3.6897 seconds
# Total time = 49.4358 seconds
# Train step 88, loss = 1.6426, acc = 0.4463; train time = 45.6747 seconds
# Test loss = 1.7757, acc = 0.3846; test time = 3.7060 seconds
# Total time = 49.3808 seconds
# Train step 89, loss = 1.6430, acc = 0.4443; train time = 45.6319 seconds
# Test loss = 1.7870, acc = 0.3845; test time = 3.7092 seconds
# Total time = 49.3412 seconds
# Train step 90, loss = 1.6414, acc = 0.4452; train time = 45.6435 seconds
# Test loss = 1.7744, acc = 0.3888; test time = 3.6825 seconds
# Total time = 49.3261 seconds
# Train step 91, loss = 1.6424, acc = 0.4467; train time = 45.7108 seconds
# Test loss = 1.7896, acc = 0.3855; test time = 3.7056 seconds
# Total time = 49.4165 seconds
# Train step 92, loss = 1.6412, acc = 0.4448; train time = 45.6559 seconds
# Test loss = 1.7846, acc = 0.3804; test time = 3.6738 seconds
# Total time = 49.3298 seconds
# Train step 93, loss = 1.6416, acc = 0.4447; train time = 45.9261 seconds
# Test loss = 1.7797, acc = 0.3835; test time = 3.6981 seconds
# Total time = 49.6244 seconds
# Train step 94, loss = 1.6427, acc = 0.4444; train time = 45.6783 seconds
# Test loss = 1.7852, acc = 0.3784; test time = 3.6585 seconds
# Total time = 49.3369 seconds
# Train step 95, loss = 1.6427, acc = 0.4458; train time = 45.7236 seconds
# Test loss = 1.7890, acc = 0.3834; test time = 3.6967 seconds
# Total time = 49.4205 seconds
# Train step 96, loss = 1.6352, acc = 0.4485; train time = 45.7026 seconds
# Test loss = 1.7784, acc = 0.3862; test time = 3.7013 seconds
# Total time = 49.4039 seconds
# Train step 97, loss = 1.6373, acc = 0.4475; train time = 45.7472 seconds
# Test loss = 1.7886, acc = 0.3879; test time = 3.7039 seconds
# Total time = 49.4513 seconds
# Train step 98, loss = 1.6361, acc = 0.4475; train time = 45.7414 seconds
# Test loss = 1.7855, acc = 0.3825; test time = 3.6931 seconds
# Total time = 49.4354 seconds
# Train step 99, loss = 1.6335, acc = 0.4475; train time = 45.7125 seconds
# Test loss = 1.7807, acc = 0.3885; test time = 3.7022 seconds
# Total time = 49.4148 seconds
# ____Training with replacement_lvl = 1____
# ----Training with repetatioin = 1----
# Files already downloaded and verified
# Files already downloaded and verified
# Train step 0, loss = 6.7291, acc = 0.2196; train time = 82.1683 seconds
# Test loss = 2.0074, acc = 0.3020; test time = 19.6733 seconds
# Total time = 101.8419 seconds
# Train step 1, loss = 1.9884, acc = 0.3058; train time = 45.1588 seconds
# Test loss = 1.9141, acc = 0.3331; test time = 3.5431 seconds
# Total time = 48.7020 seconds
# Train step 2, loss = 1.9282, acc = 0.3305; train time = 45.1269 seconds
# Test loss = 1.9373, acc = 0.3294; test time = 3.5488 seconds
# Total time = 48.6758 seconds
# Train step 3, loss = 1.9116, acc = 0.3392; train time = 45.0493 seconds
# Test loss = 1.9127, acc = 0.3125; test time = 3.5340 seconds
# Total time = 48.5834 seconds
# Train step 4, loss = 1.8564, acc = 0.3603; train time = 45.0362 seconds
# Test loss = 1.8707, acc = 0.3357; test time = 3.5945 seconds
# Total time = 48.6315 seconds
# Train step 5, loss = 1.8179, acc = 0.3753; train time = 45.3667 seconds
# Test loss = 1.8090, acc = 0.3789; test time = 3.5504 seconds
# Total time = 48.9177 seconds
# Train step 6, loss = 1.8132, acc = 0.3763; train time = 45.1015 seconds
# Test loss = 1.8039, acc = 0.3667; test time = 3.5712 seconds
# Total time = 48.6728 seconds
# Train step 7, loss = 1.7728, acc = 0.3937; train time = 45.0375 seconds
# Test loss = 1.8173, acc = 0.3636; test time = 3.5428 seconds
# Total time = 48.5804 seconds
# Train step 8, loss = 1.7748, acc = 0.3928; train time = 45.0307 seconds
# Test loss = 1.7921, acc = 0.3767; test time = 3.5165 seconds
# Total time = 48.5473 seconds
# Train step 9, loss = 1.7577, acc = 0.3998; train time = 45.0174 seconds
# Test loss = 1.7851, acc = 0.3727; test time = 3.5754 seconds
# Total time = 48.5930 seconds
# Train step 10, loss = 1.7457, acc = 0.4063; train time = 45.0362 seconds
# Test loss = 1.7921, acc = 0.3808; test time = 3.5326 seconds
# Total time = 48.5689 seconds
# Train step 11, loss = 1.7340, acc = 0.4087; train time = 45.0391 seconds
# Test loss = 1.7628, acc = 0.3886; test time = 3.5809 seconds
# Total time = 48.6202 seconds
# Train step 12, loss = 1.7216, acc = 0.4166; train time = 45.1190 seconds
# Test loss = 1.7496, acc = 0.3951; test time = 3.5768 seconds
# Total time = 48.6959 seconds
# Train step 13, loss = 1.7167, acc = 0.4194; train time = 45.0388 seconds
# Test loss = 1.7646, acc = 0.3824; test time = 3.5929 seconds
# Total time = 48.6318 seconds
# Train step 14, loss = 1.7086, acc = 0.4191; train time = 45.0588 seconds
# Test loss = 1.7559, acc = 0.3914; test time = 3.5827 seconds
# Total time = 48.6417 seconds
# Train step 15, loss = 1.7086, acc = 0.4205; train time = 44.9885 seconds
# Test loss = 1.7510, acc = 0.3913; test time = 3.5561 seconds
# Total time = 48.5447 seconds
# Train step 16, loss = 1.7035, acc = 0.4216; train time = 45.1560 seconds
# Test loss = 1.7468, acc = 0.3958; test time = 3.5800 seconds
# Total time = 48.7361 seconds
# Train step 17, loss = 1.6999, acc = 0.4258; train time = 45.1520 seconds
# Test loss = 1.7656, acc = 0.3923; test time = 3.5443 seconds
# Total time = 48.6963 seconds
# Train step 18, loss = 1.7032, acc = 0.4216; train time = 45.3800 seconds
# Test loss = 1.7559, acc = 0.3890; test time = 3.5807 seconds
# Total time = 48.9608 seconds
# Train step 19, loss = 1.6963, acc = 0.4263; train time = 45.2302 seconds
# Test loss = 1.7642, acc = 0.3875; test time = 3.5747 seconds
# Total time = 48.8051 seconds
# Train step 20, loss = 1.6962, acc = 0.4255; train time = 45.1153 seconds
# Test loss = 1.7480, acc = 0.3936; test time = 3.5494 seconds
# Total time = 48.6648 seconds
# Train step 21, loss = 1.6893, acc = 0.4302; train time = 45.1588 seconds
# Test loss = 1.7534, acc = 0.3926; test time = 3.5677 seconds
# Total time = 48.7267 seconds
# Train step 22, loss = 1.6909, acc = 0.4274; train time = 45.1599 seconds
# Test loss = 1.7649, acc = 0.3844; test time = 3.5867 seconds
# Total time = 48.7472 seconds
# Train step 23, loss = 1.6870, acc = 0.4286; train time = 45.1089 seconds
# Test loss = 1.7611, acc = 0.3908; test time = 3.5976 seconds
# Total time = 48.7067 seconds
# Train step 24, loss = 1.6851, acc = 0.4303; train time = 45.0004 seconds
# Test loss = 1.7609, acc = 0.3878; test time = 3.5729 seconds
# Total time = 48.5735 seconds
# Train step 25, loss = 1.6806, acc = 0.4301; train time = 45.0796 seconds
# Test loss = 1.7582, acc = 0.3874; test time = 3.5688 seconds
# Total time = 48.6484 seconds
# Train step 26, loss = 1.6861, acc = 0.4288; train time = 45.0338 seconds
# Test loss = 1.7598, acc = 0.3915; test time = 3.6241 seconds
# Total time = 48.6581 seconds
# Train step 27, loss = 1.6811, acc = 0.4337; train time = 45.0779 seconds
# Test loss = 1.7591, acc = 0.3894; test time = 3.5636 seconds
# Total time = 48.6416 seconds
# Train step 28, loss = 1.6768, acc = 0.4338; train time = 45.1155 seconds
# Test loss = 1.7761, acc = 0.3811; test time = 3.5751 seconds
# Total time = 48.6907 seconds
# Train step 29, loss = 1.6769, acc = 0.4337; train time = 45.0678 seconds
# Test loss = 1.7656, acc = 0.3866; test time = 3.5940 seconds
# Total time = 48.6624 seconds
# Train step 30, loss = 1.6750, acc = 0.4326; train time = 45.0894 seconds
# Test loss = 1.7756, acc = 0.3823; test time = 3.5710 seconds
# Total time = 48.6606 seconds
# Train step 31, loss = 1.6729, acc = 0.4329; train time = 45.2851 seconds
# Test loss = 1.7733, acc = 0.3876; test time = 3.5698 seconds
# Total time = 48.8557 seconds
# Train step 32, loss = 1.6735, acc = 0.4337; train time = 45.1492 seconds
# Test loss = 1.7615, acc = 0.3925; test time = 3.5627 seconds
# Total time = 48.7125 seconds
# Train step 33, loss = 1.6766, acc = 0.4333; train time = 45.1358 seconds
# Test loss = 1.7668, acc = 0.3914; test time = 3.5639 seconds
# Total time = 48.6998 seconds
# Train step 34, loss = 1.6695, acc = 0.4355; train time = 45.0674 seconds
# Test loss = 1.7704, acc = 0.3843; test time = 3.5478 seconds
# Total time = 48.6152 seconds
# Train step 35, loss = 1.6698, acc = 0.4360; train time = 45.1076 seconds
# Test loss = 1.7656, acc = 0.3888; test time = 3.5958 seconds
# Total time = 48.7035 seconds
# Train step 36, loss = 1.6668, acc = 0.4356; train time = 45.1586 seconds
# Test loss = 1.7696, acc = 0.3902; test time = 3.5858 seconds
# Total time = 48.7444 seconds
# Train step 37, loss = 1.6666, acc = 0.4379; train time = 45.0389 seconds
# Test loss = 1.7739, acc = 0.3809; test time = 3.5520 seconds
# Total time = 48.5916 seconds
# Train step 38, loss = 1.6639, acc = 0.4385; train time = 45.0679 seconds
# Test loss = 1.7760, acc = 0.3856; test time = 3.5816 seconds
# Total time = 48.6497 seconds
# Train step 39, loss = 1.6655, acc = 0.4377; train time = 45.0028 seconds
# Test loss = 1.7592, acc = 0.3870; test time = 3.5651 seconds
# Total time = 48.5681 seconds
# Train step 40, loss = 1.6664, acc = 0.4387; train time = 45.1366 seconds
# Test loss = 1.7704, acc = 0.3853; test time = 3.5665 seconds
# Total time = 48.7034 seconds
# Train step 41, loss = 1.6671, acc = 0.4374; train time = 45.0709 seconds
# Test loss = 1.7762, acc = 0.3827; test time = 3.5557 seconds
# Total time = 48.6267 seconds
# Train step 42, loss = 1.6641, acc = 0.4363; train time = 45.0910 seconds
# Test loss = 1.7629, acc = 0.3944; test time = 3.5525 seconds
# Total time = 48.6435 seconds
# Train step 43, loss = 1.6643, acc = 0.4392; train time = 45.0620 seconds
# Test loss = 1.7653, acc = 0.3913; test time = 3.7811 seconds
# Total time = 48.8432 seconds
# Train step 44, loss = 1.6611, acc = 0.4398; train time = 45.0861 seconds
# Test loss = 1.7677, acc = 0.3922; test time = 3.5381 seconds
# Total time = 48.6244 seconds
# Train step 45, loss = 1.6561, acc = 0.4411; train time = 45.0412 seconds
# Test loss = 1.7663, acc = 0.3843; test time = 3.5911 seconds
# Total time = 48.6324 seconds
# Train step 46, loss = 1.6563, acc = 0.4416; train time = 45.0788 seconds
# Test loss = 1.7610, acc = 0.3947; test time = 3.5580 seconds
# Total time = 48.6369 seconds
# Train step 47, loss = 1.6552, acc = 0.4425; train time = 45.0418 seconds
# Test loss = 1.7695, acc = 0.3901; test time = 3.5687 seconds
# Total time = 48.6105 seconds
# Train step 48, loss = 1.6549, acc = 0.4403; train time = 45.1383 seconds
# Test loss = 1.7590, acc = 0.3954; test time = 3.5713 seconds
# Total time = 48.7098 seconds
# Train step 49, loss = 1.6528, acc = 0.4440; train time = 45.1399 seconds
# Test loss = 1.7651, acc = 0.3907; test time = 3.5634 seconds
# Total time = 48.7035 seconds
# Train step 50, loss = 1.6552, acc = 0.4417; train time = 45.0945 seconds
# Test loss = 1.7774, acc = 0.3855; test time = 3.5534 seconds
# Total time = 48.6480 seconds
# Train step 51, loss = 1.6522, acc = 0.4415; train time = 45.1185 seconds
# Test loss = 1.7849, acc = 0.3796; test time = 3.5678 seconds
# Total time = 48.6864 seconds
# Train step 52, loss = 1.6563, acc = 0.4413; train time = 45.1340 seconds
# Test loss = 1.7719, acc = 0.3893; test time = 3.5582 seconds
# Total time = 48.6924 seconds
# Train step 53, loss = 1.6509, acc = 0.4427; train time = 45.0016 seconds
# Test loss = 1.7648, acc = 0.3922; test time = 3.5667 seconds
# Total time = 48.5684 seconds
# Train step 54, loss = 1.6540, acc = 0.4430; train time = 45.1070 seconds
# Test loss = 1.7660, acc = 0.3899; test time = 3.5624 seconds
# Total time = 48.6695 seconds
# Train step 55, loss = 1.6521, acc = 0.4417; train time = 45.0371 seconds
# Test loss = 1.7668, acc = 0.3854; test time = 3.5513 seconds
# Total time = 48.5885 seconds
# Train step 56, loss = 1.6541, acc = 0.4402; train time = 45.3680 seconds
# Test loss = 1.7638, acc = 0.3924; test time = 3.5549 seconds
# Total time = 48.9230 seconds
# Train step 57, loss = 1.6489, acc = 0.4430; train time = 45.0613 seconds
# Test loss = 1.7779, acc = 0.3869; test time = 3.6026 seconds
# Total time = 48.6642 seconds
# Train step 58, loss = 1.6452, acc = 0.4447; train time = 45.1369 seconds
# Test loss = 1.7757, acc = 0.3858; test time = 3.5580 seconds
# Total time = 48.6958 seconds
# Train step 59, loss = 1.6484, acc = 0.4414; train time = 45.0691 seconds
# Test loss = 1.7627, acc = 0.3941; test time = 3.5649 seconds
# Total time = 48.6340 seconds
# Train step 60, loss = 1.6458, acc = 0.4449; train time = 45.1341 seconds
# Test loss = 1.7665, acc = 0.3918; test time = 3.5848 seconds
# Total time = 48.7190 seconds
# Train step 61, loss = 1.6475, acc = 0.4426; train time = 45.1837 seconds
# Test loss = 1.7807, acc = 0.3851; test time = 3.5753 seconds
# Total time = 48.7591 seconds
# Train step 62, loss = 1.6439, acc = 0.4439; train time = 45.1392 seconds
# Test loss = 1.7786, acc = 0.3943; test time = 3.5810 seconds
# Total time = 48.7203 seconds
# Train step 63, loss = 1.6530, acc = 0.4410; train time = 45.0612 seconds
# Test loss = 1.7742, acc = 0.3904; test time = 3.5408 seconds
# Total time = 48.6022 seconds
# Train step 64, loss = 1.6432, acc = 0.4458; train time = 45.0925 seconds
# Test loss = 1.7676, acc = 0.3910; test time = 3.5656 seconds
# Total time = 48.6582 seconds
# Train step 65, loss = 1.6404, acc = 0.4449; train time = 45.1124 seconds
# Test loss = 1.7759, acc = 0.3861; test time = 3.6226 seconds
# Total time = 48.7352 seconds
# Train step 66, loss = 1.6459, acc = 0.4426; train time = 45.1455 seconds
# Test loss = 1.7800, acc = 0.3875; test time = 3.5538 seconds
# Total time = 48.7001 seconds
# Train step 67, loss = 1.6495, acc = 0.4440; train time = 45.0917 seconds
# Test loss = 1.7689, acc = 0.3874; test time = 3.5438 seconds
# Total time = 48.6356 seconds
# Train step 68, loss = 1.6417, acc = 0.4462; train time = 45.1014 seconds
# Test loss = 1.7887, acc = 0.3842; test time = 3.5812 seconds
# Total time = 48.6831 seconds
# Train step 69, loss = 1.6399, acc = 0.4474; train time = 45.3510 seconds
# Test loss = 1.7668, acc = 0.3926; test time = 3.5486 seconds
# Total time = 48.9003 seconds
# Train step 70, loss = 1.6400, acc = 0.4456; train time = 45.1115 seconds
# Test loss = 1.7744, acc = 0.3918; test time = 3.5655 seconds
# Total time = 48.6770 seconds
# Train step 71, loss = 1.6414, acc = 0.4460; train time = 45.2598 seconds
# Test loss = 1.7698, acc = 0.3921; test time = 3.5698 seconds
# Total time = 48.8296 seconds
# Train step 72, loss = 1.6376, acc = 0.4461; train time = 45.2787 seconds
# Test loss = 1.7711, acc = 0.3951; test time = 3.6042 seconds
# Total time = 48.8830 seconds
# Train step 73, loss = 1.6345, acc = 0.4477; train time = 45.1483 seconds
# Test loss = 1.7694, acc = 0.3936; test time = 3.5925 seconds
# Total time = 48.7414 seconds
# Train step 74, loss = 1.6363, acc = 0.4468; train time = 45.0577 seconds
# Test loss = 1.7800, acc = 0.3875; test time = 3.5709 seconds
# Total time = 48.6288 seconds
# Train step 75, loss = 1.6372, acc = 0.4473; train time = 45.1288 seconds
# Test loss = 1.7781, acc = 0.3905; test time = 3.5762 seconds
# Total time = 48.7052 seconds
# Train step 76, loss = 1.6355, acc = 0.4472; train time = 45.0401 seconds
# Test loss = 1.7800, acc = 0.3860; test time = 3.5928 seconds
# Total time = 48.6337 seconds
# Train step 77, loss = 1.6372, acc = 0.4464; train time = 45.1004 seconds
# Test loss = 1.7863, acc = 0.3869; test time = 3.5471 seconds
# Total time = 48.6476 seconds
# Train step 78, loss = 1.6356, acc = 0.4494; train time = 45.0733 seconds
# Test loss = 1.7685, acc = 0.3893; test time = 3.5652 seconds
# Total time = 48.6392 seconds
# Train step 79, loss = 1.6384, acc = 0.4480; train time = 45.0732 seconds
# Test loss = 1.7805, acc = 0.3804; test time = 3.5405 seconds
# Total time = 48.6138 seconds
# Train step 80, loss = 1.6364, acc = 0.4484; train time = 45.0808 seconds
# Test loss = 1.7817, acc = 0.3826; test time = 3.5983 seconds
# Total time = 48.6792 seconds
# Train step 81, loss = 1.6349, acc = 0.4493; train time = 45.0731 seconds
# Test loss = 1.7834, acc = 0.3887; test time = 3.8026 seconds
# Total time = 48.8758 seconds
# Train step 82, loss = 1.6354, acc = 0.4483; train time = 45.1207 seconds
# Test loss = 1.7844, acc = 0.3823; test time = 3.5311 seconds
# Total time = 48.6519 seconds
# Train step 83, loss = 1.6319, acc = 0.4483; train time = 45.2438 seconds
# Test loss = 1.7753, acc = 0.3849; test time = 3.5798 seconds
# Total time = 48.8237 seconds
# Train step 84, loss = 1.6317, acc = 0.4484; train time = 45.2181 seconds
# Test loss = 1.7868, acc = 0.3904; test time = 3.5842 seconds
# Total time = 48.8024 seconds
# Train step 85, loss = 1.6332, acc = 0.4463; train time = 45.0832 seconds
# Test loss = 1.7890, acc = 0.3839; test time = 3.6013 seconds
# Total time = 48.6848 seconds
# Train step 86, loss = 1.6342, acc = 0.4471; train time = 45.4052 seconds
# Test loss = 1.7778, acc = 0.3915; test time = 3.5979 seconds
# Total time = 49.0033 seconds
# Train step 87, loss = 1.6326, acc = 0.4479; train time = 45.2459 seconds
# Test loss = 1.7957, acc = 0.3835; test time = 3.5875 seconds
# Total time = 48.8335 seconds
# Train step 88, loss = 1.6288, acc = 0.4495; train time = 45.1415 seconds
# Test loss = 1.7937, acc = 0.3816; test time = 3.5813 seconds
# Total time = 48.7229 seconds
# Train step 89, loss = 1.6354, acc = 0.4503; train time = 45.2372 seconds
# Test loss = 1.7937, acc = 0.3838; test time = 3.6035 seconds
# Total time = 48.8408 seconds
# Train step 90, loss = 1.6342, acc = 0.4477; train time = 45.1497 seconds
# Test loss = 1.7857, acc = 0.3837; test time = 3.5523 seconds
# Total time = 48.7021 seconds
# Train step 91, loss = 1.6315, acc = 0.4477; train time = 45.2632 seconds
# Test loss = 1.7787, acc = 0.3827; test time = 3.5979 seconds
# Total time = 48.8612 seconds
# Train step 92, loss = 1.6290, acc = 0.4491; train time = 45.2101 seconds
# Test loss = 1.7726, acc = 0.3911; test time = 3.6097 seconds
# Total time = 48.8199 seconds
# Train step 93, loss = 1.6246, acc = 0.4513; train time = 45.1944 seconds
# Test loss = 1.7866, acc = 0.3736; test time = 3.5682 seconds
# Total time = 48.7629 seconds
# Train step 94, loss = 1.6265, acc = 0.4511; train time = 45.4285 seconds
# Test loss = 1.7842, acc = 0.3841; test time = 3.5816 seconds
# Total time = 49.0102 seconds
# Train step 95, loss = 1.6298, acc = 0.4497; train time = 45.2379 seconds
# Test loss = 1.7821, acc = 0.3834; test time = 3.5901 seconds
# Total time = 48.8287 seconds
# Train step 96, loss = 1.6274, acc = 0.4503; train time = 45.1543 seconds
# Test loss = 1.7888, acc = 0.3850; test time = 3.5762 seconds
# Total time = 48.7306 seconds
# Train step 97, loss = 1.6271, acc = 0.4498; train time = 45.1439 seconds
# Test loss = 1.7856, acc = 0.3808; test time = 3.5820 seconds
# Total time = 48.7266 seconds
# Train step 98, loss = 1.6275, acc = 0.4501; train time = 45.2102 seconds
# Test loss = 1.7739, acc = 0.3927; test time = 3.5795 seconds
# Total time = 48.7897 seconds
# Train step 99, loss = 1.6278, acc = 0.4506; train time = 45.0542 seconds
# Test loss = 1.7780, acc = 0.3887; test time = 3.5639 seconds
# Total time = 48.6187 seconds
# ____Training with replacement_lvl = 1____
# ----Training with repetatioin = 2----
# Files already downloaded and verified
# Files already downloaded and verified
# Train step 0, loss = 17.5504, acc = 0.1939; train time = 82.0218 seconds
# Test loss = 2.0663, acc = 0.2629; test time = 19.5322 seconds
# Total time = 101.5543 seconds
# Train step 1, loss = 2.0410, acc = 0.2868; train time = 43.8621 seconds
# Test loss = 2.0309, acc = 0.2793; test time = 3.3206 seconds
# Total time = 47.1833 seconds
# Train step 2, loss = 2.0102, acc = 0.2992; train time = 43.8056 seconds
# Test loss = 1.9815, acc = 0.2961; test time = 3.2912 seconds
# Total time = 47.0969 seconds
# Train step 3, loss = 1.9576, acc = 0.3190; train time = 43.8097 seconds
# Test loss = 1.8746, acc = 0.3418; test time = 3.3243 seconds
# Total time = 47.1341 seconds
# Train step 4, loss = 1.9078, acc = 0.3421; train time = 43.7630 seconds
# Test loss = 1.8858, acc = 0.3333; test time = 3.3458 seconds
# Total time = 47.1089 seconds
# Train step 5, loss = 1.8980, acc = 0.3450; train time = 43.9314 seconds
# Test loss = 1.8895, acc = 0.3383; test time = 3.3041 seconds
# Total time = 47.2356 seconds
# Train step 6, loss = 1.8770, acc = 0.3539; train time = 44.0590 seconds
# Test loss = 1.8591, acc = 0.3411; test time = 3.3359 seconds
# Total time = 47.3950 seconds
# Train step 7, loss = 1.8414, acc = 0.3685; train time = 43.9003 seconds
# Test loss = 1.8277, acc = 0.3610; test time = 3.3699 seconds
# Total time = 47.2703 seconds
# Train step 8, loss = 1.8240, acc = 0.3712; train time = 43.8891 seconds
# Test loss = 1.8310, acc = 0.3611; test time = 3.3039 seconds
# Total time = 47.1932 seconds
# Train step 9, loss = 1.7950, acc = 0.3845; train time = 43.8750 seconds
# Test loss = 1.8292, acc = 0.3500; test time = 3.3145 seconds
# Total time = 47.1896 seconds
# Train step 10, loss = 1.8021, acc = 0.3821; train time = 43.8459 seconds
# Test loss = 1.8236, acc = 0.3612; test time = 3.3097 seconds
# Total time = 47.1559 seconds
# Train step 11, loss = 1.7994, acc = 0.3849; train time = 43.7983 seconds
# Test loss = 1.8453, acc = 0.3572; test time = 3.3229 seconds
# Total time = 47.1221 seconds
# Train step 12, loss = 1.7686, acc = 0.3950; train time = 43.7341 seconds
# Test loss = 1.8378, acc = 0.3575; test time = 3.3128 seconds
# Total time = 47.0471 seconds
# Train step 13, loss = 1.7716, acc = 0.3982; train time = 43.8290 seconds
# Test loss = 1.7743, acc = 0.3798; test time = 3.2840 seconds
# Total time = 47.1130 seconds
# Train step 14, loss = 1.7602, acc = 0.4013; train time = 43.8320 seconds
# Test loss = 1.7798, acc = 0.3783; test time = 3.3030 seconds
# Total time = 47.1351 seconds
# Train step 15, loss = 1.7546, acc = 0.3995; train time = 43.8452 seconds
# Test loss = 1.7744, acc = 0.3757; test time = 3.2957 seconds
# Total time = 47.1413 seconds
# Train step 16, loss = 1.7458, acc = 0.4048; train time = 43.7836 seconds
# Test loss = 1.7831, acc = 0.3819; test time = 3.2933 seconds
# Total time = 47.0770 seconds
# Train step 17, loss = 1.7354, acc = 0.4096; train time = 43.9312 seconds
# Test loss = 1.7783, acc = 0.3840; test time = 3.3022 seconds
# Total time = 47.2335 seconds
# Train step 18, loss = 1.7320, acc = 0.4112; train time = 43.8447 seconds
# Test loss = 1.7846, acc = 0.3771; test time = 3.2824 seconds
# Total time = 47.1272 seconds
# Train step 19, loss = 1.7281, acc = 0.4140; train time = 44.2070 seconds
# Test loss = 1.7532, acc = 0.3925; test time = 3.3191 seconds
# Total time = 47.5261 seconds
# Train step 20, loss = 1.7262, acc = 0.4140; train time = 43.9036 seconds
# Test loss = 1.7564, acc = 0.3939; test time = 3.2929 seconds
# Total time = 47.1967 seconds
# Train step 21, loss = 1.7102, acc = 0.4189; train time = 43.8335 seconds
# Test loss = 1.7687, acc = 0.3834; test time = 3.3111 seconds
# Total time = 47.1448 seconds
# Train step 22, loss = 1.7085, acc = 0.4211; train time = 43.8014 seconds
# Test loss = 1.7777, acc = 0.3847; test time = 3.2871 seconds
# Total time = 47.0891 seconds
# Train step 23, loss = 1.7025, acc = 0.4227; train time = 43.8354 seconds
# Test loss = 1.7621, acc = 0.3929; test time = 3.3475 seconds
# Total time = 47.1830 seconds
# Train step 24, loss = 1.6977, acc = 0.4256; train time = 43.8458 seconds
# Test loss = 1.7647, acc = 0.3920; test time = 3.3558 seconds
# Total time = 47.2017 seconds
# Train step 25, loss = 1.7038, acc = 0.4236; train time = 43.8751 seconds
# Test loss = 1.7545, acc = 0.3933; test time = 3.2810 seconds
# Total time = 47.1562 seconds
# Train step 26, loss = 1.6927, acc = 0.4249; train time = 43.7356 seconds
# Test loss = 1.7461, acc = 0.3910; test time = 3.3085 seconds
# Total time = 47.0443 seconds
# Train step 27, loss = 1.6875, acc = 0.4301; train time = 43.7733 seconds
# Test loss = 1.7627, acc = 0.3922; test time = 3.2861 seconds
# Total time = 47.0596 seconds
# Train step 28, loss = 1.6914, acc = 0.4283; train time = 43.9470 seconds
# Test loss = 1.7450, acc = 0.3989; test time = 3.3738 seconds
# Total time = 47.3209 seconds
# Train step 29, loss = 1.6851, acc = 0.4305; train time = 43.9478 seconds
# Test loss = 1.7478, acc = 0.3942; test time = 3.3177 seconds
# Total time = 47.2661 seconds
# Train step 30, loss = 1.6806, acc = 0.4328; train time = 43.8132 seconds
# Test loss = 1.7676, acc = 0.3905; test time = 3.3129 seconds
# Total time = 47.1262 seconds
# Train step 31, loss = 1.6844, acc = 0.4306; train time = 43.7434 seconds
# Test loss = 1.7628, acc = 0.3923; test time = 3.3325 seconds
# Total time = 47.0760 seconds
# Train step 32, loss = 1.6807, acc = 0.4295; train time = 44.0819 seconds
# Test loss = 1.7620, acc = 0.3901; test time = 3.3083 seconds
# Total time = 47.3903 seconds
# Train step 33, loss = 1.6792, acc = 0.4325; train time = 43.8046 seconds
# Test loss = 1.7598, acc = 0.3924; test time = 3.2462 seconds
# Total time = 47.0509 seconds
# Train step 34, loss = 1.6787, acc = 0.4319; train time = 43.8978 seconds
# Test loss = 1.7586, acc = 0.3949; test time = 3.2712 seconds
# Total time = 47.1691 seconds
# Train step 35, loss = 1.6732, acc = 0.4343; train time = 43.8049 seconds
# Test loss = 1.7666, acc = 0.3890; test time = 3.2900 seconds
# Total time = 47.0949 seconds
# Train step 36, loss = 1.6800, acc = 0.4307; train time = 43.8654 seconds
# Test loss = 1.7581, acc = 0.3958; test time = 3.3013 seconds
# Total time = 47.1672 seconds
# Train step 37, loss = 1.6731, acc = 0.4341; train time = 43.6926 seconds
# Test loss = 1.7598, acc = 0.3894; test time = 3.2916 seconds
# Total time = 46.9843 seconds
# Train step 38, loss = 1.6753, acc = 0.4319; train time = 43.8230 seconds
# Test loss = 1.7735, acc = 0.3886; test time = 3.2688 seconds
# Total time = 47.0920 seconds
# Train step 39, loss = 1.6732, acc = 0.4329; train time = 43.7936 seconds
# Test loss = 1.7698, acc = 0.3837; test time = 3.2999 seconds
# Total time = 47.0942 seconds
# Train step 40, loss = 1.6669, acc = 0.4377; train time = 43.8059 seconds
# Test loss = 1.7648, acc = 0.3852; test time = 3.2906 seconds
# Total time = 47.0965 seconds
# Train step 41, loss = 1.6765, acc = 0.4318; train time = 43.7726 seconds
# Test loss = 1.7605, acc = 0.3941; test time = 3.2843 seconds
# Total time = 47.0570 seconds
# Train step 42, loss = 1.6665, acc = 0.4360; train time = 43.8037 seconds
# Test loss = 1.7766, acc = 0.3832; test time = 3.3392 seconds
# Total time = 47.1429 seconds
# Train step 43, loss = 1.6688, acc = 0.4358; train time = 43.7984 seconds
# Test loss = 1.7647, acc = 0.3896; test time = 3.2945 seconds
# Total time = 47.0929 seconds
# Train step 44, loss = 1.6690, acc = 0.4352; train time = 43.7775 seconds
# Test loss = 1.7583, acc = 0.3975; test time = 3.2896 seconds
# Total time = 47.0672 seconds
# Train step 45, loss = 1.6609, acc = 0.4396; train time = 43.9937 seconds
# Test loss = 1.7594, acc = 0.3882; test time = 3.3415 seconds
# Total time = 47.3359 seconds
# Train step 46, loss = 1.6677, acc = 0.4344; train time = 43.7940 seconds
# Test loss = 1.7617, acc = 0.3868; test time = 3.3136 seconds
# Total time = 47.1077 seconds
# Train step 47, loss = 1.6650, acc = 0.4382; train time = 43.7458 seconds
# Test loss = 1.7622, acc = 0.3917; test time = 3.3309 seconds
# Total time = 47.0768 seconds
# Train step 48, loss = 1.6647, acc = 0.4364; train time = 43.7452 seconds
# Test loss = 1.7647, acc = 0.3917; test time = 3.3460 seconds
# Total time = 47.0913 seconds
# Train step 49, loss = 1.6605, acc = 0.4396; train time = 43.8032 seconds
# Test loss = 1.7780, acc = 0.3871; test time = 3.2639 seconds
# Total time = 47.0672 seconds
# Train step 50, loss = 1.6658, acc = 0.4380; train time = 43.8250 seconds
# Test loss = 1.7764, acc = 0.3839; test time = 3.3388 seconds
# Total time = 47.1640 seconds
# Train step 51, loss = 1.6627, acc = 0.4420; train time = 43.8076 seconds
# Test loss = 1.7693, acc = 0.3850; test time = 3.3076 seconds
# Total time = 47.1154 seconds
# Train step 52, loss = 1.6600, acc = 0.4398; train time = 43.8060 seconds
# Test loss = 1.7782, acc = 0.3890; test time = 3.3177 seconds
# Total time = 47.1239 seconds
# Train step 53, loss = 1.6586, acc = 0.4400; train time = 43.7551 seconds
# Test loss = 1.7728, acc = 0.3856; test time = 3.2990 seconds
# Total time = 47.0543 seconds
# Train step 54, loss = 1.6598, acc = 0.4406; train time = 43.8686 seconds
# Test loss = 1.7732, acc = 0.3852; test time = 3.3071 seconds
# Total time = 47.1758 seconds
# Train step 55, loss = 1.6585, acc = 0.4423; train time = 43.8270 seconds
# Test loss = 1.7790, acc = 0.3859; test time = 3.2864 seconds
# Total time = 47.1135 seconds
# Train step 56, loss = 1.6609, acc = 0.4383; train time = 43.8573 seconds
# Test loss = 1.7710, acc = 0.3836; test time = 3.3101 seconds
# Total time = 47.1675 seconds
# Train step 57, loss = 1.6562, acc = 0.4398; train time = 43.8037 seconds
# Test loss = 1.7925, acc = 0.3781; test time = 3.2974 seconds
# Total time = 47.1012 seconds
# Train step 58, loss = 1.6605, acc = 0.4391; train time = 44.0494 seconds
# Test loss = 1.8105, acc = 0.3717; test time = 3.3120 seconds
# Total time = 47.3620 seconds
# Train step 59, loss = 1.6540, acc = 0.4423; train time = 43.8675 seconds
# Test loss = 1.7638, acc = 0.3901; test time = 3.3333 seconds
# Total time = 47.2009 seconds
# Train step 60, loss = 1.6543, acc = 0.4413; train time = 43.8635 seconds
# Test loss = 1.7767, acc = 0.3815; test time = 3.3056 seconds
# Total time = 47.1692 seconds
# Train step 61, loss = 1.6528, acc = 0.4420; train time = 43.7877 seconds
# Test loss = 1.7656, acc = 0.3924; test time = 3.2955 seconds
# Total time = 47.0834 seconds
# Train step 62, loss = 1.6533, acc = 0.4420; train time = 43.8082 seconds
# Test loss = 1.7713, acc = 0.3891; test time = 3.3639 seconds
# Total time = 47.1723 seconds
# Train step 63, loss = 1.6521, acc = 0.4419; train time = 43.7029 seconds
# Test loss = 1.7663, acc = 0.3905; test time = 3.3038 seconds
# Total time = 47.0069 seconds
# Train step 64, loss = 1.6499, acc = 0.4446; train time = 43.8615 seconds
# Test loss = 1.7736, acc = 0.3840; test time = 3.3389 seconds
# Total time = 47.2013 seconds
# Train step 65, loss = 1.6559, acc = 0.4422; train time = 43.9459 seconds
# Test loss = 1.7714, acc = 0.3858; test time = 3.3703 seconds
# Total time = 47.3164 seconds
# Train step 66, loss = 1.6515, acc = 0.4430; train time = 43.8585 seconds
# Test loss = 1.7666, acc = 0.3918; test time = 3.3237 seconds
# Total time = 47.1824 seconds
# Train step 67, loss = 1.6505, acc = 0.4429; train time = 43.7965 seconds
# Test loss = 1.7755, acc = 0.3872; test time = 3.3424 seconds
# Total time = 47.1390 seconds
# Train step 68, loss = 1.6502, acc = 0.4423; train time = 43.8484 seconds
# Test loss = 1.7709, acc = 0.3913; test time = 3.2848 seconds
# Total time = 47.1339 seconds
# Train step 69, loss = 1.6505, acc = 0.4432; train time = 43.8496 seconds
# Test loss = 1.7846, acc = 0.3846; test time = 3.3132 seconds
# Total time = 47.1629 seconds
# Train step 70, loss = 1.6494, acc = 0.4422; train time = 44.0591 seconds
# Test loss = 1.7856, acc = 0.3782; test time = 3.5890 seconds
# Total time = 47.6488 seconds
# Train step 71, loss = 1.6483, acc = 0.4440; train time = 43.9235 seconds
# Test loss = 1.7802, acc = 0.3798; test time = 3.3030 seconds
# Total time = 47.2266 seconds
# Train step 72, loss = 1.6473, acc = 0.4440; train time = 43.8594 seconds
# Test loss = 1.7919, acc = 0.3832; test time = 3.2620 seconds
# Total time = 47.1215 seconds
# Train step 73, loss = 1.6475, acc = 0.4428; train time = 43.7435 seconds
# Test loss = 1.7690, acc = 0.3918; test time = 3.3170 seconds
# Total time = 47.0606 seconds
# Train step 74, loss = 1.6455, acc = 0.4439; train time = 43.7937 seconds
# Test loss = 1.7762, acc = 0.3902; test time = 3.2984 seconds
# Total time = 47.0927 seconds
# Train step 75, loss = 1.6428, acc = 0.4458; train time = 43.8880 seconds
# Test loss = 1.7621, acc = 0.3947; test time = 3.2934 seconds
# Total time = 47.1815 seconds
# Train step 76, loss = 1.6451, acc = 0.4432; train time = 43.8563 seconds
# Test loss = 1.7942, acc = 0.3745; test time = 3.3297 seconds
# Total time = 47.1861 seconds
# Train step 77, loss = 1.6457, acc = 0.4443; train time = 43.8227 seconds
# Test loss = 1.7712, acc = 0.3910; test time = 3.3101 seconds
# Total time = 47.1329 seconds
# Train step 78, loss = 1.6406, acc = 0.4450; train time = 43.8041 seconds
# Test loss = 1.7696, acc = 0.3902; test time = 3.3092 seconds
# Total time = 47.1133 seconds
# Train step 79, loss = 1.6419, acc = 0.4464; train time = 43.8410 seconds
# Test loss = 1.7732, acc = 0.3889; test time = 3.3375 seconds
# Total time = 47.1786 seconds
# Train step 80, loss = 1.6447, acc = 0.4456; train time = 43.7899 seconds
# Test loss = 1.7841, acc = 0.3843; test time = 3.3090 seconds
# Total time = 47.0990 seconds
# Train step 81, loss = 1.6393, acc = 0.4458; train time = 43.7594 seconds
# Test loss = 1.7803, acc = 0.3865; test time = 3.2905 seconds
# Total time = 47.0500 seconds
# Train step 82, loss = 1.6405, acc = 0.4458; train time = 43.8377 seconds
# Test loss = 1.7776, acc = 0.3864; test time = 3.3299 seconds
# Total time = 47.1677 seconds
# Train step 83, loss = 1.6437, acc = 0.4466; train time = 44.1467 seconds
# Test loss = 1.8051, acc = 0.3692; test time = 3.3313 seconds
# Total time = 47.4781 seconds
# Train step 84, loss = 1.6404, acc = 0.4469; train time = 43.9035 seconds
# Test loss = 1.7882, acc = 0.3797; test time = 3.3260 seconds
# Total time = 47.2297 seconds
# Train step 85, loss = 1.6409, acc = 0.4458; train time = 43.8153 seconds
# Test loss = 1.7945, acc = 0.3727; test time = 3.3034 seconds
# Total time = 47.1189 seconds
# Train step 86, loss = 1.6357, acc = 0.4490; train time = 43.7457 seconds
# Test loss = 1.7732, acc = 0.3896; test time = 3.2985 seconds
# Total time = 47.0443 seconds
# Train step 87, loss = 1.6397, acc = 0.4484; train time = 43.8336 seconds
# Test loss = 1.7990, acc = 0.3778; test time = 3.3224 seconds
# ...
# Total time = 69.2025 seconds
# Train step 2, loss = 2.2296, acc = 0.2273; train time = 64.4660 seconds
# Test loss = 2.2083, acc = 0.2760; test time = 4.8098 seconds
# Total time = 69.2759 seconds
# Train step 3, loss = 2.2091, acc = 0.3085; train time = 64.2479 seconds
# Test loss = 2.2042, acc = 0.3140; test time = 4.7814 seconds
# Total time = 69.0294 seconds
# Train step 4, loss = 2.2028, acc = 0.3252; train time = 64.4849 seconds
# Test loss = 2.2006, acc = 0.3234; test time = 4.8962 seconds
# Total time = 69.3814 seconds
# Train step 5, loss = 2.1983, acc = 0.3312; train time = 64.4312 seconds
# Test loss = 2.1930, acc = 0.3185; test time = 4.7962 seconds
# Total time = 69.2279 seconds
# Train step 6, loss = 2.1937, acc = 0.3349; train time = 64.3688 seconds
# Test loss = 2.1915, acc = 0.3280; test time = 4.8051 seconds
# Total time = 69.1740 seconds
# Train step 7, loss = 2.1913, acc = 0.3380; train time = 64.2843 seconds
# Test loss = 2.1870, acc = 0.3332; test time = 4.7954 seconds
# Total time = 69.0798 seconds
# Train step 8, loss = 2.1908, acc = 0.3387; train time = 64.2623 seconds
# Test loss = 2.1869, acc = 0.3326; test time = 4.8076 seconds
# Total time = 69.0701 seconds
# Train step 9, loss = 2.1895, acc = 0.3408; train time = 64.5409 seconds
# Test loss = 2.1874, acc = 0.3365; test time = 4.8141 seconds
# Total time = 69.3551 seconds
# Train step 10, loss = 2.1872, acc = 0.3457; train time = 64.2612 seconds
# Test loss = 2.1859, acc = 0.3379; test time = 4.8385 seconds
# Total time = 69.0998 seconds
# Train step 11, loss = 2.1864, acc = 0.3472; train time = 64.2823 seconds
# Test loss = 2.1812, acc = 0.3352; test time = 4.8265 seconds
# Total time = 69.1089 seconds
# Train step 12, loss = 2.1850, acc = 0.3476; train time = 64.2263 seconds
# Test loss = 2.1854, acc = 0.3361; test time = 4.8396 seconds
# Total time = 69.0660 seconds
# Train step 13, loss = 2.1851, acc = 0.3498; train time = 64.4967 seconds
# Test loss = 2.1812, acc = 0.3357; test time = 4.8606 seconds
# Total time = 69.3574 seconds
# Train step 14, loss = 2.1843, acc = 0.3511; train time = 64.4664 seconds
# Test loss = 2.1825, acc = 0.3447; test time = 4.7934 seconds
# Total time = 69.2604 seconds
# Train step 15, loss = 2.1829, acc = 0.3525; train time = 64.3432 seconds
# Test loss = 2.1784, acc = 0.3386; test time = 4.8077 seconds
# Total time = 69.1510 seconds
# Train step 16, loss = 2.1804, acc = 0.3530; train time = 64.2504 seconds
# Test loss = 2.1763, acc = 0.3469; test time = 4.8134 seconds
# Total time = 69.0639 seconds
# Train step 17, loss = 2.1811, acc = 0.3533; train time = 64.1778 seconds
# Test loss = 2.1775, acc = 0.3440; test time = 4.8091 seconds
# Total time = 68.9871 seconds
# Train step 18, loss = 2.1786, acc = 0.3533; train time = 64.3215 seconds
# Test loss = 2.1742, acc = 0.3503; test time = 4.8204 seconds
# Total time = 69.1420 seconds
# Train step 19, loss = 2.1795, acc = 0.3564; train time = 64.3213 seconds
# Test loss = 2.1769, acc = 0.3445; test time = 4.7873 seconds
# Total time = 69.1087 seconds
# Train step 20, loss = 2.1776, acc = 0.3566; train time = 64.2097 seconds
# Test loss = 2.1770, acc = 0.3483; test time = 4.7946 seconds
# Total time = 69.0046 seconds
# Train step 21, loss = 2.1792, acc = 0.3568; train time = 64.2349 seconds
# Test loss = 2.1746, acc = 0.3489; test time = 4.7770 seconds
# Total time = 69.0120 seconds
# Train step 22, loss = 2.1771, acc = 0.3582; train time = 64.2312 seconds
# Test loss = 2.1725, acc = 0.3461; test time = 4.7933 seconds
# Total time = 69.0246 seconds
# Train step 23, loss = 2.1757, acc = 0.3583; train time = 64.2258 seconds
# Test loss = 2.1742, acc = 0.3474; test time = 4.8535 seconds
# Total time = 69.0795 seconds
# Train step 24, loss = 2.1771, acc = 0.3601; train time = 64.4148 seconds
# Test loss = 2.1755, acc = 0.3475; test time = 4.8130 seconds
# Total time = 69.2279 seconds
# Train step 25, loss = 2.1760, acc = 0.3597; train time = 64.4197 seconds
# Test loss = 2.1729, acc = 0.3504; test time = 4.8428 seconds
# Total time = 69.2626 seconds
# Train step 26, loss = 2.1757, acc = 0.3610; train time = 64.3889 seconds
# Test loss = 2.1742, acc = 0.3512; test time = 4.7860 seconds
# Total time = 69.1750 seconds
# Train step 27, loss = 2.1746, acc = 0.3624; train time = 64.3093 seconds
# Test loss = 2.1703, acc = 0.3479; test time = 4.8337 seconds
# Total time = 69.1431 seconds
# Train step 28, loss = 2.1747, acc = 0.3625; train time = 64.2613 seconds
# Test loss = 2.1743, acc = 0.3458; test time = 4.8136 seconds
# Total time = 69.0751 seconds
# Train step 29, loss = 2.1747, acc = 0.3609; train time = 64.2268 seconds
# Test loss = 2.1717, acc = 0.3545; test time = 4.7896 seconds
# Total time = 69.0166 seconds
# Train step 30, loss = 2.1736, acc = 0.3633; train time = 64.1779 seconds
# Test loss = 2.1749, acc = 0.3461; test time = 4.7709 seconds
# Total time = 68.9488 seconds
# Train step 31, loss = 2.1721, acc = 0.3642; train time = 64.1892 seconds
# Test loss = 2.1707, acc = 0.3521; test time = 4.8117 seconds
# Total time = 69.0010 seconds
# Train step 32, loss = 2.1736, acc = 0.3649; train time = 64.3548 seconds
# Test loss = 2.1736, acc = 0.3528; test time = 4.7951 seconds
# Total time = 69.1500 seconds
# Train step 33, loss = 2.1729, acc = 0.3638; train time = 64.2049 seconds
# Test loss = 2.1701, acc = 0.3528; test time = 4.7862 seconds
# Total time = 68.9913 seconds
# Train step 34, loss = 2.1712, acc = 0.3654; train time = 64.3416 seconds
# Test loss = 2.1694, acc = 0.3576; test time = 4.8036 seconds
# Total time = 69.1452 seconds
# Train step 35, loss = 2.1711, acc = 0.3651; train time = 64.2702 seconds
# Test loss = 2.1682, acc = 0.3567; test time = 4.7850 seconds
# Total time = 69.0553 seconds
# Train step 36, loss = 2.1689, acc = 0.3666; train time = 64.2867 seconds
# Test loss = 2.1687, acc = 0.3574; test time = 4.7794 seconds
# Total time = 69.0662 seconds
# Train step 37, loss = 2.1698, acc = 0.3670; train time = 64.2395 seconds
# Test loss = 2.1709, acc = 0.3562; test time = 4.8468 seconds
# Total time = 69.0864 seconds
# Train step 38, loss = 2.1693, acc = 0.3673; train time = 64.2545 seconds
# Test loss = 2.1679, acc = 0.3602; test time = 4.8470 seconds
# Total time = 69.1017 seconds
# Train step 39, loss = 2.1702, acc = 0.3679; train time = 64.3603 seconds
# Test loss = 2.1696, acc = 0.3550; test time = 4.8008 seconds
# Total time = 69.1612 seconds
# Train step 40, loss = 2.1692, acc = 0.3678; train time = 64.3264 seconds
# Test loss = 2.1685, acc = 0.3599; test time = 4.8187 seconds
# Total time = 69.1453 seconds
# Train step 41, loss = 2.1685, acc = 0.3687; train time = 64.3629 seconds
# Test loss = 2.1656, acc = 0.3578; test time = 4.8367 seconds
# Total time = 69.1998 seconds
# Train step 42, loss = 2.1700, acc = 0.3700; train time = 67.3265 seconds
# Test loss = 2.1686, acc = 0.3624; test time = 4.8053 seconds
# Total time = 72.1324 seconds
# Train step 43, loss = 2.1685, acc = 0.3693; train time = 64.2653 seconds
# Test loss = 2.1657, acc = 0.3558; test time = 4.8320 seconds
# Total time = 69.0974 seconds
# Train step 44, loss = 2.1670, acc = 0.3705; train time = 64.3156 seconds
# Test loss = 2.1667, acc = 0.3617; test time = 4.8339 seconds
# Total time = 69.1496 seconds
# Train step 45, loss = 2.1673, acc = 0.3696; train time = 64.3188 seconds
# Test loss = 2.1648, acc = 0.3595; test time = 4.8421 seconds
# Total time = 69.1610 seconds
# Train step 46, loss = 2.1681, acc = 0.3696; train time = 64.3003 seconds
# Test loss = 2.1637, acc = 0.3588; test time = 4.7852 seconds
# Total time = 69.0862 seconds
# Train step 47, loss = 2.1665, acc = 0.3705; train time = 64.3977 seconds
# Test loss = 2.1655, acc = 0.3621; test time = 4.8404 seconds
# Total time = 69.2390 seconds
# Train step 48, loss = 2.1677, acc = 0.3723; train time = 64.3926 seconds
# Test loss = 2.1652, acc = 0.3615; test time = 4.8257 seconds
# Total time = 69.2184 seconds
# Train step 49, loss = 2.1654, acc = 0.3709; train time = 64.3719 seconds
# Test loss = 2.1638, acc = 0.3629; test time = 4.8257 seconds
# Total time = 69.1977 seconds
# Train step 50, loss = 2.1674, acc = 0.3718; train time = 64.5474 seconds
# Test loss = 2.1639, acc = 0.3615; test time = 4.9366 seconds
# Total time = 69.4840 seconds
# Train step 51, loss = 2.1651, acc = 0.3729; train time = 64.5226 seconds
# Test loss = 2.1644, acc = 0.3588; test time = 4.8342 seconds
# Total time = 69.3570 seconds
# Train step 52, loss = 2.1656, acc = 0.3738; train time = 64.6390 seconds
# Test loss = 2.1626, acc = 0.3618; test time = 4.8637 seconds
# Total time = 69.5028 seconds
# Train step 53, loss = 2.1662, acc = 0.3715; train time = 64.6513 seconds
# Test loss = 2.1646, acc = 0.3639; test time = 4.8435 seconds
# Total time = 69.4955 seconds
# Train step 54, loss = 2.1664, acc = 0.3722; train time = 64.5752 seconds
# Test loss = 2.1676, acc = 0.3659; test time = 4.8824 seconds
# Total time = 69.4577 seconds
# Train step 55, loss = 2.1656, acc = 0.3741; train time = 64.5810 seconds
# Test loss = 2.1654, acc = 0.3670; test time = 4.8457 seconds
# Total time = 69.4268 seconds
# Train step 56, loss = 2.1648, acc = 0.3761; train time = 64.4557 seconds
# Test loss = 2.1653, acc = 0.3570; test time = 4.9599 seconds
# Total time = 69.4156 seconds
# Train step 57, loss = 2.1646, acc = 0.3746; train time = 64.6005 seconds
# Test loss = 2.1630, acc = 0.3614; test time = 4.8323 seconds
# Total time = 69.4330 seconds
# Train step 58, loss = 2.1637, acc = 0.3754; train time = 64.4871 seconds
# Test loss = 2.1609, acc = 0.3632; test time = 4.8068 seconds
# Total time = 69.2939 seconds
# Train step 59, loss = 2.1643, acc = 0.3749; train time = 64.5227 seconds
# Test loss = 2.1629, acc = 0.3568; test time = 4.8387 seconds
# Total time = 69.3615 seconds
# Train step 60, loss = 2.1645, acc = 0.3748; train time = 64.4908 seconds
# Test loss = 2.1619, acc = 0.3626; test time = 4.8692 seconds
# Total time = 69.3603 seconds
# Train step 61, loss = 2.1636, acc = 0.3755; train time = 64.5653 seconds
# Test loss = 2.1648, acc = 0.3612; test time = 4.8298 seconds
# Total time = 69.3952 seconds
# Train step 62, loss = 2.1639, acc = 0.3770; train time = 64.4442 seconds
# Test loss = 2.1634, acc = 0.3658; test time = 4.8511 seconds
# Total time = 69.2955 seconds
# Train step 63, loss = 2.1639, acc = 0.3768; train time = 64.5112 seconds
# Test loss = 2.1615, acc = 0.3653; test time = 4.8255 seconds
# Total time = 69.3370 seconds
# Train step 64, loss = 2.1636, acc = 0.3762; train time = 64.4933 seconds
# Test loss = 2.1623, acc = 0.3684; test time = 4.9025 seconds
# Total time = 69.3960 seconds
# Train step 65, loss = 2.1638, acc = 0.3780; train time = 64.4334 seconds
# Test loss = 2.1634, acc = 0.3618; test time = 4.8825 seconds
# Total time = 69.3160 seconds
# Train step 66, loss = 2.1625, acc = 0.3774; train time = 64.4582 seconds
# Test loss = 2.1585, acc = 0.3681; test time = 4.8769 seconds
# Total time = 69.3352 seconds
# Train step 67, loss = 2.1627, acc = 0.3763; train time = 64.5154 seconds
# Test loss = 2.1596, acc = 0.3597; test time = 4.9448 seconds
# Total time = 69.4602 seconds
# Train step 68, loss = 2.1632, acc = 0.3770; train time = 64.5595 seconds
# Test loss = 2.1632, acc = 0.3698; test time = 4.9053 seconds
# Total time = 69.4650 seconds
# Train step 69, loss = 2.1623, acc = 0.3770; train time = 64.7011 seconds
# Test loss = 2.1617, acc = 0.3650; test time = 4.8335 seconds
# Total time = 69.5346 seconds
# Train step 70, loss = 2.1622, acc = 0.3776; train time = 64.6711 seconds
# Test loss = 2.1576, acc = 0.3681; test time = 4.8627 seconds
# Total time = 69.5339 seconds
# Train step 71, loss = 2.1605, acc = 0.3770; train time = 64.5860 seconds
# Test loss = 2.1633, acc = 0.3638; test time = 4.8532 seconds
# Total time = 69.4399 seconds
# Train step 72, loss = 2.1609, acc = 0.3767; train time = 64.4995 seconds
# Test loss = 2.1600, acc = 0.3692; test time = 4.8993 seconds
# Total time = 69.3995 seconds
# Train step 73, loss = 2.1618, acc = 0.3789; train time = 64.5862 seconds
# Test loss = 2.1618, acc = 0.3716; test time = 4.8835 seconds
# Total time = 69.4699 seconds
# Train step 74, loss = 2.1610, acc = 0.3791; train time = 64.5246 seconds
# Test loss = 2.1608, acc = 0.3663; test time = 4.8132 seconds
# Total time = 69.3379 seconds
# Train step 75, loss = 2.1611, acc = 0.3794; train time = 64.4790 seconds
# Test loss = 2.1581, acc = 0.3694; test time = 4.8045 seconds
# Total time = 69.2837 seconds
# Train step 76, loss = 2.1617, acc = 0.3803; train time = 64.3000 seconds
# Test loss = 2.1608, acc = 0.3701; test time = 4.8389 seconds
# Total time = 69.1390 seconds
# Train step 77, loss = 2.1614, acc = 0.3793; train time = 64.3273 seconds
# Test loss = 2.1605, acc = 0.3678; test time = 4.8174 seconds
# Total time = 69.1453 seconds
# Train step 78, loss = 2.1609, acc = 0.3798; train time = 64.3574 seconds
# Test loss = 2.1590, acc = 0.3698; test time = 4.8235 seconds
# Total time = 69.1810 seconds
# Train step 79, loss = 2.1603, acc = 0.3794; train time = 64.2631 seconds
# Test loss = 2.1558, acc = 0.3717; test time = 4.7925 seconds
# Total time = 69.0556 seconds
# Train step 80, loss = 2.1608, acc = 0.3802; train time = 64.2582 seconds
# Test loss = 2.1586, acc = 0.3706; test time = 4.8096 seconds
# Total time = 69.0679 seconds
# Train step 81, loss = 2.1601, acc = 0.3802; train time = 64.2705 seconds
# Test loss = 2.1595, acc = 0.3653; test time = 4.8207 seconds
# Total time = 69.0912 seconds
# Train step 82, loss = 2.1609, acc = 0.3806; train time = 64.2440 seconds
# Test loss = 2.1612, acc = 0.3740; test time = 4.8183 seconds
# Total time = 69.0624 seconds
# Train step 83, loss = 2.1618, acc = 0.3811; train time = 64.3025 seconds
# Test loss = 2.1581, acc = 0.3718; test time = 4.8037 seconds
# Total time = 69.1065 seconds
# Train step 84, loss = 2.1589, acc = 0.3813; train time = 64.3111 seconds
# Test loss = 2.1582, acc = 0.3671; test time = 4.7722 seconds
# Total time = 69.0834 seconds
# Train step 85, loss = 2.1590, acc = 0.3812; train time = 64.2257 seconds
# Test loss = 2.1578, acc = 0.3679; test time = 4.7952 seconds
# Total time = 69.0210 seconds
# Train step 86, loss = 2.1592, acc = 0.3796; train time = 64.1945 seconds
# Test loss = 2.1541, acc = 0.3743; test time = 4.8278 seconds
# Total time = 69.0225 seconds
# Train step 87, loss = 2.1596, acc = 0.3830; train time = 64.3853 seconds
# Test loss = 2.1586, acc = 0.3726; test time = 4.8214 seconds
# Total time = 69.2068 seconds
# Train step 88, loss = 2.1602, acc = 0.3826; train time = 64.2495 seconds
# Test loss = 2.1572, acc = 0.3717; test time = 4.7697 seconds
# Total time = 69.0193 seconds
# Train step 89, loss = 2.1600, acc = 0.3821; train time = 64.3093 seconds
# Test loss = 2.1549, acc = 0.3683; test time = 4.8097 seconds
# Total time = 69.1191 seconds
# Train step 90, loss = 2.1576, acc = 0.3817; train time = 64.2285 seconds
# Test loss = 2.1575, acc = 0.3751; test time = 4.8096 seconds
# Total time = 69.0382 seconds
# Train step 91, loss = 2.1587, acc = 0.3824; train time = 64.3165 seconds
# Test loss = 2.1588, acc = 0.3722; test time = 4.8057 seconds
# Total time = 69.1223 seconds
# Train step 92, loss = 2.1587, acc = 0.3822; train time = 64.3488 seconds
# Test loss = 2.1605, acc = 0.3697; test time = 4.8173 seconds
# Total time = 69.1662 seconds
# Train step 93, loss = 2.1583, acc = 0.3835; train time = 64.3516 seconds
# Test loss = 2.1587, acc = 0.3698; test time = 4.8730 seconds
# Total time = 69.2255 seconds
# Train step 94, loss = 2.1579, acc = 0.3829; train time = 64.3971 seconds
# Test loss = 2.1602, acc = 0.3715; test time = 4.8079 seconds
# Total time = 69.2051 seconds
# Train step 95, loss = 2.1592, acc = 0.3822; train time = 64.2800 seconds
# Test loss = 2.1591, acc = 0.3751; test time = 4.7880 seconds
# Total time = 69.0686 seconds
# Train step 96, loss = 2.1577, acc = 0.3838; train time = 64.3729 seconds
# Test loss = 2.1536, acc = 0.3717; test time = 4.8323 seconds
# Total time = 69.2055 seconds
# Train step 97, loss = 2.1590, acc = 0.3834; train time = 64.2988 seconds
# Test loss = 2.1609, acc = 0.3707; test time = 4.7884 seconds
# Total time = 69.0873 seconds
# Train step 98, loss = 2.1582, acc = 0.3838; train time = 64.3417 seconds
# Test loss = 2.1553, acc = 0.3752; test time = 4.8084 seconds
# Total time = 69.1502 seconds
# Train step 99, loss = 2.1576, acc = 0.3834; train time = 64.2313 seconds
# Test loss = 2.1553, acc = 0.3728; test time = 4.8509 seconds
# Total time = 69.0828 seconds
