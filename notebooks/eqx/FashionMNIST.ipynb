# %%
#pip install -U "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install pennylane pennylane-lightning pennylane-lightning[gpu] cotengra quimb equinox jaxtyping --upgrade
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.35.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.5 MB/s eta 0:00:00
# Collecting pennylane-lightning
#   Downloading PennyLane_Lightning-0.35.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 76.3 MB/s eta 0:00:00
# Collecting cotengra
#   Downloading cotengra-0.6.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 27.3 MB/s eta 0:00:00
# Collecting quimb
#   Downloading quimb-1.8.0-py3-none-any.whl (522 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.1/522.1 kB 57.0 MB/s eta 0:00:00
# Collecting equinox
#   Downloading equinox-0.11.4-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.2/175.2 kB 27.3 MB/s eta 0:00:00
# Collecting jaxtyping
#   Downloading jaxtyping-0.2.28-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.3)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 91.2 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.9-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.11.0)
# Collecting pennylane-lightning-gpu (from pennylane-lightning)
#   Downloading PennyLane_Lightning_GPU-0.35.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.2 MB/s eta 0:00:00
# Collecting cytoolz>=0.8.0 (from quimb)
#   Downloading cytoolz-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.39 in /usr/local/lib/python3.10/dist-packages (from quimb) (0.58.1)
# Requirement already satisfied: psutil>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from quimb) (5.9.5)
# Requirement already satisfied: tqdm>=4 in /usr/local/lib/python3.10/dist-packages (from quimb) (4.66.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.10/dist-packages (from equinox) (0.4.26)
# Collecting typeguard==2.13.3 (from jaxtyping)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz>=0.8.0->quimb) (0.12.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->equinox) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->equinox) (3.3.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.39->quimb) (0.41.1)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Installing collected packages: typeguard, semantic-version, rustworkx, cytoolz, autoray, jaxtyping, cotengra, quimb, equinox, pennylane-lightning, pennylane, pennylane-lightning-gpu
# Successfully installed autoray-0.6.9 cotengra-0.6.0 cytoolz-0.12.3 equinox-0.11.4 jaxtyping-0.2.28 pennylane-0.35.1 pennylane-lightning-0.35.1 pennylane-lightning-gpu-0.35.1 quimb-1.8.0 rustworkx-0.14.2 semantic-version-2.10.0 typeguard-2.13.3

# %% [markdown]
# # Import Packages

# %%
import matplotlib.pyplot as plt
import sys
import pandas as pd
import jax

import os, json

from datetime import datetime
import time

from jaxtyping import Array, Float, Int, PyTree
import jax.numpy as jnp
import numpy as np

import equinox as eqx

import optax  # optimization using jax

import torch  # https://pytorch.org
import torchvision  # https://pytorch.org

import pennylane as qml
import pennylane.numpy as pnp

import functools, itertools

from jax.lib import xla_bridge

#jax.config.update("jax_enable_x64", True)

def set_jax_platform():
    # Check if TPU is available
    try:
        tpu_backend = xla_bridge.get_backend('tpu')
        if tpu_backend and tpu_backend.device_count() > 0:
            # Set platform to TPU
            jax.config.update('jax_platform_name', 'tpu')
            print("Set platform to TPU")
            return
    except RuntimeError:
        pass  # No TPU found, move on to check for GPU

    # Check if GPU is available
    try:
      gpu_backend = xla_bridge.get_backend('gpu')
      if gpu_backend and gpu_backend.device_count() > 0:
          # Set platform to CUDA (GPU)
          jax.config.update('jax_platform_name', 'gpu')
          print("Set platform to GPU")
    except RuntimeError:
          # Set platform to CPU
          jax.config.update('jax_platform_name', 'cpu')
          print("Set platform to CPU")

# Call the function to set the platform
set_jax_platform()

seed = 1701
jrng_key = jax.random.PRNGKey(seed)
torch.manual_seed(seed)
print(jax.devices())
# Out:
# Set platform to GPU
# [cuda(id=0)]

# %% [markdown]
# # Training Hyper-parameters

# %%
# some training configuration
DATA = "FashionMNIST" # "MNIST", "FashionMNIST", "CIFAR10"
BATCH_SIZE = 1000
EPOCHS = 100
LEARNING_RATE = 5E-3
REPEATS = 5

curr_time = datetime.now().strftime("%Y%m%d_%H%M%S")

# %% [markdown]
# # Utilities for Quantum Circuit Simulation and Quantum Layers

# %%
# utilities
ket = {
    '0':jnp.array([1,0]),
    '1':jnp.array([0,1]),
    '+':(jnp.array([1,0]) + jnp.array([0,1]))/jnp.sqrt(2),
    '-':(jnp.array([1,0]) - jnp.array([0,1]))/jnp.sqrt(2)
}

pauli = {
    'I':jnp.array([[1,0],[0,1]]),
    'X':jnp.array([[0,1],[1,0]]),
    'Y':jnp.array([[0, -1j],[1j, 0]]),
    'Z':jnp.array([[1,0],[0,-1]])
}

def tensor_product(*args):
  input_list = [a for a in args]
  return functools.reduce(jnp.kron, input_list)

def multi_qubit_identity(n_qubits:int)->jnp.ndarray:
  assert n_qubits>0
  if n_qubits == 1:
    return pauli['I']
  else:
    return tensor_product(*[pauli['I'] for _ in range(n_qubits)])

def pauli_dict_func(key):
    return pauli[key]

def pauli_dict_func_multiple_keys(keys):
    return list(map(pauli_dict_func, keys))

def pauli_string_tensor_prod(pauli_string:str):
    paulis_char = list(pauli_string)
    paulis_mat = pauli_dict_func_multiple_keys(paulis_char)
    return tensor_product(*paulis_mat)

def generate_nqubit_pauli_strings(n_qubits:int):
    assert n_qubits>0
    pauli_labels = ['I', 'X', 'Y', 'Z']
    pauli_strings = []
    for labels in itertools.product(pauli_labels, repeat=n_qubits):
        pauli_str = "".join(labels)
        if pauli_str != 'I'*n_qubits:
            pauli_strings.append(pauli_str)
    return pauli_strings

def generate_pauli_tensor_list(pauli_strings:list):
    return list(map(pauli_string_tensor_prod, pauli_strings))

su4_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(2)
)

su32_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(5)
)

su8_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(3)
)

su16_generators = generate_pauli_tensor_list(
    generate_nqubit_pauli_strings(4)
)

def su32_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su32_generators))
    return jax.scipy.linalg.expm(1j*generator)

def su4_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su4_generators))
    return jax.scipy.linalg.expm(1j*generator)

def su8_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su8_generators))
    return jax.scipy.linalg.expm(1j*generator)

def su16_op(
    params:jnp.ndarray
):
    generator = jnp.einsum("i, ijk - >jk", params, jnp.asarray(su16_generators))
    return jax.scipy.linalg.expm(1j*generator)

def measure_sv(
    state:jnp.ndarray,
    observable:jnp.ndarray
    ):
  """
  Measure a statevector with a Hermitian observable.
  Note: No checking Hermitianicity of the observable or whether the observable
  has all real eigenvalues or not
  """
  expectation_value = jnp.dot(jnp.conj(state.T), jnp.dot(observable, state))
  return jnp.real(expectation_value)

def measure_dm(
    rho:jnp.ndarray,
    observable:jnp.ndarray
):
  """
  Measure a density matrix with a Hermitian observable.
  Note: No checking Hermitianicity of the observable or whether the observable
  has all real eigenvalues or not.
  """
  product = jnp.dot(rho, observable)

  # Calculate the trace, which is the sum of diagonal elements
  trace = jnp.trace(product)

  # The expectation value should be real for physical observables
  return jnp.real(trace)

# assuming the input patch (hermitianized) has shape (c, h, w)
# assuming the input set statevectors has shape (c, 2**n)
# assuming we have a list of (state, observable) pairs
vmap_measure_sv_ob_pairs = jax.vmap(lambda pair: measure_sv(pair[0], pair[1]), in_axes=0, out_axes=0)
# assuming the input set desnity matrices has shape (c, 2**n, 2**n)
# assuming we have a list of (rho, observable) pairs
vmap_measure_dm_ob_pairs = jax.vmap(lambda pair: measure_dm(pair[0], pair[1]), in_axes=0, out_axes=0)

# vmap through different observables
vmap_measure_sv = jax.vmap(measure_sv, in_axes=(None, 0), out_axes=0)
vmap_measure_dm = jax.vmap(measure_dm, in_axes=(None, 0), out_axes=0)

def bitstring_to_state(bitstring:str):
  """
  Convert a bit string, like '0101001' or '+-+-101'
  to a statevector. Each character in the bitstring must be among
  0, 1, + and -
  """
  assert len(bitstring)>0
  for c in bitstring:
    assert c in ['0', '1', '+', '-']
  single_qubit_states = [ket[c] for c in bitstring]
  return tensor_product(*single_qubit_states)


# utilities for the flipped quanvolution kernel
def extract_patches(image, patch_size, stride, padding=None):
    """
    Extracts patches from an image with multiple input channels and optional custom padding.

    Args:
        image (jnp.ndarray): Input image tensor of shape (in_channels, height, width).
        patch_size (int): Size of the square patches to extract.
        stride (int): Stride between patches.
        padding (tuple): Padding value(s) for each dimension.

    Returns:
        jnp.ndarray: Tensor of extracted patches of shape (num_patches, in_channels, patch_size, patch_size).
    """

    in_channels, height, width = image.shape[-3], image.shape[-2], image.shape[-1]

    pad_h, pad_w = padding if padding is not None else (0, 0)


    image = jnp.pad(image, [(0, 0), (pad_h, pad_h), (pad_w, pad_w)], mode='constant') if padding is not None else image


    _, height, width = image.shape


    num_patches_h = (height - patch_size) // stride + 1
    num_patches_w = (width - patch_size) // stride + 1

    patch_indices = [(i, j) for i in range(num_patches_h) for j in range(num_patches_w)]

    patches = jnp.stack([image[:, i*stride:i*stride+patch_size, j*stride:j*stride+patch_size]
                         for i, j in patch_indices])

    return patches


def generate_2q_param_state(theta):
  state = bitstring_to_state('00')
  state = jnp.dot(
      su4_op(theta),
      state
  )
  return state

vmap_generate_2q_param_state = jax.vmap(generate_2q_param_state, in_axes=0, out_axes = 0)

# FlippedQuanv3x3 kernel
def single_kernel_op(thetas, patch):
  # patch has shape (c_in, h, w)
  # thetas has shape (c_in, 4^2-1) for SU4 gates
  n_theta = thetas.shape[0]
  n_channel = patch.shape[0]
  assert n_theta == n_channel, "Thetas and patch must have the same number of channels."
  states = vmap_generate_2q_param_state(thetas)
  patch = jnp.pad(patch, [(0,0),(0,1),(0,1)], mode='constant')
  herm_patch = (jnp.einsum("ijk->ikj", patch)+patch)/2
  channel_out = vmap_measure_sv_ob_pairs([states, herm_patch])
  return jnp.sum(channel_out, axis = 0)/n_theta

vmap_single_kernel_op_through_extracted_patches = jax.vmap(single_kernel_op, in_axes=(None, 0), out_axes=0)

# For multiple channel output
# parameter has shape (c_out, c_in, 4**2-1) for SU4 gates
vmap_vmap_single_kernel_op_through_extracted_patches = jax.vmap(vmap_single_kernel_op_through_extracted_patches, in_axes=(0, None), out_axes=0)

# Quantum version of the linear layer
# Realized with data reuploading and Hamiltonian embedding
# for input dimension D
# the quantum linear layer is a n = ceil(log4(D+1))-qubit quantum circuit
# Both the data encoding and the parameterised cirucit are achieved via the SU(2^n) unitary

def data_encode_unitary(padded_data, t):
    #original_dim = 4**7 # fix to 7 qubits #padded_data.shape[-1]
    #new_dim = jnp.sqrt(original_dim).astype(jnp.int_)
    data = jnp.reshape(padded_data, (2**7, 2**7))
    generator = (data + jnp.einsum('...jk->...kj', data))/2
    return jax.scipy.linalg.expm(1.0j*t*generator)

def su_n(params, pauli_string_tensor_list):
    paulis = jnp.asarray(pauli_string_tensor_list)
    generator = jnp.einsum("i, ijk -> jk", params, paulis)
    return jax.scipy.linalg.expm(1.0j*generator)

def linear_layer_func(
        padded_data,
        params,
        pauli_string_tensor_list,
        observables,
        n_qubits
):
    n_rep = params.shape[0]
    state = bitstring_to_state("+" * n_qubits)
    data_unitary = data_encode_unitary(padded_data, 1.0/n_rep)
    for i in range(n_rep):
        state = jnp.dot(data_unitary, state)
        state = jnp.dot(su_n(params[i], pauli_string_tensor_list), state)
    return vmap_measure_sv(state, observables)

vmap_batch_linear_layer_func = jax.vmap(linear_layer_func, in_axes=(0, None, None, None, None), out_axes=0)

# %% [markdown]
# # Layers and Models

# %%
# models
class FlippedQuanv3x3(eqx.Module):
  weight: jax.Array
  bias: jax.Array
  stride: int
  pad: tuple|None
  pad_h: int
  pad_w: int

  def __init__(self, in_channels, out_channels, stride, padding, key):
    wkey, bkey = jax.random.split(key,2)
    self.weight = jax.random.normal(shape=[out_channels, in_channels, 15], key=wkey)
    self.bias = jax.random.normal(shape=[out_channels, 1], key=bkey)
    self.stride = stride
    self.pad = padding
    self.pad_h, self.pad_w = padding if padding is not None else (0,0)

  def __call__(self, x):
    # x has shape ( ,c_in, h, w)
    # weight has shape (c_out, c_in, 15)
    # bias has shape (c_out, 1)
    c_in, h_in, w_in = x.shape[-3], x.shape[-2], x.shape[-1]
    patches = extract_patches(x, patch_size=3, stride=self.stride, padding=self.pad)
    h_out = (h_in-3+2*self.pad_h)//self.stride +1
    w_out = (w_in-3+2*self.pad_w)//self.stride +1
    out = vmap_vmap_single_kernel_op_through_extracted_patches(self.weight, patches)
    out = out + self.bias
    return out.reshape((-1, h_out, w_out))

class DataReUploadingLinear(eqx.Module):
    weight: jax.Array
    bias: jax.Array
    n_reps:int
    in_dim:int
    out_dim:int
    n_qubits:int

    def __init__(self, n_reps, key):
        #assert 2 ** n_qubits >= out_dim
        #assert 4 ** n_qubits >= in_dim
        wkey, bkey = jax.random.split(key, 2)
        # fix the following parameters for jit
        self.in_dim = 16 * 28 * 28
        self.out_dim = 10
        self.n_qubits = 7
        # in_dim is 16 * 28 * 28
        # out_dim is 10
        self.n_reps = n_reps
        param_dim = 4 ** self.n_qubits - 1
        self.weight = jax.random.normal(shape=[self.n_reps, param_dim], key=wkey)
        self.bias = jax.random.normal(shape=[self.out_dim], key=bkey)

    def generate_observables(self):
        observables = []
        for i in range(self.out_dim):
            temp_bitstring = '{0:b}'.format(i).zfill(self.n_qubits)
            ob = jnp.outer(bitstring_to_state(temp_bitstring), bitstring_to_state(temp_bitstring))
            observables.append(ob)
        return jnp.asarray(observables)

    def get_pauli_string_tensor_list(self):
        return generate_pauli_tensor_list(generate_nqubit_pauli_strings(self.n_qubits))

    #def get_pad_size(self):
    #    return 4 ** self.n_qubits - self.in_dim

    def __call__(self, x):
        # x has size (batchsize, in_dim)
        # pad x
        x = jnp.pad(x, (0, 4 ** self.n_qubits - self.in_dim))

        out = linear_layer_func(
            padded_data=x,
            params=self.weight,
            pauli_string_tensor_list=self.get_pauli_string_tensor_list(),
            observables=self.generate_observables(),
            n_qubits=self.n_qubits
        )
        out = out + self.bias
        return out

# %%
def loss_fn(
    pred_y:Float[Array, "batch 10"],
    y:Int[Array, "batch"]
):
  return jnp.mean(optax.softmax_cross_entropy_with_integer_labels(pred_y, y))

def accuracy_fn(
    pred_y:Float[Array, "batch 10"],
    y:Int[Array, "batch"]
):
  pred = jnp.argmax(pred_y, axis=1)
  return jnp.sum(jnp.array(pred == y).astype(int)) / len(pred_y)

# depending on input dataset, the input number of channels differs
if DATA == "CIFAR10":
    class HybridNet(eqx.Module):
      replacement_lvl:int
      layers:list
      def __init__(self, replacement_lvl, key):
        assert replacement_lvl in [0,1,2]
        self.replacement_lvl = replacement_lvl
        key1, key2, key3 = jax.random.split(key, 3)
        if self.replacement_lvl == 0:
          self.layers = [
              eqx.nn.Conv2d(3, 32, kernel_size = 3, padding = 0, key=key1),
              eqx.nn.Conv2d(32, 16, kernel_size = 3, padding = 0, key=key2),
              jnp.ravel,
              eqx.nn.Linear(16*28*28, 10, key=key3)
          ]
        elif self.replacement_lvl == 1:
          self.layers = [
                FlippedQuanv3x3(3, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                eqx.nn.Linear(16 * 28 * 28, 10, key=key3),
          ]
        elif self.replacement_lvl == 2:
          self.layers = [
                FlippedQuanv3x3(3, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                DataReUploadingLinear(n_reps=10, key=key3),
          ]
        else:
          raise ValueError("replacement_lvl should be 0, 1, or 2")

      def __call__(self, x:Float[Array, "3 h w"])->Float[Array, "10"]:
        for layer in self.layers:
          x = layer(x)
        return x

    @eqx.filter_jit
    def compute_out(
        model:HybridNet,
        x:Float[Array, "batch 3 32 32"]
    ) -> Float[Array, "batch 10"]:
      return jax.vmap(model)(x)

    @eqx.filter_jit
    def compute_loss(
        model: HybridNet, x: Float[Array, "batch 3 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return loss_fn(pred_y, y)

    @eqx.filter_jit
    def compute_accuracy(
        model: HybridNet, x: Float[Array, "batch 3 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return accuracy_fn(pred_y, y)


else:
    class HybridNet(eqx.Module):
      replacement_lvl:int
      layers:list
      def __init__(self, replacement_lvl, key):
        assert replacement_lvl in [0,1,2]
        self.replacement_lvl = replacement_lvl
        key1, key2, key3 = jax.random.split(key, 3)
        if self.replacement_lvl == 0:
          self.layers = [
              eqx.nn.Conv2d(1, 32, kernel_size = 3, padding = 0, key=key1),
              eqx.nn.Conv2d(32, 16, kernel_size = 3, padding = 0, key=key2),
              jnp.ravel,
              eqx.nn.Linear(16*28*28, 10, key=key3)
          ]
        elif self.replacement_lvl == 1:
          self.layers = [
                FlippedQuanv3x3(1, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                eqx.nn.Linear(16 * 28 * 28, 10, key=key3),
          ]
        elif self.replacement_lvl == 2:
          self.layers = [
                FlippedQuanv3x3(1, 32, stride=1, padding=(0, 0), key=key1),
                FlippedQuanv3x3(32, 16, stride=1, padding=(0, 0), key=key2),
                jnp.ravel,
                DataReUploadingLinear(n_reps=10, key=key3),
          ]
        else:
          raise ValueError("replacement_lvl should be 0, 1, or 2")

      def __call__(self, x:Float[Array, "1 h w"])->Float[Array, "10"]:
        for layer in self.layers:
          x = layer(x)
        return x

    @eqx.filter_jit
    def compute_out(
        model:HybridNet,
        x:Float[Array, "batch 1 32 32"]
    ) -> Float[Array, "batch 10"]:
      return jax.vmap(model)(x)

    @eqx.filter_jit
    def compute_loss(
        model: HybridNet, x: Float[Array, "batch 1 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return loss_fn(pred_y, y)

    @eqx.filter_jit
    def compute_accuracy(
        model: HybridNet, x: Float[Array, "batch 1 32 32"], y: Int[Array, " batch"]
    ):
      pred_y = compute_out(model, x)
      return accuracy_fn(pred_y, y)

# %% [markdown]
# # Training Utilities

# %%
def get_train_test_data(name = "MNIST"):
  assert name in ["MNIST", "CIFAR10", "FashionMNIST"]
  if name  == "CIFAR10":
    preprocess = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5,), (0.5,))
    ])
  else:
    preprocess =  torchvision.transforms.Compose([
    torchvision.transforms.Pad(2),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5,), (0.5,))
    ])
  if name == "MNIST":
    train = torchvision.datasets.MNIST(
        root="MNIST",
        train=True,
        transform=preprocess,
        download=True)
    test = torchvision.datasets.MNIST(
        root="MNIST",
        train=False,
        transform=preprocess,
        download=True)
  elif name == "CIFAR10":
    train = torchvision.datasets.CIFAR10(
        root="CIFAR10",
        train=True,
        transform=preprocess,
        download=True)
    test = torchvision.datasets.CIFAR10(
        root="CIFAR10",
        train=False,
        transform=preprocess,
        download=True)
  elif name == "FashionMNIST":
    train = torchvision.datasets.FashionMNIST(
        root="FashionMNIST",
        train=True,
        transform=preprocess,
        download=True)
    test = torchvision.datasets.FashionMNIST(
        root="FashionMNIST",
        train=False,
        transform=preprocess,
        download=True)
  else:
    raise ValueError("name should be MNIST, CIFAR10, or FashionMNIST")
  return train, test

def train(
      model: HybridNet,
      data_name: str,
      batchsize: int,
      epochs: int,
      optim: optax.GradientTransformation,
  ):

  train_loss = []
  train_acc = []
  test_loss = []
  test_acc = []

  opt_state = optim.init(eqx.filter(model, eqx.is_array))
  train_data, test_data = get_train_test_data(data_name)
  trainloader = torch.utils.data.DataLoader(
      train_data, batch_size=batchsize, shuffle=True)
  test_loader = torch.utils.data.DataLoader(
      test_data, batch_size=batchsize, shuffle=False)
  if data_name == "CIFAR10":
    @eqx.filter_jit
    def make_step(
      model: HybridNet,
      opt_state: PyTree,
      x: Float[Array, "batch 3 32 32"],
      y: Int[Array, "batch"],
    ):
      loss_value, grads = eqx.filter_value_and_grad(compute_loss)(model, x, y)
      updates, opt_state = optim.update(grads, opt_state, model)
      model = eqx.apply_updates(model, updates)
      acc = compute_accuracy(model, x, y)
      return model, opt_state, loss_value, acc

    @eqx.filter_jit
    def make_test_step(
        model:HybridNet,
        x: Float[Array, "batch 3 32 32"],
        y: Int[Array, "batch"],
    ):
      out = compute_out(model, x)
      loss_value = loss_fn(out, y)
      acc = accuracy_fn(out, y)
      return loss_value, acc
  else:
    @eqx.filter_jit
    def make_step(
      model: HybridNet,
      opt_state: PyTree,
      x: Float[Array, "batch 1 32 32"],
      y: Int[Array, "batch"],
    ):
      loss_value, grads = eqx.filter_value_and_grad(compute_loss)(model, x, y)
      updates, opt_state = optim.update(grads, opt_state, model)
      model = eqx.apply_updates(model, updates)
      acc = compute_accuracy(model, x, y)
      return model, opt_state, loss_value, acc

    @eqx.filter_jit
    def make_test_step(
        model:HybridNet,
        x: Float[Array, "batch 1 32 32"],
        y: Int[Array, "batch"],
    ):
      out = compute_out(model, x)
      loss_value = loss_fn(out, y)
      acc = accuracy_fn(out, y)
      return loss_value, acc


  for step in range(epochs):
    step_start = time.time()
    batch_train_loss = []
    batch_train_acc = []
    batch_test_loss = []
    batch_test_acc = []
    for batchidx, (x, y) in enumerate(trainloader):
      x = x.numpy()
      y = y.numpy()
      model, opt_state, loss_value_batch, acc_value_batch = make_step(model, opt_state, x, y)
      batch_train_loss.append(loss_value_batch)
      batch_train_acc.append(acc_value_batch)
    loss_value = float(np.mean(batch_train_loss))
    acc_value = float(np.mean(batch_train_acc))
    train_loss.append(loss_value)
    train_acc.append(acc_value)
    train_time = time.time() - step_start
    print(f"Train step {step}, loss = {loss_value:.4f}, acc = {acc_value:.4f}; train time = {train_time:.4f} seconds")

    for batchidx, (x, y) in enumerate(test_loader):
      x = x.numpy()
      y = y.numpy()
      loss_value_batch, acc_value_batch = make_test_step(model, x, y)
      batch_test_loss.append(loss_value_batch)
      batch_test_acc.append(acc_value_batch)

    test_loss_value, test_acc_value = float(np.mean(batch_test_loss)), float(np.mean(batch_test_acc))
    test_loss.append(test_loss_value)
    test_acc.append(test_acc_value)
    test_time = time.time() - step_start - train_time
    print(f"Test loss = {test_loss_value:.4f}, acc = {test_acc_value:.4f}; test time = {test_time:.4f} seconds")
    print(f"Total time = {time.time() - step_start:.4f} seconds")

  return model, train_loss, train_acc, test_loss, test_acc

# %% [markdown]
# # Training

# %%
REPLACEMENT_LVL = [2, 1, 0]
NUM_KEYS = len(REPLACEMENT_LVL)*REPEATS

keys = jax.random.split(jrng_key, NUM_KEYS)
key_count = 0
for replacement_lvl in REPLACEMENT_LVL:
  for rep in range(REPEATS):
    if replacement_lvl == 2 and (rep==0 or rep==1 or rep==2):
      continue # already have rep = 0,1,2 from a previous execution
    print(f"____Training with replacement_lvl = {replacement_lvl}____")
    print(f"----Training with repetatioin = {rep}----")
    key = keys[key_count]
    key_count += 1
    model = HybridNet(replacement_lvl, key)
    optim = optax.adam(LEARNING_RATE)
    model, train_loss, train_acc, test_loss, test_acc = train(model, DATA, BATCH_SIZE, EPOCHS, optim)
    results = {
      "train_loss": train_loss,
      "train_acc": train_acc,
      "test_loss": test_loss,
      "test_acc": test_acc,
    }
    with open(os.path.join('/content/drive/MyDrive/Research/Quanvolution/notebooks/eqx', f"{curr_time}_{DATA}_replacement_lvl_{replacement_lvl}_rep_{rep}.json"), 'w') as f:
      json.dump(results, f, indent=4)

    eqx.tree_serialise_leaves(os.path.join('/content/drive/MyDrive/Research/Quanvolution/notebooks/eqx', f"{curr_time}_{DATA}_replacement_lvl_{replacement_lvl}_rep_{rep}.eqx"), model)
# Out:
# ____Training with replacement_lvl = 2____
# ----Training with repetatioin = 3----
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to FashionMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 9413430.32it/s]
# Extracting FashionMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to FashionMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 157005.66it/s]
# Extracting FashionMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to FashionMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 2956257.15it/s]
# Extracting FashionMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to FashionMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 6302474.31it/s]
# Extracting FashionMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to FashionMNIST/FashionMNIST/raw
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# Train step 0, loss = 2.4517, acc = 0.1221; train time = 1175.8027 seconds
# Test loss = 2.2069, acc = 0.2007; test time = 715.4422 seconds
# Total time = 1891.2451 seconds
# Train step 1, loss = 2.1030, acc = 0.2614; train time = 62.8342 seconds
# Test loss = 2.0296, acc = 0.3203; test time = 3.8581 seconds
# Total time = 66.6924 seconds
# Train step 2, loss = 1.9733, acc = 0.3884; train time = 62.9598 seconds
# Test loss = 1.9360, acc = 0.4321; test time = 3.8654 seconds
# Total time = 66.8253 seconds
# Train step 3, loss = 1.9003, acc = 0.5012; train time = 62.5599 seconds
# Test loss = 1.8828, acc = 0.5613; test time = 3.8353 seconds
# Total time = 66.3953 seconds
# Train step 4, loss = 1.8580, acc = 0.6395; train time = 62.7829 seconds
# Test loss = 1.8509, acc = 0.6924; test time = 3.8288 seconds
# Total time = 66.6119 seconds
# Train step 5, loss = 1.8366, acc = 0.7386; train time = 62.5995 seconds
# Test loss = 1.8351, acc = 0.7525; test time = 3.8440 seconds
# Total time = 66.4436 seconds
# Train step 6, loss = 1.8238, acc = 0.7716; train time = 62.7427 seconds
# Test loss = 1.8256, acc = 0.7677; test time = 3.8247 seconds
# Total time = 66.5676 seconds
# Train step 7, loss = 1.8166, acc = 0.7798; train time = 62.9682 seconds
# Test loss = 1.8180, acc = 0.7716; test time = 3.8408 seconds
# Total time = 66.8091 seconds
# Train step 8, loss = 1.8109, acc = 0.7831; train time = 62.9711 seconds
# Test loss = 1.8150, acc = 0.7719; test time = 3.8522 seconds
# Total time = 66.8234 seconds
# Train step 9, loss = 1.8073, acc = 0.7845; train time = 62.9524 seconds
# Test loss = 1.8128, acc = 0.7746; test time = 3.8466 seconds
# Total time = 66.7991 seconds
# Train step 10, loss = 1.8043, acc = 0.7865; train time = 62.7832 seconds
# Test loss = 1.8136, acc = 0.7750; test time = 3.8646 seconds
# Total time = 66.6479 seconds
# Train step 11, loss = 1.8024, acc = 0.7874; train time = 62.8523 seconds
# Test loss = 1.8099, acc = 0.7767; test time = 3.8620 seconds
# Total time = 66.7143 seconds
# Train step 12, loss = 1.7993, acc = 0.7891; train time = 62.6192 seconds
# Test loss = 1.8074, acc = 0.7788; test time = 3.8719 seconds
# Total time = 66.4913 seconds
# Train step 13, loss = 1.7981, acc = 0.7891; train time = 62.8051 seconds
# Test loss = 1.7999, acc = 0.7800; test time = 3.8521 seconds
# Total time = 66.6580 seconds
# Train step 14, loss = 1.7946, acc = 0.7912; train time = 62.9650 seconds
# Test loss = 1.8008, acc = 0.7807; test time = 3.8730 seconds
# Total time = 66.8380 seconds
# Train step 15, loss = 1.7937, acc = 0.7919; train time = 62.7771 seconds
# Test loss = 1.7984, acc = 0.7816; test time = 3.8375 seconds
# Total time = 66.6147 seconds
# Train step 16, loss = 1.7906, acc = 0.7929; train time = 62.8107 seconds
# Test loss = 1.7956, acc = 0.7835; test time = 3.8396 seconds
# Total time = 66.6505 seconds
# Train step 17, loss = 1.7895, acc = 0.7936; train time = 63.1231 seconds
# Test loss = 1.7980, acc = 0.7798; test time = 3.8958 seconds
# Total time = 67.0190 seconds
# Train step 18, loss = 1.7889, acc = 0.7949; train time = 62.8400 seconds
# Test loss = 1.7943, acc = 0.7833; test time = 3.8470 seconds
# Total time = 66.6871 seconds
# Train step 19, loss = 1.7875, acc = 0.7963; train time = 63.1572 seconds
# Test loss = 1.7946, acc = 0.7849; test time = 3.8537 seconds
# Total time = 67.0111 seconds
# Train step 20, loss = 1.7867, acc = 0.7965; train time = 62.9912 seconds
# Test loss = 1.7923, acc = 0.7848; test time = 3.8130 seconds
# Total time = 66.8042 seconds
# Train step 21, loss = 1.7852, acc = 0.7968; train time = 62.7407 seconds
# Test loss = 1.7924, acc = 0.7859; test time = 3.8437 seconds
# Total time = 66.5845 seconds
# Train step 22, loss = 1.7850, acc = 0.7969; train time = 63.0621 seconds
# Test loss = 1.7913, acc = 0.7879; test time = 3.8753 seconds
# Total time = 66.9375 seconds
# Train step 23, loss = 1.7822, acc = 0.7986; train time = 62.9305 seconds
# Test loss = 1.7912, acc = 0.7875; test time = 3.8429 seconds
# Total time = 66.7736 seconds
# Train step 24, loss = 1.7819, acc = 0.7990; train time = 63.0016 seconds
# Test loss = 1.7913, acc = 0.7869; test time = 3.8798 seconds
# Total time = 66.8815 seconds
# Train step 25, loss = 1.7820, acc = 0.7993; train time = 62.8241 seconds
# Test loss = 1.7867, acc = 0.7893; test time = 3.9020 seconds
# Total time = 66.7268 seconds
# Train step 26, loss = 1.7805, acc = 0.7995; train time = 62.7173 seconds
# Test loss = 1.7858, acc = 0.7874; test time = 3.8546 seconds
# Total time = 66.5720 seconds
# Train step 27, loss = 1.7788, acc = 0.8002; train time = 62.9406 seconds
# Test loss = 1.7861, acc = 0.7886; test time = 3.8910 seconds
# Total time = 66.8318 seconds
# Train step 28, loss = 1.7790, acc = 0.8008; train time = 62.9564 seconds
# Test loss = 1.7836, acc = 0.7895; test time = 3.8465 seconds
# Total time = 66.8030 seconds
# Train step 29, loss = 1.7775, acc = 0.8018; train time = 63.1899 seconds
# Test loss = 1.7857, acc = 0.7894; test time = 3.8831 seconds
# Total time = 67.0731 seconds
# Train step 30, loss = 1.7775, acc = 0.8019; train time = 65.7026 seconds
# Test loss = 1.7824, acc = 0.7904; test time = 3.8508 seconds
# Total time = 69.5536 seconds
# Train step 31, loss = 1.7762, acc = 0.8026; train time = 62.7689 seconds
# Test loss = 1.7816, acc = 0.7909; test time = 3.8354 seconds
# Total time = 66.6044 seconds
# Train step 32, loss = 1.7745, acc = 0.8027; train time = 62.6643 seconds
# Test loss = 1.7795, acc = 0.7922; test time = 3.8293 seconds
# Total time = 66.4937 seconds
# Train step 33, loss = 1.7733, acc = 0.8031; train time = 62.5799 seconds
# Test loss = 1.7832, acc = 0.7914; test time = 3.8518 seconds
# Total time = 66.4318 seconds
# Train step 34, loss = 1.7734, acc = 0.8035; train time = 62.9117 seconds
# Test loss = 1.7774, acc = 0.7925; test time = 3.8438 seconds
# Total time = 66.7556 seconds
# Train step 35, loss = 1.7739, acc = 0.8044; train time = 62.6424 seconds
# Test loss = 1.7804, acc = 0.7938; test time = 3.8391 seconds
# Total time = 66.4816 seconds
# Train step 36, loss = 1.7716, acc = 0.8043; train time = 62.7881 seconds
# Test loss = 1.7775, acc = 0.7934; test time = 3.8527 seconds
# Total time = 66.6414 seconds
# Train step 37, loss = 1.7714, acc = 0.8042; train time = 62.9526 seconds
# Test loss = 1.7799, acc = 0.7920; test time = 3.8856 seconds
# Total time = 66.8382 seconds
# Train step 38, loss = 1.7715, acc = 0.8056; train time = 62.9990 seconds
# Test loss = 1.7774, acc = 0.7933; test time = 3.8215 seconds
# Total time = 66.8209 seconds
# Train step 39, loss = 1.7703, acc = 0.8056; train time = 62.6660 seconds
# Test loss = 1.7769, acc = 0.7945; test time = 3.8470 seconds
# Total time = 66.5138 seconds
# Train step 40, loss = 1.7701, acc = 0.8056; train time = 62.6890 seconds
# Test loss = 1.7785, acc = 0.7931; test time = 3.8418 seconds
# Total time = 66.5309 seconds
# Train step 41, loss = 1.7698, acc = 0.8060; train time = 62.7504 seconds
# Test loss = 1.7760, acc = 0.7948; test time = 3.8415 seconds
# Total time = 66.5919 seconds
# Train step 42, loss = 1.7695, acc = 0.8064; train time = 62.7198 seconds
# Test loss = 1.7795, acc = 0.7928; test time = 3.8830 seconds
# Total time = 66.6029 seconds
# Train step 43, loss = 1.7699, acc = 0.8075; train time = 62.6522 seconds
# Test loss = 1.7744, acc = 0.7949; test time = 3.8353 seconds
# Total time = 66.4882 seconds
# Train step 44, loss = 1.7682, acc = 0.8071; train time = 62.8001 seconds
# Test loss = 1.7732, acc = 0.7959; test time = 3.8545 seconds
# Total time = 66.6547 seconds
# Train step 45, loss = 1.7651, acc = 0.8078; train time = 62.7883 seconds
# Test loss = 1.7719, acc = 0.7950; test time = 3.8484 seconds
# Total time = 66.6367 seconds
# Train step 46, loss = 1.7663, acc = 0.8074; train time = 62.8048 seconds
# Test loss = 1.7729, acc = 0.7967; test time = 3.8431 seconds
# Total time = 66.6482 seconds
# Train step 47, loss = 1.7671, acc = 0.8076; train time = 62.8523 seconds
# Test loss = 1.7711, acc = 0.7968; test time = 3.8579 seconds
# Total time = 66.7104 seconds
# Train step 48, loss = 1.7659, acc = 0.8080; train time = 62.7595 seconds
# Test loss = 1.7700, acc = 0.7976; test time = 3.8491 seconds
# Total time = 66.6089 seconds
# Train step 49, loss = 1.7650, acc = 0.8090; train time = 62.8465 seconds
# Test loss = 1.7691, acc = 0.7973; test time = 3.8981 seconds
# Total time = 66.7452 seconds
# Train step 50, loss = 1.7651, acc = 0.8088; train time = 62.9660 seconds
# Test loss = 1.7712, acc = 0.7969; test time = 3.8985 seconds
# Total time = 66.8646 seconds
# Train step 51, loss = 1.7641, acc = 0.8092; train time = 62.8483 seconds
# Test loss = 1.7698, acc = 0.7976; test time = 3.8375 seconds
# Total time = 66.6859 seconds
# Train step 52, loss = 1.7637, acc = 0.8096; train time = 62.8265 seconds
# Test loss = 1.7712, acc = 0.7983; test time = 3.8627 seconds
# Total time = 66.6893 seconds
# Train step 53, loss = 1.7641, acc = 0.8102; train time = 62.8696 seconds
# Test loss = 1.7715, acc = 0.7981; test time = 3.8611 seconds
# Total time = 66.7309 seconds
# Train step 54, loss = 1.7637, acc = 0.8106; train time = 62.9516 seconds
# Test loss = 1.7696, acc = 0.7973; test time = 3.8477 seconds
# Total time = 66.7994 seconds
# Train step 55, loss = 1.7630, acc = 0.8094; train time = 62.8213 seconds
# Test loss = 1.7685, acc = 0.7991; test time = 3.8459 seconds
# Total time = 66.6673 seconds
# Train step 56, loss = 1.7631, acc = 0.8104; train time = 62.9713 seconds
# Test loss = 1.7721, acc = 0.7985; test time = 3.8305 seconds
# Total time = 66.8019 seconds
# Train step 57, loss = 1.7614, acc = 0.8114; train time = 62.8870 seconds
# Test loss = 1.7693, acc = 0.7977; test time = 3.8775 seconds
# Total time = 66.7646 seconds
# Train step 58, loss = 1.7617, acc = 0.8108; train time = 62.7806 seconds
# Test loss = 1.7694, acc = 0.7988; test time = 3.8449 seconds
# Total time = 66.6256 seconds
# Train step 59, loss = 1.7608, acc = 0.8113; train time = 62.7151 seconds
# Test loss = 1.7679, acc = 0.7987; test time = 3.9007 seconds
# Total time = 66.6164 seconds
# Train step 60, loss = 1.7611, acc = 0.8111; train time = 62.8094 seconds
# Test loss = 1.7690, acc = 0.8003; test time = 3.8618 seconds
# Total time = 66.6713 seconds
# Train step 61, loss = 1.7600, acc = 0.8121; train time = 63.1365 seconds
# Test loss = 1.7702, acc = 0.7994; test time = 3.8450 seconds
# Total time = 66.9817 seconds
# Train step 62, loss = 1.7609, acc = 0.8118; train time = 62.8218 seconds
# Test loss = 1.7681, acc = 0.8007; test time = 3.8837 seconds
# Total time = 66.7058 seconds
# Train step 63, loss = 1.7595, acc = 0.8118; train time = 63.0968 seconds
# Test loss = 1.7693, acc = 0.8021; test time = 3.8396 seconds
# Total time = 66.9365 seconds
# Train step 64, loss = 1.7605, acc = 0.8119; train time = 62.8877 seconds
# Test loss = 1.7689, acc = 0.8003; test time = 3.8570 seconds
# Total time = 66.7448 seconds
# Train step 65, loss = 1.7591, acc = 0.8126; train time = 62.6843 seconds
# Test loss = 1.7674, acc = 0.7999; test time = 3.8494 seconds
# Total time = 66.5338 seconds
# Train step 66, loss = 1.7590, acc = 0.8125; train time = 62.8710 seconds
# Test loss = 1.7665, acc = 0.7998; test time = 3.8791 seconds
# Total time = 66.7501 seconds
# Train step 67, loss = 1.7582, acc = 0.8132; train time = 62.5818 seconds
# Test loss = 1.7654, acc = 0.8015; test time = 3.8759 seconds
# Total time = 66.4577 seconds
# Train step 68, loss = 1.7587, acc = 0.8132; train time = 62.8351 seconds
# Test loss = 1.7681, acc = 0.7999; test time = 3.8327 seconds
# Total time = 66.6679 seconds
# Train step 69, loss = 1.7584, acc = 0.8137; train time = 62.7147 seconds
# Test loss = 1.7664, acc = 0.8017; test time = 3.8626 seconds
# Total time = 66.5775 seconds
# Train step 70, loss = 1.7578, acc = 0.8135; train time = 62.8425 seconds
# Test loss = 1.7663, acc = 0.8009; test time = 3.9102 seconds
# Total time = 66.7530 seconds
# Train step 71, loss = 1.7577, acc = 0.8134; train time = 62.8467 seconds
# Test loss = 1.7625, acc = 0.8013; test time = 3.8723 seconds
# Total time = 66.7191 seconds
# Train step 72, loss = 1.7575, acc = 0.8146; train time = 62.9928 seconds
# Test loss = 1.7624, acc = 0.8023; test time = 3.8735 seconds
# Total time = 66.8664 seconds
# Train step 73, loss = 1.7576, acc = 0.8144; train time = 62.9577 seconds
# Test loss = 1.7642, acc = 0.8033; test time = 3.8540 seconds
# Total time = 66.8118 seconds
# Train step 74, loss = 1.7568, acc = 0.8144; train time = 62.7508 seconds
# Test loss = 1.7636, acc = 0.8022; test time = 3.8711 seconds
# Total time = 66.6220 seconds
# Train step 75, loss = 1.7565, acc = 0.8143; train time = 62.6308 seconds
# Test loss = 1.7615, acc = 0.8031; test time = 3.8702 seconds
# Total time = 66.5016 seconds
# Train step 76, loss = 1.7549, acc = 0.8150; train time = 62.8909 seconds
# Test loss = 1.7637, acc = 0.8028; test time = 3.8681 seconds
# Total time = 66.7591 seconds
# Train step 77, loss = 1.7564, acc = 0.8149; train time = 62.7799 seconds
# Test loss = 1.7627, acc = 0.8031; test time = 3.8333 seconds
# Total time = 66.6134 seconds
# Train step 78, loss = 1.7559, acc = 0.8157; train time = 62.7726 seconds
# Test loss = 1.7642, acc = 0.8030; test time = 3.8612 seconds
# Total time = 66.6338 seconds
# Train step 79, loss = 1.7553, acc = 0.8149; train time = 63.0398 seconds
# Test loss = 1.7626, acc = 0.8031; test time = 3.8303 seconds
# Total time = 66.8701 seconds
# Train step 80, loss = 1.7557, acc = 0.8145; train time = 62.8996 seconds
# Test loss = 1.7632, acc = 0.8044; test time = 3.8225 seconds
# Total time = 66.7222 seconds
# Train step 81, loss = 1.7549, acc = 0.8157; train time = 62.8631 seconds
# Test loss = 1.7627, acc = 0.8043; test time = 3.8307 seconds
# Total time = 66.6939 seconds
# Train step 82, loss = 1.7554, acc = 0.8168; train time = 62.8161 seconds
# Test loss = 1.7632, acc = 0.8029; test time = 3.8436 seconds
# Total time = 66.6598 seconds
# Train step 83, loss = 1.7543, acc = 0.8168; train time = 62.5881 seconds
# Test loss = 1.7604, acc = 0.8045; test time = 3.8525 seconds
# Total time = 66.4406 seconds
# Train step 84, loss = 1.7535, acc = 0.8164; train time = 62.7834 seconds
# Test loss = 1.7597, acc = 0.8024; test time = 3.9038 seconds
# Total time = 66.6872 seconds
# Train step 85, loss = 1.7541, acc = 0.8158; train time = 62.6445 seconds
# Test loss = 1.7642, acc = 0.8033; test time = 3.8395 seconds
# Total time = 66.4845 seconds
# Train step 86, loss = 1.7546, acc = 0.8164; train time = 62.8543 seconds
# Test loss = 1.7596, acc = 0.8051; test time = 3.9202 seconds
# Total time = 66.7747 seconds
# Train step 87, loss = 1.7533, acc = 0.8167; train time = 62.7932 seconds
# Test loss = 1.7590, acc = 0.8057; test time = 3.8278 seconds
# Total time = 66.6211 seconds
# Train step 88, loss = 1.7526, acc = 0.8168; train time = 62.8487 seconds
# Test loss = 1.7612, acc = 0.8058; test time = 3.8693 seconds
# Total time = 66.7181 seconds
# Train step 89, loss = 1.7534, acc = 0.8165; train time = 63.0403 seconds
# Test loss = 1.7601, acc = 0.8067; test time = 3.8551 seconds
# Total time = 66.8955 seconds
# Train step 90, loss = 1.7524, acc = 0.8177; train time = 62.8190 seconds
# Test loss = 1.7586, acc = 0.8038; test time = 3.8444 seconds
# Total time = 66.6635 seconds
# Train step 91, loss = 1.7518, acc = 0.8169; train time = 63.0141 seconds
# Test loss = 1.7603, acc = 0.8038; test time = 3.8566 seconds
# Total time = 66.8708 seconds
# Train step 92, loss = 1.7524, acc = 0.8169; train time = 62.9840 seconds
# Test loss = 1.7614, acc = 0.8057; test time = 3.8473 seconds
# Total time = 66.8314 seconds
# Train step 93, loss = 1.7522, acc = 0.8174; train time = 62.8571 seconds
# Test loss = 1.7584, acc = 0.8052; test time = 3.8504 seconds
# Total time = 66.7077 seconds
# Train step 94, loss = 1.7519, acc = 0.8174; train time = 62.9063 seconds
# Test loss = 1.7580, acc = 0.8042; test time = 3.8550 seconds
# Total time = 66.7614 seconds
# Train step 95, loss = 1.7518, acc = 0.8179; train time = 63.0007 seconds
# Test loss = 1.7591, acc = 0.8051; test time = 3.8305 seconds
# Total time = 66.8313 seconds
# Train step 96, loss = 1.7518, acc = 0.8175; train time = 62.6573 seconds
# Test loss = 1.7575, acc = 0.8042; test time = 3.8423 seconds
# Total time = 66.4997 seconds
# Train step 97, loss = 1.7503, acc = 0.8176; train time = 62.9365 seconds
# Test loss = 1.7603, acc = 0.8020; test time = 3.8558 seconds
# Total time = 66.7924 seconds
# Train step 98, loss = 1.7506, acc = 0.8185; train time = 62.7510 seconds
# Test loss = 1.7576, acc = 0.8066; test time = 3.8557 seconds
# Total time = 66.6068 seconds
# Train step 99, loss = 1.7504, acc = 0.8184; train time = 63.1092 seconds
# Test loss = 1.7595, acc = 0.8054; test time = 3.8741 seconds
# Total time = 66.9833 seconds
# ____Training with replacement_lvl = 2____
# ----Training with repetatioin = 4----
# Train step 0, loss = 2.2288, acc = 0.1001; train time = 1092.0904 seconds
# Test loss = 2.0110, acc = 0.1032; test time = 726.2865 seconds
# Total time = 1818.3771 seconds
# Train step 1, loss = 1.9516, acc = 0.2259; train time = 63.8114 seconds
# Test loss = 1.9121, acc = 0.3705; test time = 4.0472 seconds
# Total time = 67.8587 seconds
# Train step 2, loss = 1.8847, acc = 0.4966; train time = 63.9850 seconds
# Test loss = 1.8721, acc = 0.5865; test time = 4.0442 seconds
# Total time = 68.0292 seconds
# Train step 3, loss = 1.8541, acc = 0.6815; train time = 63.7673 seconds
# Test loss = 1.8509, acc = 0.7224; test time = 4.0780 seconds
# Total time = 67.8455 seconds
# Train step 4, loss = 1.8361, acc = 0.7572; train time = 63.9204 seconds
# Test loss = 1.8349, acc = 0.7574; test time = 4.0511 seconds
# Total time = 67.9716 seconds
# Train step 5, loss = 1.8255, acc = 0.7714; train time = 63.9422 seconds
# Test loss = 1.8238, acc = 0.7643; test time = 4.0319 seconds
# Total time = 67.9742 seconds
# Train step 6, loss = 1.8190, acc = 0.7749; train time = 63.7276 seconds
# Test loss = 1.8223, acc = 0.7713; test time = 4.0349 seconds
# Total time = 67.7626 seconds
# Train step 7, loss = 1.8145, acc = 0.7780; train time = 63.9080 seconds
# Test loss = 1.8198, acc = 0.7733; test time = 4.0417 seconds
# Total time = 67.9498 seconds
# Train step 8, loss = 1.8107, acc = 0.7798; train time = 63.9549 seconds
# Test loss = 1.8159, acc = 0.7755; test time = 4.0302 seconds
# Total time = 67.9852 seconds
# Train step 9, loss = 1.8071, acc = 0.7818; train time = 64.2531 seconds
# Test loss = 1.8116, acc = 0.7728; test time = 4.0508 seconds
# Total time = 68.3040 seconds
# Train step 10, loss = 1.8033, acc = 0.7831; train time = 63.9772 seconds
# Test loss = 1.8060, acc = 0.7785; test time = 4.0460 seconds
# Total time = 68.0233 seconds
# Train step 11, loss = 1.8020, acc = 0.7855; train time = 64.1622 seconds
# Test loss = 1.8075, acc = 0.7753; test time = 4.0728 seconds
# Total time = 68.2356 seconds
# Train step 12, loss = 1.7995, acc = 0.7865; train time = 63.9619 seconds
# Test loss = 1.8021, acc = 0.7780; test time = 4.0260 seconds
# Total time = 67.9880 seconds
# Train step 13, loss = 1.7966, acc = 0.7873; train time = 64.0163 seconds
# Test loss = 1.8045, acc = 0.7813; test time = 4.0396 seconds
# Total time = 68.0561 seconds
# Train step 14, loss = 1.7954, acc = 0.7893; train time = 63.8128 seconds
# Test loss = 1.7984, acc = 0.7823; test time = 4.0198 seconds
# Total time = 67.8328 seconds
# Train step 15, loss = 1.7930, acc = 0.7901; train time = 64.2123 seconds
# Test loss = 1.7972, acc = 0.7813; test time = 4.0568 seconds
# Total time = 68.2692 seconds
# Train step 16, loss = 1.7919, acc = 0.7910; train time = 63.9037 seconds
# Test loss = 1.7973, acc = 0.7831; test time = 4.0158 seconds
# Total time = 67.9196 seconds
# Train step 17, loss = 1.7906, acc = 0.7919; train time = 63.9325 seconds
# Test loss = 1.7965, acc = 0.7843; test time = 4.0476 seconds
# Total time = 67.9802 seconds
# Train step 18, loss = 1.7879, acc = 0.7924; train time = 63.8087 seconds
# Test loss = 1.7949, acc = 0.7841; test time = 4.0463 seconds
# Total time = 67.8552 seconds
# Train step 19, loss = 1.7874, acc = 0.7943; train time = 63.9475 seconds
# Test loss = 1.7923, acc = 0.7862; test time = 4.0440 seconds
# Total time = 67.9916 seconds
# Train step 20, loss = 1.7862, acc = 0.7944; train time = 63.8089 seconds
# Test loss = 1.7933, acc = 0.7875; test time = 4.0424 seconds
# Total time = 67.8520 seconds
# Train step 21, loss = 1.7861, acc = 0.7952; train time = 63.8916 seconds
# Test loss = 1.7885, acc = 0.7869; test time = 4.0745 seconds
# Total time = 67.9661 seconds
# Train step 22, loss = 1.7828, acc = 0.7961; train time = 64.3470 seconds
# Test loss = 1.7909, acc = 0.7877; test time = 4.0442 seconds
# Total time = 68.3913 seconds
# Train step 23, loss = 1.7835, acc = 0.7968; train time = 63.9948 seconds
# Test loss = 1.7888, acc = 0.7867; test time = 4.0198 seconds
# Total time = 68.0151 seconds
# Train step 24, loss = 1.7809, acc = 0.7973; train time = 63.9746 seconds
# Test loss = 1.7893, acc = 0.7884; test time = 4.0823 seconds
# Total time = 68.0570 seconds
# Train step 25, loss = 1.7797, acc = 0.7982; train time = 63.9336 seconds
# Test loss = 1.7869, acc = 0.7888; test time = 4.0192 seconds
# Total time = 67.9529 seconds
# Train step 26, loss = 1.7806, acc = 0.7990; train time = 63.7760 seconds
# Test loss = 1.7843, acc = 0.7876; test time = 4.0377 seconds
# Total time = 67.8138 seconds
# Train step 27, loss = 1.7792, acc = 0.7989; train time = 63.9047 seconds
# Test loss = 1.7864, acc = 0.7908; test time = 4.0122 seconds
# Total time = 67.9170 seconds
# Train step 28, loss = 1.7786, acc = 0.7995; train time = 63.7955 seconds
# Test loss = 1.7860, acc = 0.7881; test time = 4.0528 seconds
# Total time = 67.8489 seconds
# Train step 29, loss = 1.7769, acc = 0.8001; train time = 63.9556 seconds
# Test loss = 1.7860, acc = 0.7890; test time = 4.0445 seconds
# Total time = 68.0002 seconds
# Train step 30, loss = 1.7757, acc = 0.8009; train time = 63.7468 seconds
# Test loss = 1.7810, acc = 0.7918; test time = 4.0521 seconds
# Total time = 67.7990 seconds
# Train step 31, loss = 1.7762, acc = 0.8018; train time = 63.9434 seconds
# Test loss = 1.7820, acc = 0.7919; test time = 4.0393 seconds
# Total time = 67.9828 seconds
# Train step 32, loss = 1.7760, acc = 0.8014; train time = 63.9202 seconds
# Test loss = 1.7843, acc = 0.7910; test time = 4.0310 seconds
# Total time = 67.9514 seconds
# Train step 33, loss = 1.7748, acc = 0.8027; train time = 63.8798 seconds
# Test loss = 1.7820, acc = 0.7904; test time = 4.0378 seconds
# Total time = 67.9178 seconds
# Train step 34, loss = 1.7732, acc = 0.8028; train time = 64.0324 seconds
# Test loss = 1.7777, acc = 0.7930; test time = 4.0572 seconds
# Total time = 68.0897 seconds
# Train step 35, loss = 1.7717, acc = 0.8028; train time = 64.2000 seconds
# Test loss = 1.7779, acc = 0.7931; test time = 4.0249 seconds
# Total time = 68.2250 seconds
# Train step 36, loss = 1.7727, acc = 0.8037; train time = 63.9918 seconds
# Test loss = 1.7779, acc = 0.7915; test time = 4.0409 seconds
# Total time = 68.0328 seconds
# Train step 37, loss = 1.7724, acc = 0.8040; train time = 63.8120 seconds
# Test loss = 1.7786, acc = 0.7936; test time = 4.0852 seconds
# Total time = 67.8978 seconds
# Train step 38, loss = 1.7716, acc = 0.8051; train time = 63.9598 seconds
# Test loss = 1.7776, acc = 0.7923; test time = 4.0408 seconds
# Total time = 68.0008 seconds
# Train step 39, loss = 1.7708, acc = 0.8050; train time = 64.0488 seconds
# Test loss = 1.7792, acc = 0.7930; test time = 4.0475 seconds
# Total time = 68.0963 seconds
# Train step 40, loss = 1.7703, acc = 0.8049; train time = 64.0933 seconds
# Test loss = 1.7762, acc = 0.7938; test time = 4.0416 seconds
# Total time = 68.1349 seconds
# Train step 41, loss = 1.7696, acc = 0.8050; train time = 64.1021 seconds
# Test loss = 1.7738, acc = 0.7948; test time = 4.0425 seconds
# Total time = 68.1448 seconds
# Train step 42, loss = 1.7679, acc = 0.8052; train time = 64.0452 seconds
# Test loss = 1.7740, acc = 0.7941; test time = 4.0327 seconds
# Total time = 68.0780 seconds
# Train step 43, loss = 1.7677, acc = 0.8055; train time = 64.0161 seconds
# Test loss = 1.7765, acc = 0.7949; test time = 4.0255 seconds
# Total time = 68.0417 seconds
# Train step 44, loss = 1.7691, acc = 0.8065; train time = 64.1514 seconds
# Test loss = 1.7751, acc = 0.7976; test time = 4.0371 seconds
# Total time = 68.1886 seconds
# Train step 45, loss = 1.7675, acc = 0.8060; train time = 64.1217 seconds
# Test loss = 1.7732, acc = 0.7961; test time = 4.0403 seconds
# Total time = 68.1621 seconds
# Train step 46, loss = 1.7675, acc = 0.8071; train time = 64.2650 seconds
# Test loss = 1.7741, acc = 0.7974; test time = 4.0489 seconds
# Total time = 68.3140 seconds
# Train step 47, loss = 1.7669, acc = 0.8069; train time = 64.0377 seconds
# Test loss = 1.7752, acc = 0.7956; test time = 4.0248 seconds
# Total time = 68.0626 seconds
# Train step 48, loss = 1.7663, acc = 0.8070; train time = 63.9568 seconds
# Test loss = 1.7735, acc = 0.7976; test time = 4.0506 seconds
# Total time = 68.0075 seconds
# Train step 49, loss = 1.7661, acc = 0.8079; train time = 63.8233 seconds
# Test loss = 1.7733, acc = 0.7981; test time = 3.9997 seconds
# Total time = 67.8231 seconds
# Train step 50, loss = 1.7654, acc = 0.8077; train time = 63.7902 seconds
# Test loss = 1.7709, acc = 0.7959; test time = 4.0945 seconds
# Total time = 67.8848 seconds
# Train step 51, loss = 1.7651, acc = 0.8078; train time = 63.9969 seconds
# Test loss = 1.7720, acc = 0.7975; test time = 4.0450 seconds
# Total time = 68.0420 seconds
# Train step 52, loss = 1.7639, acc = 0.8081; train time = 64.0588 seconds
# Test loss = 1.7705, acc = 0.7989; test time = 4.0537 seconds
# Total time = 68.1127 seconds
# Train step 53, loss = 1.7645, acc = 0.8088; train time = 64.2278 seconds
# Test loss = 1.7699, acc = 0.7988; test time = 4.0653 seconds
# Total time = 68.2932 seconds
# Train step 54, loss = 1.7642, acc = 0.8092; train time = 63.7641 seconds
# Test loss = 1.7700, acc = 0.7977; test time = 4.0275 seconds
# Total time = 67.7917 seconds
# Train step 55, loss = 1.7627, acc = 0.8089; train time = 64.0301 seconds
# Test loss = 1.7695, acc = 0.7983; test time = 4.0524 seconds
# Total time = 68.0827 seconds
# Train step 56, loss = 1.7639, acc = 0.8094; train time = 63.8476 seconds
# Test loss = 1.7702, acc = 0.8000; test time = 4.0264 seconds
# Total time = 67.8741 seconds
# Train step 57, loss = 1.7640, acc = 0.8095; train time = 64.0479 seconds
# Test loss = 1.7687, acc = 0.7994; test time = 4.0351 seconds
# Total time = 68.0831 seconds
# Train step 58, loss = 1.7615, acc = 0.8094; train time = 64.1054 seconds
# Test loss = 1.7687, acc = 0.7990; test time = 4.0326 seconds
# Total time = 68.1381 seconds
# Train step 59, loss = 1.7626, acc = 0.8102; train time = 64.1098 seconds
# Test loss = 1.7684, acc = 0.8012; test time = 4.0476 seconds
# Total time = 68.1575 seconds
# Train step 60, loss = 1.7610, acc = 0.8104; train time = 64.0420 seconds
# Test loss = 1.7676, acc = 0.8006; test time = 4.0378 seconds
# Total time = 68.0799 seconds
# Train step 61, loss = 1.7602, acc = 0.8100; train time = 63.8064 seconds
# Test loss = 1.7686, acc = 0.7999; test time = 4.0665 seconds
# Total time = 67.8735 seconds
# Train step 62, loss = 1.7620, acc = 0.8100; train time = 64.0475 seconds
# Test loss = 1.7669, acc = 0.8009; test time = 4.0225 seconds
# Total time = 68.0701 seconds
# Train step 63, loss = 1.7608, acc = 0.8110; train time = 64.0884 seconds
# Test loss = 1.7665, acc = 0.8007; test time = 6.8889 seconds
# Total time = 70.9774 seconds
# Train step 64, loss = 1.7593, acc = 0.8109; train time = 64.0892 seconds
# Test loss = 1.7663, acc = 0.8004; test time = 4.0512 seconds
# Total time = 68.1406 seconds
# Train step 65, loss = 1.7586, acc = 0.8115; train time = 63.7275 seconds
# Test loss = 1.7668, acc = 0.7981; test time = 4.0762 seconds
# Total time = 67.8038 seconds
# Train step 66, loss = 1.7583, acc = 0.8110; train time = 63.9600 seconds
# Test loss = 1.7652, acc = 0.8003; test time = 4.0258 seconds
# Total time = 67.9859 seconds
# Train step 67, loss = 1.7589, acc = 0.8116; train time = 63.9540 seconds
# Test loss = 1.7664, acc = 0.8022; test time = 4.0574 seconds
# Total time = 68.0116 seconds
# Train step 68, loss = 1.7592, acc = 0.8122; train time = 63.7436 seconds
# Test loss = 1.7640, acc = 0.8013; test time = 4.0581 seconds
# Total time = 67.8017 seconds
# Train step 69, loss = 1.7578, acc = 0.8120; train time = 63.8834 seconds
# Test loss = 1.7684, acc = 0.8000; test time = 4.0705 seconds
# Total time = 67.9542 seconds
# Train step 70, loss = 1.7583, acc = 0.8130; train time = 64.1302 seconds
# Test loss = 1.7663, acc = 0.8010; test time = 4.0706 seconds
# Total time = 68.2009 seconds
# Train step 71, loss = 1.7580, acc = 0.8126; train time = 63.8263 seconds
# Test loss = 1.7643, acc = 0.8014; test time = 4.0344 seconds
# Total time = 67.8608 seconds
# Train step 72, loss = 1.7580, acc = 0.8127; train time = 63.8630 seconds
# Test loss = 1.7637, acc = 0.8011; test time = 4.0982 seconds
# Total time = 67.9613 seconds
# Train step 73, loss = 1.7586, acc = 0.8133; train time = 64.2059 seconds
# Test loss = 1.7668, acc = 0.8029; test time = 4.0203 seconds
# Total time = 68.2263 seconds
# Train step 74, loss = 1.7573, acc = 0.8136; train time = 63.9799 seconds
# Test loss = 1.7660, acc = 0.8049; test time = 4.0326 seconds
# Total time = 68.0125 seconds
# Train step 75, loss = 1.7578, acc = 0.8135; train time = 63.9260 seconds
# Test loss = 1.7629, acc = 0.8027; test time = 4.0616 seconds
# Total time = 67.9877 seconds
# Train step 76, loss = 1.7567, acc = 0.8132; train time = 63.9975 seconds
# Test loss = 1.7622, acc = 0.8026; test time = 4.0517 seconds
# Total time = 68.0493 seconds
# Train step 77, loss = 1.7566, acc = 0.8129; train time = 63.9786 seconds
# Test loss = 1.7619, acc = 0.8025; test time = 4.0154 seconds
# Total time = 67.9941 seconds
# Train step 78, loss = 1.7571, acc = 0.8140; train time = 63.9717 seconds
# Test loss = 1.7624, acc = 0.8004; test time = 4.0939 seconds
# Total time = 68.0658 seconds
# Train step 79, loss = 1.7564, acc = 0.8136; train time = 63.8831 seconds
# Test loss = 1.7644, acc = 0.8029; test time = 4.0602 seconds
# Total time = 67.9434 seconds
# Train step 80, loss = 1.7556, acc = 0.8143; train time = 64.0280 seconds
# Test loss = 1.7650, acc = 0.8023; test time = 4.0495 seconds
# Total time = 68.0777 seconds
# Train step 81, loss = 1.7544, acc = 0.8139; train time = 64.2266 seconds
# Test loss = 1.7621, acc = 0.8022; test time = 4.0913 seconds
# Total time = 68.3181 seconds
# Train step 82, loss = 1.7561, acc = 0.8145; train time = 63.7789 seconds
# Test loss = 1.7597, acc = 0.8032; test time = 4.0850 seconds
# Total time = 67.8640 seconds
# Train step 83, loss = 1.7546, acc = 0.8147; train time = 63.9403 seconds
# Test loss = 1.7605, acc = 0.8047; test time = 4.0354 seconds
# Total time = 67.9758 seconds
# Train step 84, loss = 1.7548, acc = 0.8148; train time = 64.0356 seconds
# Test loss = 1.7619, acc = 0.8021; test time = 4.0432 seconds
# Total time = 68.0789 seconds
# Train step 85, loss = 1.7551, acc = 0.8147; train time = 64.1706 seconds
# Test loss = 1.7620, acc = 0.8053; test time = 4.0803 seconds
# Total time = 68.2511 seconds
# Train step 86, loss = 1.7547, acc = 0.8158; train time = 64.0904 seconds
# Test loss = 1.7622, acc = 0.8045; test time = 4.0529 seconds
# Total time = 68.1434 seconds
# Train step 87, loss = 1.7540, acc = 0.8150; train time = 64.1209 seconds
# Test loss = 1.7591, acc = 0.8047; test time = 4.0567 seconds
# Total time = 68.1776 seconds
# Train step 88, loss = 1.7539, acc = 0.8156; train time = 63.9430 seconds
# Test loss = 1.7621, acc = 0.8045; test time = 4.0833 seconds
# Total time = 68.0264 seconds
# Train step 89, loss = 1.7543, acc = 0.8160; train time = 63.8802 seconds
# Test loss = 1.7597, acc = 0.8052; test time = 4.0619 seconds
# Total time = 67.9422 seconds
# Train step 90, loss = 1.7528, acc = 0.8156; train time = 64.0852 seconds
# Test loss = 1.7596, acc = 0.8060; test time = 4.0351 seconds
# Total time = 68.1205 seconds
# Train step 91, loss = 1.7536, acc = 0.8158; train time = 64.3131 seconds
# Test loss = 1.7583, acc = 0.8062; test time = 4.0594 seconds
# Total time = 68.3727 seconds
# Train step 92, loss = 1.7524, acc = 0.8156; train time = 64.0698 seconds
# Test loss = 1.7581, acc = 0.8059; test time = 4.0766 seconds
# Total time = 68.1466 seconds
# Train step 93, loss = 1.7524, acc = 0.8158; train time = 64.1826 seconds
# Test loss = 1.7595, acc = 0.8061; test time = 4.0596 seconds
# Total time = 68.2423 seconds
# Train step 94, loss = 1.7526, acc = 0.8163; train time = 63.7849 seconds
# Test loss = 1.7587, acc = 0.8055; test time = 4.0838 seconds
# Total time = 67.8689 seconds
# Train step 95, loss = 1.7511, acc = 0.8164; train time = 64.2283 seconds
# Test loss = 1.7591, acc = 0.8049; test time = 4.0341 seconds
# Total time = 68.2625 seconds
# Train step 96, loss = 1.7524, acc = 0.8167; train time = 63.9444 seconds
# Test loss = 1.7581, acc = 0.8055; test time = 4.0420 seconds
# Total time = 67.9865 seconds
# Train step 97, loss = 1.7524, acc = 0.8165; train time = 63.7619 seconds
# Test loss = 1.7570, acc = 0.8056; test time = 4.0199 seconds
# Total time = 67.7819 seconds
# Train step 98, loss = 1.7524, acc = 0.8169; train time = 63.8238 seconds
# Test loss = 1.7572, acc = 0.8056; test time = 4.0607 seconds
# Total time = 67.8846 seconds
# Train step 99, loss = 1.7525, acc = 0.8170; train time = 64.2284 seconds
# Test loss = 1.7597, acc = 0.8055; test time = 4.0597 seconds
# Total time = 68.2887 seconds
# ____Training with replacement_lvl = 1____
# ----Training with repetatioin = 0----
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py:2740: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# Train step 0, loss = 16.1340, acc = 0.5448; train time = 95.9984 seconds
# Test loss = 1.6580, acc = 0.7306; test time = 20.3821 seconds
# Total time = 116.3809 seconds
# Train step 1, loss = 0.9734, acc = 0.7808; train time = 44.7418 seconds
# Test loss = 0.7815, acc = 0.7527; test time = 2.7423 seconds
# Total time = 47.4843 seconds
# Train step 2, loss = 0.6367, acc = 0.7923; train time = 44.7654 seconds
# Test loss = 0.6169, acc = 0.7854; test time = 2.7882 seconds
# Total time = 47.5537 seconds
# Train step 3, loss = 0.5610, acc = 0.8076; train time = 44.7219 seconds
# Test loss = 0.5700, acc = 0.7987; test time = 2.7924 seconds
# Total time = 47.5145 seconds
# Train step 4, loss = 0.5381, acc = 0.8133; train time = 44.8180 seconds
# Test loss = 0.5682, acc = 0.7972; test time = 2.7385 seconds
# Total time = 47.5567 seconds
# Train step 5, loss = 0.5104, acc = 0.8232; train time = 44.6044 seconds
# Test loss = 0.5431, acc = 0.8002; test time = 2.8062 seconds
# Total time = 47.4107 seconds
# Train step 6, loss = 0.5696, acc = 0.8135; train time = 44.9402 seconds
# Test loss = 0.5086, acc = 0.8192; test time = 2.7939 seconds
# Total time = 47.7344 seconds
# Train step 7, loss = 0.4857, acc = 0.8334; train time = 44.8535 seconds
# Test loss = 0.5089, acc = 0.8231; test time = 2.7744 seconds
# Total time = 47.6280 seconds
# Train step 8, loss = 0.4746, acc = 0.8370; train time = 44.8662 seconds
# Test loss = 0.5057, acc = 0.8172; test time = 2.7295 seconds
# Total time = 47.5958 seconds
# Train step 9, loss = 0.4910, acc = 0.8314; train time = 44.8159 seconds
# Test loss = 0.5236, acc = 0.8141; test time = 2.7368 seconds
# Total time = 47.5527 seconds
# Train step 10, loss = 0.4606, acc = 0.8417; train time = 45.0863 seconds
# Test loss = 0.4874, acc = 0.8272; test time = 2.7559 seconds
# Total time = 47.8422 seconds
# Train step 11, loss = 0.4558, acc = 0.8418; train time = 44.8841 seconds
# Test loss = 0.5229, acc = 0.8095; test time = 2.7838 seconds
# Total time = 47.6680 seconds
# Train step 12, loss = 0.4522, acc = 0.8449; train time = 44.7536 seconds
# Test loss = 0.5147, acc = 0.8218; test time = 2.7545 seconds
# Total time = 47.5082 seconds
# Train step 13, loss = 0.4460, acc = 0.8473; train time = 44.7468 seconds
# Test loss = 0.4729, acc = 0.8363; test time = 2.7842 seconds
# Total time = 47.5312 seconds
# Train step 14, loss = 0.4291, acc = 0.8537; train time = 44.7000 seconds
# Test loss = 0.4678, acc = 0.8377; test time = 2.7713 seconds
# Total time = 47.4715 seconds
# Train step 15, loss = 0.4350, acc = 0.8510; train time = 44.4347 seconds
# Test loss = 0.4603, acc = 0.8379; test time = 2.7733 seconds
# Total time = 47.2081 seconds
# Train step 16, loss = 0.4307, acc = 0.8529; train time = 44.4391 seconds
# Test loss = 0.4918, acc = 0.8249; test time = 2.7695 seconds
# Total time = 47.2088 seconds
# Train step 17, loss = 0.4300, acc = 0.8538; train time = 44.9065 seconds
# Test loss = 0.4794, acc = 0.8288; test time = 2.7464 seconds
# Total time = 47.6531 seconds
# Train step 18, loss = 0.4210, acc = 0.8569; train time = 44.7374 seconds
# Test loss = 0.4727, acc = 0.8285; test time = 2.7977 seconds
# Total time = 47.5352 seconds
# Train step 19, loss = 0.4284, acc = 0.8525; train time = 44.9519 seconds
# Test loss = 0.4780, acc = 0.8357; test time = 2.7633 seconds
# Total time = 47.7153 seconds
# Train step 20, loss = 0.4201, acc = 0.8570; train time = 44.4504 seconds
# Test loss = 0.4957, acc = 0.8328; test time = 2.7553 seconds
# Total time = 47.2058 seconds
# Train step 21, loss = 0.4193, acc = 0.8564; train time = 44.9263 seconds
# Test loss = 0.4664, acc = 0.8376; test time = 2.7916 seconds
# Total time = 47.7180 seconds
# Train step 22, loss = 0.4094, acc = 0.8603; train time = 44.6507 seconds
# Test loss = 0.4858, acc = 0.8309; test time = 2.7683 seconds
# Total time = 47.4191 seconds
# Train step 23, loss = 0.4039, acc = 0.8617; train time = 44.8116 seconds
# Test loss = 0.4586, acc = 0.8406; test time = 2.7587 seconds
# Total time = 47.5705 seconds
# Train step 24, loss = 0.4027, acc = 0.8612; train time = 44.8511 seconds
# Test loss = 0.4847, acc = 0.8311; test time = 2.7397 seconds
# Total time = 47.5910 seconds
# Train step 25, loss = 0.4007, acc = 0.8626; train time = 44.8730 seconds
# Test loss = 0.4552, acc = 0.8453; test time = 2.7633 seconds
# Total time = 47.6364 seconds
# Train step 26, loss = 0.4013, acc = 0.8633; train time = 44.6606 seconds
# Test loss = 0.4589, acc = 0.8417; test time = 2.7733 seconds
# Total time = 47.4341 seconds
# Train step 27, loss = 0.4060, acc = 0.8598; train time = 44.6385 seconds
# Test loss = 0.4539, acc = 0.8444; test time = 2.7495 seconds
# Total time = 47.3887 seconds
# Train step 28, loss = 0.3997, acc = 0.8627; train time = 44.4249 seconds
# Test loss = 0.4741, acc = 0.8248; test time = 2.7378 seconds
# Total time = 47.1633 seconds
# Train step 29, loss = 0.4014, acc = 0.8624; train time = 44.6070 seconds
# Test loss = 0.5004, acc = 0.8254; test time = 2.7434 seconds
# Total time = 47.3505 seconds
# Train step 30, loss = 0.4074, acc = 0.8611; train time = 44.8729 seconds
# Test loss = 0.4506, acc = 0.8438; test time = 2.7619 seconds
# Total time = 47.6348 seconds
# Train step 31, loss = 0.3966, acc = 0.8640; train time = 44.6700 seconds
# Test loss = 0.4637, acc = 0.8434; test time = 2.7464 seconds
# Total time = 47.4165 seconds
# Train step 32, loss = 0.3902, acc = 0.8659; train time = 44.6817 seconds
# Test loss = 0.4774, acc = 0.8336; test time = 2.7727 seconds
# Total time = 47.4546 seconds
# Train step 33, loss = 0.3844, acc = 0.8678; train time = 44.6735 seconds
# Test loss = 0.4575, acc = 0.8393; test time = 2.7719 seconds
# Total time = 47.4454 seconds
# Train step 34, loss = 0.3880, acc = 0.8673; train time = 45.0232 seconds
# Test loss = 0.4593, acc = 0.8425; test time = 2.8030 seconds
# Total time = 47.8263 seconds
# Train step 35, loss = 0.3901, acc = 0.8659; train time = 44.6523 seconds
# Test loss = 0.4557, acc = 0.8405; test time = 2.7376 seconds
# Total time = 47.3901 seconds
# Train step 36, loss = 0.3871, acc = 0.8672; train time = 44.4178 seconds
# Test loss = 0.4988, acc = 0.8224; test time = 2.7485 seconds
# Total time = 47.1664 seconds
# Train step 37, loss = 0.3945, acc = 0.8627; train time = 44.8844 seconds
# Test loss = 0.4615, acc = 0.8336; test time = 2.7420 seconds
# Total time = 47.6264 seconds
# Train step 38, loss = 0.3858, acc = 0.8679; train time = 44.8952 seconds
# Test loss = 0.5059, acc = 0.8321; test time = 2.7435 seconds
# Total time = 47.6388 seconds
# Train step 39, loss = 0.3826, acc = 0.8687; train time = 44.8646 seconds
# Test loss = 0.4556, acc = 0.8377; test time = 2.7647 seconds
# Total time = 47.6294 seconds
# Train step 40, loss = 0.3808, acc = 0.8688; train time = 44.9217 seconds
# Test loss = 0.4587, acc = 0.8384; test time = 5.6762 seconds
# Total time = 50.5980 seconds
# Train step 41, loss = 0.3801, acc = 0.8686; train time = 44.9136 seconds
# Test loss = 0.4756, acc = 0.8330; test time = 2.7662 seconds
# Total time = 47.6800 seconds
# Train step 42, loss = 0.3770, acc = 0.8693; train time = 45.0180 seconds
# Test loss = 0.4620, acc = 0.8403; test time = 2.7637 seconds
# Total time = 47.7825 seconds
# Train step 43, loss = 0.3769, acc = 0.8696; train time = 44.6693 seconds
# Test loss = 0.4649, acc = 0.8360; test time = 2.7562 seconds
# Total time = 47.4257 seconds
# Train step 44, loss = 0.3771, acc = 0.8701; train time = 44.4690 seconds
# Test loss = 0.4603, acc = 0.8386; test time = 2.7575 seconds
# Total time = 47.2267 seconds
# Train step 45, loss = 0.3753, acc = 0.8706; train time = 44.4847 seconds
# Test loss = 0.4591, acc = 0.8422; test time = 2.7662 seconds
# Total time = 47.2510 seconds
# Train step 46, loss = 0.3779, acc = 0.8701; train time = 44.5733 seconds
# Test loss = 0.4549, acc = 0.8427; test time = 2.7480 seconds
# Total time = 47.3215 seconds
# Train step 47, loss = 0.3794, acc = 0.8697; train time = 44.6223 seconds
# Test loss = 0.4632, acc = 0.8408; test time = 2.7669 seconds
# Total time = 47.3899 seconds
# Train step 48, loss = 0.3707, acc = 0.8716; train time = 44.3608 seconds
# Test loss = 0.4606, acc = 0.8415; test time = 2.7365 seconds
# Total time = 47.0974 seconds
# Train step 49, loss = 0.3724, acc = 0.8708; train time = 44.5766 seconds
# Test loss = 0.4747, acc = 0.8332; test time = 2.7378 seconds
# Total time = 47.3145 seconds
# Train step 50, loss = 0.3746, acc = 0.8703; train time = 44.9257 seconds
# Test loss = 0.4599, acc = 0.8414; test time = 2.7954 seconds
# Total time = 47.7212 seconds
# Train step 51, loss = 0.3788, acc = 0.8693; train time = 44.6401 seconds
# Test loss = 0.4803, acc = 0.8277; test time = 2.7519 seconds
# Total time = 47.3921 seconds
# Train step 52, loss = 0.3685, acc = 0.8732; train time = 44.7216 seconds
# Test loss = 0.4581, acc = 0.8412; test time = 2.7822 seconds
# Total time = 47.5039 seconds
# Train step 53, loss = 0.3703, acc = 0.8718; train time = 44.3556 seconds
# Test loss = 0.4700, acc = 0.8341; test time = 2.7585 seconds
# Total time = 47.1142 seconds
# Train step 54, loss = 0.3677, acc = 0.8726; train time = 44.8245 seconds
# Test loss = 0.4647, acc = 0.8383; test time = 2.7795 seconds
# Total time = 47.6041 seconds
# Train step 55, loss = 0.3671, acc = 0.8734; train time = 44.7719 seconds
# Test loss = 0.4679, acc = 0.8389; test time = 2.7852 seconds
# Total time = 47.5572 seconds
# Train step 56, loss = 0.3687, acc = 0.8713; train time = 44.8182 seconds
# Test loss = 0.4643, acc = 0.8393; test time = 2.8305 seconds
# Total time = 47.6489 seconds
# Train step 57, loss = 0.3672, acc = 0.8723; train time = 44.8599 seconds
# Test loss = 0.4806, acc = 0.8356; test time = 2.8001 seconds
# Total time = 47.6601 seconds
# Train step 58, loss = 0.3709, acc = 0.8713; train time = 45.0304 seconds
# Test loss = 0.4613, acc = 0.8380; test time = 2.8321 seconds
# Total time = 47.8626 seconds
# Train step 59, loss = 0.3634, acc = 0.8753; train time = 44.8753 seconds
# Test loss = 0.4626, acc = 0.8395; test time = 2.7558 seconds
# Total time = 47.6313 seconds
# Train step 60, loss = 0.3680, acc = 0.8721; train time = 44.7632 seconds
# Test loss = 0.4751, acc = 0.8376; test time = 2.7908 seconds
# Total time = 47.5542 seconds
# Train step 61, loss = 0.3641, acc = 0.8737; train time = 44.7839 seconds
# Test loss = 0.4660, acc = 0.8373; test time = 2.7934 seconds
# Total time = 47.5773 seconds
# Train step 62, loss = 0.3696, acc = 0.8723; train time = 44.6729 seconds
# Test loss = 0.4588, acc = 0.8403; test time = 2.7687 seconds
# Total time = 47.4417 seconds
# Train step 63, loss = 0.3618, acc = 0.8744; train time = 44.5008 seconds
# Test loss = 0.4673, acc = 0.8373; test time = 2.7685 seconds
# Total time = 47.2694 seconds
# Train step 64, loss = 0.3606, acc = 0.8744; train time = 44.7700 seconds
# Test loss = 0.4646, acc = 0.8405; test time = 2.7475 seconds
# Total time = 47.5181 seconds
# Train step 65, loss = 0.3618, acc = 0.8743; train time = 44.3153 seconds
# Test loss = 0.4622, acc = 0.8392; test time = 2.7335 seconds
# Total time = 47.0495 seconds
# Train step 66, loss = 0.3616, acc = 0.8751; train time = 44.8983 seconds
# Test loss = 0.4666, acc = 0.8368; test time = 2.7554 seconds
# Total time = 47.6538 seconds
# Train step 67, loss = 0.3643, acc = 0.8744; train time = 44.6080 seconds
# Test loss = 0.4681, acc = 0.8396; test time = 2.7243 seconds
# Total time = 47.3324 seconds
# Train step 68, loss = 0.3604, acc = 0.8748; train time = 44.4114 seconds
# Test loss = 0.4673, acc = 0.8385; test time = 2.7518 seconds
# Total time = 47.1634 seconds
# Train step 69, loss = 0.3612, acc = 0.8750; train time = 44.3891 seconds
# Test loss = 0.4646, acc = 0.8386; test time = 2.7506 seconds
# Total time = 47.1398 seconds
# Train step 70, loss = 0.3587, acc = 0.8755; train time = 44.8324 seconds
# Test loss = 0.4750, acc = 0.8327; test time = 2.7530 seconds
# Total time = 47.5855 seconds
# Train step 71, loss = 0.3613, acc = 0.8740; train time = 44.6362 seconds
# Test loss = 0.4734, acc = 0.8387; test time = 2.7444 seconds
# Total time = 47.3807 seconds
# Train step 72, loss = 0.3607, acc = 0.8749; train time = 45.0201 seconds
# Test loss = 0.4716, acc = 0.8394; test time = 2.7580 seconds
# Total time = 47.7782 seconds
# Train step 73, loss = 0.3586, acc = 0.8754; train time = 44.8745 seconds
# Test loss = 0.4712, acc = 0.8389; test time = 2.7436 seconds
# Total time = 47.6182 seconds
# Train step 74, loss = 0.3596, acc = 0.8754; train time = 44.6983 seconds
# Test loss = 0.4642, acc = 0.8394; test time = 2.7591 seconds
# Total time = 47.4576 seconds
# Train step 75, loss = 0.3592, acc = 0.8758; train time = 44.7518 seconds
# Test loss = 0.4655, acc = 0.8417; test time = 2.7439 seconds
# Total time = 47.4957 seconds
# ...
# Total time = 16.8234 seconds
# Train step 2, loss = 0.4293, acc = 0.8552; train time = 14.4164 seconds
# Test loss = 0.4619, acc = 0.8369; test time = 2.4216 seconds
# Total time = 16.8381 seconds
# Train step 3, loss = 0.4220, acc = 0.8592; train time = 14.3742 seconds
# Test loss = 0.4748, acc = 0.8312; test time = 2.4213 seconds
# Total time = 16.7956 seconds
# Train step 4, loss = 0.4119, acc = 0.8607; train time = 14.3659 seconds
# Test loss = 0.4715, acc = 0.8347; test time = 2.4074 seconds
# Total time = 16.7740 seconds
# Train step 5, loss = 0.4058, acc = 0.8618; train time = 14.5031 seconds
# Test loss = 0.4666, acc = 0.8358; test time = 2.3662 seconds
# Total time = 16.8693 seconds
# Train step 6, loss = 0.3984, acc = 0.8630; train time = 14.4455 seconds
# Test loss = 0.4588, acc = 0.8365; test time = 2.3885 seconds
# Total time = 16.8341 seconds
# Train step 7, loss = 0.3955, acc = 0.8648; train time = 14.4361 seconds
# Test loss = 0.4554, acc = 0.8372; test time = 2.3781 seconds
# Total time = 16.8142 seconds
# Train step 8, loss = 0.3912, acc = 0.8666; train time = 14.3333 seconds
# Test loss = 0.4607, acc = 0.8360; test time = 2.3283 seconds
# Total time = 16.6617 seconds
# Train step 9, loss = 0.3897, acc = 0.8668; train time = 14.3254 seconds
# Test loss = 0.4670, acc = 0.8366; test time = 2.3617 seconds
# Total time = 16.6872 seconds
# Train step 10, loss = 0.3873, acc = 0.8694; train time = 14.3594 seconds
# Test loss = 0.4642, acc = 0.8356; test time = 2.3778 seconds
# Total time = 16.7377 seconds
# Train step 11, loss = 0.3849, acc = 0.8685; train time = 14.2599 seconds
# Test loss = 0.4657, acc = 0.8369; test time = 2.3807 seconds
# Total time = 16.6406 seconds
# Train step 12, loss = 0.3815, acc = 0.8694; train time = 14.3908 seconds
# Test loss = 0.4605, acc = 0.8385; test time = 2.4095 seconds
# Total time = 16.8004 seconds
# Train step 13, loss = 0.3813, acc = 0.8688; train time = 14.4068 seconds
# Test loss = 0.4619, acc = 0.8388; test time = 2.3506 seconds
# Total time = 16.7575 seconds
# Train step 14, loss = 0.3834, acc = 0.8682; train time = 14.3608 seconds
# Test loss = 0.4686, acc = 0.8327; test time = 2.3856 seconds
# Total time = 16.7465 seconds
# Train step 15, loss = 0.3851, acc = 0.8682; train time = 14.2871 seconds
# Test loss = 0.4787, acc = 0.8348; test time = 2.3721 seconds
# Total time = 16.6594 seconds
# Train step 16, loss = 0.3802, acc = 0.8710; train time = 14.2490 seconds
# Test loss = 0.4621, acc = 0.8380; test time = 2.3760 seconds
# Total time = 16.6251 seconds
# Train step 17, loss = 0.3796, acc = 0.8703; train time = 14.3799 seconds
# Test loss = 0.4663, acc = 0.8344; test time = 2.3981 seconds
# Total time = 16.7781 seconds
# Train step 18, loss = 0.3773, acc = 0.8711; train time = 14.3664 seconds
# Test loss = 0.4701, acc = 0.8350; test time = 2.3790 seconds
# Total time = 16.7455 seconds
# Train step 19, loss = 0.3805, acc = 0.8704; train time = 14.4201 seconds
# Test loss = 0.4621, acc = 0.8358; test time = 2.3814 seconds
# Total time = 16.8016 seconds
# Train step 20, loss = 0.3783, acc = 0.8709; train time = 14.2850 seconds
# Test loss = 0.4737, acc = 0.8395; test time = 2.3732 seconds
# Total time = 16.6582 seconds
# Train step 21, loss = 0.3777, acc = 0.8710; train time = 14.4364 seconds
# Test loss = 0.4658, acc = 0.8388; test time = 2.3872 seconds
# Total time = 16.8237 seconds
# Train step 22, loss = 0.3753, acc = 0.8707; train time = 14.3414 seconds
# Test loss = 0.4663, acc = 0.8404; test time = 2.3663 seconds
# Total time = 16.7078 seconds
# Train step 23, loss = 0.3750, acc = 0.8717; train time = 14.4054 seconds
# Test loss = 0.4611, acc = 0.8396; test time = 2.3882 seconds
# Total time = 16.7939 seconds
# Train step 24, loss = 0.3737, acc = 0.8725; train time = 14.3434 seconds
# Test loss = 0.4679, acc = 0.8368; test time = 2.4083 seconds
# Total time = 16.7518 seconds
# Train step 25, loss = 0.3744, acc = 0.8719; train time = 14.4096 seconds
# Test loss = 0.4802, acc = 0.8344; test time = 2.3897 seconds
# Total time = 16.7995 seconds
# Train step 26, loss = 0.3769, acc = 0.8708; train time = 14.3169 seconds
# Test loss = 0.4705, acc = 0.8378; test time = 2.3783 seconds
# Total time = 16.6953 seconds
# Train step 27, loss = 0.3704, acc = 0.8723; train time = 14.3283 seconds
# Test loss = 0.4662, acc = 0.8365; test time = 2.3719 seconds
# Total time = 16.7003 seconds
# Train step 28, loss = 0.3752, acc = 0.8723; train time = 14.2212 seconds
# Test loss = 0.4643, acc = 0.8335; test time = 2.3618 seconds
# Total time = 16.5830 seconds
# Train step 29, loss = 0.3711, acc = 0.8719; train time = 14.3779 seconds
# Test loss = 0.4656, acc = 0.8395; test time = 2.3788 seconds
# Total time = 16.7569 seconds
# Train step 30, loss = 0.3717, acc = 0.8725; train time = 14.4004 seconds
# Test loss = 0.4760, acc = 0.8354; test time = 2.4059 seconds
# Total time = 16.8064 seconds
# Train step 31, loss = 0.3714, acc = 0.8730; train time = 14.2958 seconds
# Test loss = 0.4736, acc = 0.8360; test time = 2.3751 seconds
# Total time = 16.6710 seconds
# Train step 32, loss = 0.3741, acc = 0.8714; train time = 14.5190 seconds
# Test loss = 0.4781, acc = 0.8385; test time = 2.4301 seconds
# Total time = 16.9492 seconds
# Train step 33, loss = 0.3714, acc = 0.8733; train time = 14.3878 seconds
# Test loss = 0.4725, acc = 0.8362; test time = 2.3491 seconds
# Total time = 16.7370 seconds
# Train step 34, loss = 0.3698, acc = 0.8728; train time = 14.3573 seconds
# Test loss = 0.4720, acc = 0.8340; test time = 2.3675 seconds
# Total time = 16.7249 seconds
# Train step 35, loss = 0.3705, acc = 0.8731; train time = 14.3072 seconds
# Test loss = 0.4828, acc = 0.8340; test time = 2.3539 seconds
# Total time = 16.6613 seconds
# Train step 36, loss = 0.3708, acc = 0.8719; train time = 14.2548 seconds
# Test loss = 0.4722, acc = 0.8358; test time = 2.3561 seconds
# Total time = 16.6110 seconds
# Train step 37, loss = 0.3680, acc = 0.8738; train time = 14.3495 seconds
# Test loss = 0.4683, acc = 0.8365; test time = 2.3807 seconds
# Total time = 16.7303 seconds
# Train step 38, loss = 0.3664, acc = 0.8749; train time = 14.3030 seconds
# Test loss = 0.4731, acc = 0.8337; test time = 2.4050 seconds
# Total time = 16.7081 seconds
# Train step 39, loss = 0.3687, acc = 0.8739; train time = 14.3387 seconds
# Test loss = 0.4651, acc = 0.8357; test time = 2.3870 seconds
# Total time = 16.7258 seconds
# Train step 40, loss = 0.3692, acc = 0.8734; train time = 14.3608 seconds
# Test loss = 0.4652, acc = 0.8382; test time = 2.3491 seconds
# Total time = 16.7100 seconds
# Train step 41, loss = 0.3659, acc = 0.8740; train time = 14.3211 seconds
# Test loss = 0.4826, acc = 0.8340; test time = 2.3656 seconds
# Total time = 16.6869 seconds
# Train step 42, loss = 0.3655, acc = 0.8738; train time = 14.2944 seconds
# Test loss = 0.4751, acc = 0.8349; test time = 2.3783 seconds
# Total time = 16.6728 seconds
# Train step 43, loss = 0.3687, acc = 0.8723; train time = 14.4055 seconds
# Test loss = 0.4783, acc = 0.8323; test time = 2.3460 seconds
# Total time = 16.7517 seconds
# Train step 44, loss = 0.3663, acc = 0.8730; train time = 14.2832 seconds
# Test loss = 0.4671, acc = 0.8413; test time = 2.3495 seconds
# Total time = 16.6327 seconds
# Train step 45, loss = 0.3652, acc = 0.8748; train time = 14.2933 seconds
# Test loss = 0.4711, acc = 0.8387; test time = 2.3440 seconds
# Total time = 16.6374 seconds
# Train step 46, loss = 0.3634, acc = 0.8745; train time = 14.2682 seconds
# Test loss = 0.4755, acc = 0.8374; test time = 2.3599 seconds
# Total time = 16.6283 seconds
# Train step 47, loss = 0.3662, acc = 0.8734; train time = 14.2650 seconds
# Test loss = 0.4718, acc = 0.8385; test time = 2.3510 seconds
# Total time = 16.6161 seconds
# Train step 48, loss = 0.3665, acc = 0.8733; train time = 14.3775 seconds
# Test loss = 0.4835, acc = 0.8335; test time = 2.3936 seconds
# Total time = 16.7712 seconds
# Train step 49, loss = 0.3647, acc = 0.8741; train time = 14.4144 seconds
# Test loss = 0.4745, acc = 0.8386; test time = 2.4075 seconds
# Total time = 16.8220 seconds
# Train step 50, loss = 0.3624, acc = 0.8750; train time = 17.4886 seconds
# Test loss = 0.4684, acc = 0.8360; test time = 2.3746 seconds
# Total time = 19.8634 seconds
# Train step 51, loss = 0.3629, acc = 0.8755; train time = 14.4944 seconds
# Test loss = 0.4742, acc = 0.8332; test time = 2.3880 seconds
# Total time = 16.8825 seconds
# Train step 52, loss = 0.3623, acc = 0.8743; train time = 14.3802 seconds
# Test loss = 0.4817, acc = 0.8322; test time = 2.4086 seconds
# Total time = 16.7889 seconds
# Train step 53, loss = 0.3630, acc = 0.8754; train time = 14.3810 seconds
# Test loss = 0.4720, acc = 0.8385; test time = 2.3645 seconds
# Total time = 16.7457 seconds
# Train step 54, loss = 0.3638, acc = 0.8739; train time = 14.3964 seconds
# Test loss = 0.4789, acc = 0.8339; test time = 2.3727 seconds
# Total time = 16.7693 seconds
# Train step 55, loss = 0.3635, acc = 0.8745; train time = 14.4323 seconds
# Test loss = 0.4755, acc = 0.8360; test time = 2.3928 seconds
# Total time = 16.8252 seconds
# Train step 56, loss = 0.3610, acc = 0.8758; train time = 14.3649 seconds
# Test loss = 0.4738, acc = 0.8353; test time = 2.4657 seconds
# Total time = 16.8306 seconds
# Train step 57, loss = 0.3626, acc = 0.8748; train time = 14.4509 seconds
# Test loss = 0.4753, acc = 0.8344; test time = 2.4026 seconds
# Total time = 16.8537 seconds
# Train step 58, loss = 0.3626, acc = 0.8746; train time = 14.5502 seconds
# Test loss = 0.4642, acc = 0.8391; test time = 2.3913 seconds
# Total time = 16.9416 seconds
# Train step 59, loss = 0.3608, acc = 0.8752; train time = 14.4849 seconds
# Test loss = 0.4796, acc = 0.8315; test time = 2.4220 seconds
# Total time = 16.9071 seconds
# Train step 60, loss = 0.3613, acc = 0.8753; train time = 14.5087 seconds
# Test loss = 0.4700, acc = 0.8389; test time = 2.3868 seconds
# Total time = 16.8957 seconds
# Train step 61, loss = 0.3606, acc = 0.8752; train time = 14.6198 seconds
# Test loss = 0.4784, acc = 0.8340; test time = 2.4074 seconds
# Total time = 17.0273 seconds
# Train step 62, loss = 0.3600, acc = 0.8761; train time = 14.3506 seconds
# Test loss = 0.4781, acc = 0.8348; test time = 2.3728 seconds
# Total time = 16.7235 seconds
# Train step 63, loss = 0.3590, acc = 0.8766; train time = 14.3211 seconds
# Test loss = 0.4680, acc = 0.8396; test time = 2.3906 seconds
# Total time = 16.7117 seconds
# Train step 64, loss = 0.3600, acc = 0.8757; train time = 14.2927 seconds
# Test loss = 0.4643, acc = 0.8400; test time = 2.3845 seconds
# Total time = 16.6773 seconds
# Train step 65, loss = 0.3580, acc = 0.8763; train time = 14.3904 seconds
# Test loss = 0.4689, acc = 0.8379; test time = 2.4159 seconds
# Total time = 16.8064 seconds
# Train step 66, loss = 0.3592, acc = 0.8747; train time = 14.3303 seconds
# Test loss = 0.4757, acc = 0.8360; test time = 2.4039 seconds
# Total time = 16.7347 seconds
# Train step 67, loss = 0.3605, acc = 0.8751; train time = 14.3100 seconds
# Test loss = 0.4696, acc = 0.8390; test time = 2.3619 seconds
# Total time = 16.6720 seconds
# Train step 68, loss = 0.3568, acc = 0.8766; train time = 14.3690 seconds
# Test loss = 0.4709, acc = 0.8382; test time = 2.3933 seconds
# Total time = 16.7624 seconds
# Train step 69, loss = 0.3559, acc = 0.8773; train time = 14.3872 seconds
# Test loss = 0.4782, acc = 0.8410; test time = 2.3724 seconds
# Total time = 16.7602 seconds
# Train step 70, loss = 0.3560, acc = 0.8768; train time = 14.4086 seconds
# Test loss = 0.4719, acc = 0.8379; test time = 2.3624 seconds
# Total time = 16.7711 seconds
# Train step 71, loss = 0.3585, acc = 0.8754; train time = 14.2896 seconds
# Test loss = 0.4882, acc = 0.8340; test time = 2.3924 seconds
# Total time = 16.6828 seconds
# Train step 72, loss = 0.3625, acc = 0.8743; train time = 14.3843 seconds
# Test loss = 0.4825, acc = 0.8382; test time = 2.3999 seconds
# Total time = 16.7845 seconds
# Train step 73, loss = 0.3571, acc = 0.8765; train time = 14.3836 seconds
# Test loss = 0.4749, acc = 0.8394; test time = 2.4158 seconds
# Total time = 16.7999 seconds
# Train step 74, loss = 0.3562, acc = 0.8763; train time = 14.3914 seconds
# Test loss = 0.4867, acc = 0.8334; test time = 2.3788 seconds
# Total time = 16.7703 seconds
# Train step 75, loss = 0.3562, acc = 0.8763; train time = 14.3377 seconds
# Test loss = 0.4848, acc = 0.8355; test time = 2.3816 seconds
# Total time = 16.7194 seconds
# Train step 76, loss = 0.3563, acc = 0.8769; train time = 14.3143 seconds
# Test loss = 0.4812, acc = 0.8374; test time = 2.3716 seconds
# Total time = 16.6860 seconds
# Train step 77, loss = 0.3549, acc = 0.8775; train time = 14.3898 seconds
# Test loss = 0.4736, acc = 0.8407; test time = 2.3919 seconds
# Total time = 16.7818 seconds
# Train step 78, loss = 0.3563, acc = 0.8763; train time = 14.3500 seconds
# Test loss = 0.4913, acc = 0.8337; test time = 2.4511 seconds
# Total time = 16.8012 seconds
# Train step 79, loss = 0.3559, acc = 0.8774; train time = 14.4789 seconds
# Test loss = 0.4773, acc = 0.8368; test time = 2.3885 seconds
# Total time = 16.8677 seconds
# Train step 80, loss = 0.3553, acc = 0.8775; train time = 14.4521 seconds
# Test loss = 0.4750, acc = 0.8362; test time = 2.3844 seconds
# Total time = 16.8366 seconds
# Train step 81, loss = 0.3559, acc = 0.8777; train time = 14.3857 seconds
# Test loss = 0.4733, acc = 0.8376; test time = 2.3703 seconds
# Total time = 16.7561 seconds
# Train step 82, loss = 0.3548, acc = 0.8772; train time = 14.3244 seconds
# Test loss = 0.4777, acc = 0.8377; test time = 2.3825 seconds
# Total time = 16.7070 seconds
# Train step 83, loss = 0.3545, acc = 0.8774; train time = 14.3585 seconds
# Test loss = 0.4806, acc = 0.8387; test time = 2.3675 seconds
# Total time = 16.7261 seconds
# Train step 84, loss = 0.3576, acc = 0.8758; train time = 14.4131 seconds
# Test loss = 0.4790, acc = 0.8357; test time = 2.3935 seconds
# Total time = 16.8067 seconds
# Train step 85, loss = 0.3558, acc = 0.8769; train time = 14.3839 seconds
# Test loss = 0.4779, acc = 0.8355; test time = 2.3721 seconds
# Total time = 16.7561 seconds
# Train step 86, loss = 0.3551, acc = 0.8771; train time = 14.4313 seconds
# Test loss = 0.4775, acc = 0.8362; test time = 2.3600 seconds
# Total time = 16.7916 seconds
# Train step 87, loss = 0.3556, acc = 0.8771; train time = 14.4629 seconds
# Test loss = 0.4798, acc = 0.8320; test time = 2.3713 seconds
# Total time = 16.8349 seconds
# Train step 88, loss = 0.3577, acc = 0.8755; train time = 14.4776 seconds
# Test loss = 0.4872, acc = 0.8327; test time = 2.4786 seconds
# Total time = 16.9563 seconds
# Train step 89, loss = 0.3535, acc = 0.8772; train time = 14.5627 seconds
# Test loss = 0.4824, acc = 0.8350; test time = 2.3746 seconds
# Total time = 16.9375 seconds
# Train step 90, loss = 0.3546, acc = 0.8771; train time = 14.4455 seconds
# Test loss = 0.4786, acc = 0.8352; test time = 2.3948 seconds
# Total time = 16.8405 seconds
# Train step 91, loss = 0.3532, acc = 0.8773; train time = 14.2940 seconds
# Test loss = 0.4733, acc = 0.8360; test time = 2.3640 seconds
# Total time = 16.6582 seconds
# Train step 92, loss = 0.3539, acc = 0.8770; train time = 14.2581 seconds
# Test loss = 0.4820, acc = 0.8341; test time = 2.3866 seconds
# Total time = 16.6452 seconds
# Train step 93, loss = 0.3537, acc = 0.8786; train time = 14.5037 seconds
# Test loss = 0.4843, acc = 0.8350; test time = 2.4424 seconds
# Total time = 16.9462 seconds
# Train step 94, loss = 0.3532, acc = 0.8775; train time = 14.5955 seconds
# Test loss = 0.4789, acc = 0.8404; test time = 2.3890 seconds
# Total time = 16.9846 seconds
# Train step 95, loss = 0.3570, acc = 0.8769; train time = 14.4915 seconds
# Test loss = 0.4832, acc = 0.8367; test time = 2.4076 seconds
# Total time = 16.8992 seconds
# Train step 96, loss = 0.3545, acc = 0.8786; train time = 14.4105 seconds
# Test loss = 0.4878, acc = 0.8311; test time = 2.3327 seconds
# Total time = 16.7432 seconds
# Train step 97, loss = 0.3534, acc = 0.8776; train time = 14.5026 seconds
# Test loss = 0.4801, acc = 0.8362; test time = 2.4123 seconds
# Total time = 16.9150 seconds
# Train step 98, loss = 0.3526, acc = 0.8778; train time = 14.4587 seconds
# Test loss = 0.4873, acc = 0.8360; test time = 2.4028 seconds
# Total time = 16.8616 seconds
# Train step 99, loss = 0.3559, acc = 0.8769; train time = 14.4192 seconds
# Test loss = 0.4956, acc = 0.8313; test time = 2.4082 seconds
# Total time = 16.8275 seconds
